# %%
from typing import Optional, Callable
from dataclasses import dataclass
import json
import numpy as np
import pandas as pd
from tqdm import tqdm

from functools import partial

np.random.seed(42)

# %%
dataset = pd.read_parquet("products_with_names.parquet")

# %%
dataset.head()
# Out:
#    product_id                                               name
# 0     4036767      Модуль сменный фильтрующий Аквафор КН, 208731
# 1     4050873  Водоочиститель Аквафор модель Кристалл Н, 2059...
# 2     4226160      Развиваем мышление (2-3 года) | Земцова Ольга
# 3     4644911          Lacoste Вода парфюмерная Pour Femme 50 мл
# 4     4788809  Сменные Кассеты Для Мужской Бритвы Gillette Ma...

# %%
dataset.shape
# Out:
# (238443, 2)

# %%
documents_dict = {
    doc[1]["product_id"]: doc[1]["name"] for doc in dataset.iterrows()
}

# %% [markdown]
# ## Подготовим документы

# %%
@dataclass
class Document:
    doc_id: int
    name: str

# %%
documents = [Document(doc_id=doc[1]["product_id"], name=doc[1]["name"]) for doc in dataset.iterrows()]

# %%
documents[:3]
# Out:
# [Document(doc_id=4036767, name='Модуль сменный фильтрующий Аквафор КН, 208731'),
#  Document(doc_id=4050873, name='Водоочиститель Аквафор модель Кристалл Н, 205963 //с краном'),
#  Document(doc_id=4226160, name='Развиваем мышление (2-3 года) | Земцова Ольга')]

# %% [markdown]
# ## Метрики качества

# %% [markdown]
# ### В этом файле собраны взаимодействия пользователей с товарами в поиске
# ### Будем считать товары, с которыми провзаимодействовали - позитивами, остальные - негативами

# %%
query_product_interactions = pd.read_parquet("query_product_interactions.parquet")

# %%
query_product_interactions.sample(5)
# Out:
#                         search_query  \
# 255754                  лимон и лайм
# 175947  печень индюшиная охлажденная
# 160581            озон фреш нашгетсы
# 199324                           мом
# 104727    зарядное устройство кабель
#
#                                                  products
# 255754                                   [[688372347, 2]]
# 175947                                   [[142120793, 1]]
# 160581                 [[1394225566, 1], [1394225559, 1]]
# 199324  [[146944254, 1], [146936389, 2], [148170218, 2...
# 104727                                   [[776057178, 1]]

# %%
query_positives = {
    row[1]["search_query"]: set([x[0] for x in row[1]["products"]]) 
    for row in query_product_interactions.iterrows()
}

# %%
query_positives["homecat"]
# Out:
# {34629202,
#  34629203,
#  139864790,
#  139864791,
#  139864792,
#  177668198,
#  177668199,
#  215201915,
#  248843140,
#  257675430,
#  352414492,
#  667810552}

# %%
good_enough_query_positives = {
    k: v
    for k, v in query_positives.items()
    if len(v) > 10
}

# %%
list(good_enough_query_positives.keys())[:100]
# Out:
# ['durr сыр',
#  'fler alpin',
#  'huggies трусики 6',
#  'monge для кошек',
#  'synergetic мыло',
#  'алкогольные напитки',
#  'альметте сыр',
#  'без глютена хлеб',
#  'белковые батончики без сахара',
#  'болоньезе',
#  'бри сыр',
#  'вафли',
#  'вегета приправа',
#  'веник',
#  'вермишель barilla',
#  'вино',
#  'вискас для кошек сухой',
#  'вода святой источник',
#  'вода снежинская',
#  'вода со вкусом',
#  'вода фрутоняня',
#  'гель для стрики',
#  'голень курицы',
#  'грудинка сырокопченая',
#  'дистья салата',
#  'для бассейна',
#  'жидкость для полоскания рта',
#  'запеканка',
#  'зарядка type с',
#  'зубочистки',
#  'йогурт клубника',
#  'карртошка',
#  'каша безмолочная детская fleur alpine',
#  'каша молочная агуша',
#  'каша молочная детская',
#  'каши фрутоняня',
#  'кекс с изюмом',
#  'кета слабосоленая',
#  'кето',
#  'кола добрый 2 л',
#  'колбаски гриль',
#  'конверт подарочный',
#  'консервация',
#  'конфеиы',
#  'копченый сыр',
#  'краьовые палочки',
#  'ктндер',
#  'лего майнкрафт',
#  'лимонад добрый',
#  'майнкрафт',
#  'макроны',
#  'масло 82,5 сливочное',
#  'масло сливочное 400гр',
#  'матрикс шампунь',
#  'минеральная',
#  'минеральная вода газированная',
#  'минеральная вода негазированная',
#  'мороженое венеция',
#  'мороженое лакомка',
#  'моющие средства для ванны',
#  'мужчине',
#  'мюсли для завтрака',
#  'мясной дом бородина',
#  'напиток добрый',
#  'наушники',
#  'негазированная вода',
#  'ножи кухонные',
#  'облепиха замороженная',
#  'овощные смеси',
#  'огурцы консервированные',
#  'окраина',
#  'отбеливатель кислородный',
#  'памперс трусики 6',
#  'пельмени цезарь',
#  'пена для бритья nivea',
#  'перловая крупа',
#  'печень говяжья',
#  'пиколини колбаски',
#  'питьевые йогурты',
#  'подарок на день рождения',
#  'полотенца в рулоне',
#  'после загара',
#  'праздник',
#  'пюре детское',
#  'пюре детское говядина',
#  'растительные продукты',
#  'рикотта лайт',
#  'рыбные',
#  'с чесноком',
#  'свежая капуста',
#  'святой источник 5 л',
#  'сливки 33 %',
#  'сливки 33 процента',
#  'собачий корм сухой',
#  'соль каменная 1 кг',
#  'сорковь',
#  'спонжи ватные',
#  'средство',
#  'субпродукты куриные',
#  'сухой корм для собак royal canin']

# %%
validation_queries_set = np.random.choice(
    list(good_enough_query_positives.keys()), size=100, replace=False
).tolist()

# %%
validation_queries_set
# Out:
# ['хлеб нарезной белый',
#  'usb lightning',
#  'гель для душа женский 750мл',
#  'хлеб чесночный',
#  'безалкогольное',
#  'лезвия для бритвы',
#  'шоколадное печенье',
#  'мусорные мешки',
#  'вода 19л',
#  'прокладки урологические для женщин',
#  'ессентуки 4 минеральная вода',
#  'злаковые конфеты',
#  'помидорв',
#  'сыр копченый',
#  'donat вода',
#  'блоки для унитаза',
#  'греческий йогурт teos',
#  'майонез heinz',
#  'кофе капсульный dolce gusto',
#  'молоко село зеленое',
#  'шампунь estel',
#  'рагу свиное мираторг',
#  'вертикальный пылесос',
#  'агуша вода',
#  'для творчества',
#  'детский порошок стиральный',
#  'иамло оливковое',
#  'озон фреш мороженое',
#  'без сахара кола',
#  'жидкое мыло synergetic',
#  'корм жидкий для кошек',
#  'каша фрутоняня жидкая',
#  'бадминтон набор',
#  'joonies xxl',
#  'бытовая химия',
#  'подушка для путешествий',
#  'корнер',
#  'эвервес',
#  'proplan для собак',
#  'томат',
#  'кашка фрутоняня',
#  'яблоки фуджи',
#  'чехол на айфон 14',
#  'салат романо свежий',
#  'няня фруто',
#  'велком',
#  'для посуды средство мытья',
#  'кофе капсулы lor',
#  'лакомство для кошек',
#  'felix',
#  'майка женская',
#  'активиа йогурт питьевой',
#  'наполнитель для кошачьего туалета cat step',
#  'фильтр для воды барьер',
#  'дезодорант дав',
#  'pet pride наполнитель',
#  'груша конференция',
#  'каши heinz',
#  'авокадо',
#  'молоко агуша',
#  'котлеты овощные замороженные',
#  'сып',
#  'макароны роллтон',
#  'наркзка',
#  'одноразовые пеленки',
#  'аода',
#  'универсальное чистящее средство',
#  'детские макароны',
#  'мочалки для мытья посуды',
#  'яйцо куриное',
#  'чизкейк',
#  'корм для кошки',
#  'хохланд творожный сыр',
#  'эвалар',
#  'продукты озон фреш',
#  'вкусняшки',
#  'глиняный наполнитель для кошачьего туалета',
#  'смеиана',
#  'для собак',
#  'пчелка конфеты',
#  'хот дог',
#  'мачло',
#  'semper детское питание',
#  'грасс',
#  'корм для собак средних пород',
#  'крылышки',
#  'гоколад',
#  'рублевский',
#  'мороденное',
#  'чили перец',
#  'автозагар для тела',
#  'яипсы',
#  'шоколад черный',
#  'parmalat молоко',
#  'уборки',
#  'творог зерненый карат',
#  'нель для стирки',
#  'лед для напитков',
#  'желатин',
#  'мангал']

# %%
validation_query_positives = {
    k: v
    for k, v in query_positives.items()
    if k in validation_queries_set
}

# %%
validation_query_positives
# Out:
# {'хлеб чесночный': {148234009,
#   148590542,
#   175341662,
#   266528732,
#   321861482,
#   326365538,
#   346528161,
#   396633134,
#   398644622,
#   566943599,
#   719236341,
#   871445282,
#   1032351727,
#   1032351797,
#   1061274470,
#   1141489583,
#   1147086672,
#   1149940627,
#   1149960068,
#   1152411084,
#   1214992426,
#   1603713078},
#  'грасс': {168316689,
#   207862018,
#   207862019,
#   207862120,
#   215542718,
#   216090127,
#   250450073,
#   289657309,
#   289857440,
#   289857826,
#   341751956,
#   349695676,
#   349699275,
#   370718753,
#   422323059,
#   553853260,
#   661424231,
#   862276595,
#   1621042273,
#   1631010650},
#  'donat вода': {138898172,
#   142401068,
#   143484936,
#   145026870,
#   148001285,
#   161571260,
#   220188988,
#   308031476,
#   308031749,
#   549222934,
#   803032431,
#   895258653,
#   1175035709,
#   1292066577,
#   1526948555},
#  'каша фрутоняня жидкая': {141734954,
#   141822580,
#   141822582,
#   141822583,
#   141822587,
#   144967330,
#   145026870,
#   146805007,
#   146805009,
#   146805010,
#   149989767,
#   154599313,
#   154599314,
#   154599317,
#   154599318,
#   154599319,
#   154599320,
#   154599321,
#   154599323,
#   154599325,
#   282145758,
#   487809905,
#   686824985,
#   711290739,
#   723888768,
#   753391211,
#   880281754,
#   1051173730,
#   1618695135},
#  'шоколадное печенье': {135984963,
#   136780563,
#   136780578,
#   138860213,
#   141155425,
#   141326712,
#   141520191,
#   142139275,
#   142139277,
#   142262848,
#   144561084,
#   145803937,
#   145803938,
#   147423729,
#   147423730,
#   150143411,
#   150143413,
#   168765868,
#   173310579,
#   178046083,
#   185094665,
#   240122956,
#   555687179,
#   622804582,
#   692591759,
#   706771281,
#   1230544172,
#   1295810026,
#   1399536158,
#   1487783032,
#   1539018248,
#   1543272605,
#   1635871836},
#  'бадминтон набор': {30947723,
#   172538358,
#   210224591,
#   215872497,
#   226428053,
#   558158335,
#   747279727,
#   891210432,
#   910007680,
#   1075397309,
#   1402174129},
#  'кашка фрутоняня': {141822580,
#   141822582,
#   141822583,
#   141822587,
#   141822595,
#   141822598,
#   141822601,
#   144967340,
#   154599313,
#   154599317,
#   154599318,
#   154599319,
#   154599320,
#   154599321,
#   154599323,
#   154599325,
#   880281715,
#   880281754},
#  'глиняный наполнитель для кошачьего туалета': {7353497,
#   149480572,
#   166124354,
#   736634149,
#   1606451030,
#   1610143018,
#   1611487147,
#   1615305118,
#   1617826402,
#   1618258867,
#   1618258869,
#   1618300856},
#  'озон фреш мороженое': {135507647,
#   138235083,
#   164121569,
#   167653044,
#   167653046,
#   168316689,
#   239542311,
#   311849551,
#   311849552,
#   311849553,
#   311849554,
#   311849555,
#   311849556,
#   472004749,
#   584940620,
#   584940627,
#   584940632,
#   584940639,
#   686824985,
#   845531033,
#   943107933,
#   946829341,
#   946829348,
#   947744677,
#   1033990782,
#   1330312170,
#   1394654510,
#   1394654515,
#   1394654520,
#   1394654524,
#   1394654878,
#   1525488857,
#   1590953101,
#   1614577050,
#   1614577051,
#   1614577128},
#  'лакомство для кошек': {35002260,
#   137324023,
#   180252303,
#   257714362,
#   268901076,
#   273882775,
#   621041182,
#   631049253,
#   713490452,
#   824062895,
#   1000411576,
#   1420677050,
#   1616552995},
#  'детские макароны': {135507647,
#   135507649,
#   135507650,
#   135507653,
#   136001595,
#   136001615,
#   136001625,
#   138349239,
#   138898177,
#   140676396,
#   140676402,
#   140800346,
#   140800363,
#   140800364,
#   140800387,
#   140800394,
#   141020145,
#   141530480,
#   141822580,
#   141822583,
#   142623928,
#   144967324,
#   145547517,
#   146763544,
#   146763547,
#   147677695,
#   147677696,
#   150175609,
#   161270715,
#   163091773,
#   210475282,
#   239542311,
#   243157595,
#   243157648,
#   269188850,
#   292197511,
#   430697207,
#   684933637,
#   712817752,
#   847609213,
#   1051820408,
#   1051820415,
#   1051820420,
#   1051820421,
#   1051820422,
#   1411738764},
#  'гель для душа женский 750мл': {5176642,
#   19045001,
#   19045002,
#   19045003,
#   34846726,
#   140830362,
#   140903638,
#   158524189,
#   244971979,
#   543596285,
#   543943688,
#   543973748,
#   547667920},
#  'felix': {229832733,
#   256987522,
#   285949159,
#   294972437,
#   356292677,
#   556793521,
#   631049253,
#   653995548,
#   653996167,
#   653996170,
#   677234474,
#   677234475,
#   677234758,
#   714958413,
#   714958579,
#   714958800,
#   714958815,
#   714959015,
#   714959018,
#   714959045,
#   714959052,
#   714959096,
#   745224323,
#   763938958,
#   763939193,
#   763939893,
#   763939948,
#   763940255,
#   763940256,
#   763940269,
#   852485497,
#   1307272658,
#   1409910590,
#   1585967420,
#   1623735420,
#   1624794116,
#   1640554850},
#  'томат': {34872818,
#   137324023,
#   137825737,
#   137825742,
#   137827565,
#   139009304,
#   141019962,
#   141019963,
#   141019965,
#   141935261,
#   142224885,
#   142224888,
#   142224889,
#   143170429,
#   146749619,
#   1148373605,
#   1419391162,
#   1508809514,
#   1526778335,
#   1526784960,
#   1526948585},
#  'наркзка': {143294378,
#   146649639,
#   146649648,
#   148481523,
#   153536655,
#   162965683,
#   162965684,
#   166413320,
#   168157533,
#   182542633,
#   184609125,
#   202605425,
#   269856866,
#   281056561,
#   305384028,
#   305384029,
#   305929905,
#   306382660,
#   325341384,
#   335429983,
#   342799080,
#   367336496,
#   390863211,
#   414787502,
#   569257377,
#   652230331,
#   686824985,
#   729640757,
#   743956217,
#   750579819,
#   753343842,
#   807726116,
#   865963950,
#   892411739,
#   1061264483,
#   1148373605,
#   1154106740,
#   1252514368,
#   1498718863,
#   1535350842},
#  'подушка для путешествий': {137324023,
#   617486591,
#   1041390481,
#   1074808726,
#   1211235497,
#   1400247838,
#   1563567751,
#   1563976965,
#   1577365392,
#   1599110378,
#   1599110380,
#   1604886361,
#   1619032126},
#  'универсальное чистящее средство': {20400191,
#   29843722,
#   32345610,
#   32345611,
#   32345612,
#   33695495,
#   33695500,
#   34635445,
#   141530428,
#   142053906,
#   147565469,
#   149245133,
#   151635318,
#   151635323,
#   159377434,
#   162177884,
#   204851984,
#   207862120,
#   266202966,
#   289857440,
#   316056668,
#   316427455,
#   370718753,
#   422323059,
#   540332660,
#   540338606,
#   540349518,
#   541315183,
#   554798039,
#   598077172,
#   598115035,
#   629063495,
#   733119631,
#   864982501,
#   1051820420,
#   1119626520},
#  'чили перец': {136000282,
#   144650891,
#   145324142,
#   149678306,
#   164964635,
#   178103586,
#   267896019,
#   280355901,
#   425638153,
#   1211547017,
#   1417616506},
#  'parmalat молоко': {141580513,
#   141580514,
#   141580515,
#   141876199,
#   141876200,
#   146215073,
#   168666402,
#   172292342,
#   208092637,
#   619302979,
#   765886656,
#   1564275349,
#   1618765125},
#  'прокладки урологические для женщин': {170118453,
#   224692177,
#   260760606,
#   320230734,
#   334628368,
#   334628477,
#   334628542,
#   334628621,
#   563647521,
#   1383524565,
#   1383540745,
#   1608731301,
#   1612601109,
#   1612601112},
#  'сыр копченый': {142731176,
#   142731183,
#   146395534,
#   148814026,
#   189758223,
#   197363587,
#   239486787,
#   261058723,
#   267897218,
#   270670920,
#   286356458,
#   305402004,
#   339823809,
#   343795171,
#   343795172,
#   381300415,
#   398644623,
#   636894743,
#   646829007,
#   661174746,
#   686824985,
#   688375697,
#   733187473,
#   733187480,
#   765289821,
#   814439174,
#   814439181,
#   839595607,
#   866018342,
#   942373519,
#   942373521,
#   942373578,
#   1030035603,
#   1164390209,
#   1300189500,
#   1301966211,
#   1408068030,
#   1417616506,
#   1418429037,
#   1431323815,
#   1568696499},
#  'рагу свиное мираторг': {145127154,
#   146227153,
#   146439891,
#   146439899,
#   152022064,
#   159850699,
#   165273751,
#   172430621,
#   172430622,
#   188564195,
#   248896973,
#   358675922,
#   1213043165},
#  'для творчества': {32868812,
#   148219804,
#   150875672,
#   172112777,
#   174417475,
#   178985079,
#   194878713,
#   230550049,
#   312794060,
#   313982454,
#   317113640,
#   503945628,
#   728435390,
#   747279727,
#   1485413284},
#  'пчелка конфеты': {137673722,
#   137734039,
#   138860272,
#   140486596,
#   143047421,
#   143932917,
#   147359787,
#   415102445,
#   621177276,
#   722547763,
#   865812518,
#   865812531},
#  'яблоки фуджи': {143327789,
#   160572085,
#   248896988,
#   248897020,
#   248897023,
#   292581302,
#   292581304,
#   293814112,
#   496272801,
#   1052320837,
#   1601399877,
#   1613246906},
#  'вертикальный пылесос': {151517600,
#   180062859,
#   190855172,
#   204695787,
#   204709645,
#   278676526,
#   278694078,
#   313622413,
#   464893565,
#   660924146,
#   879646920,
#   899957590,
#   977712914,
#   1166632488,
#   1235364001,
#   1354281046,
#   1380254635,
#   1413954717,
#   1591173827},
#  'продукты озон фреш': {135507650,
#   135653559,
#   137324023,
#   138763790,
#   140800387,
#   142120792,
#   142138049,
#   142224881,
#   145127160,
#   146395435,
#   146439889,
#   163600543,
#   164734608,
#   165273751,
#   168406158,
#   171452688,
#   188564195,
#   246074704,
#   251178770,
#   261375234,
#   267896049,
#   267896105,
#   267896351,
#   270670920,
#   277003287,
#   282769010,
#   284206046,
#   296195153,
#   296196380,
#   297787862,
#   308276983,
#   309527105,
#   311849552,
#   311849553,
#   311849554,
#   313179165,
#   317362784,
#   317362785,
#   317362786,
#   320400213,
#   322661616,
#   322661681,
#   322661720,
#   327789556,
#   358897930,
#   365878874,
#   365878887,
#   396633131,
#   397356460,
#   397356467,
#   425397482,
#   428674257,
#   428674301,
#   437921393,
#   439058771,
#   439058775,
#   448212506,
#   462823741,
#   468728739,
#   471497218,
#   480415577,
#   480419939,
#   484661900,
#   484661910,
#   484661920,
#   484661925,
#   484661930,
#   484661950,
#   487917408,
#   503813627,
#   507161475,
#   553245035,
#   560608280,
#   569979056,
#   578811071,
#   584940620,
#   584940627,
#   584940632,
#   584940705,
#   609364513,
#   609364514,
#   609364515,
#   609364518,
#   613286961,
#   613882096,
#   613882117,
#   613882118,
#   618193600,
#   618195302,
#   618195318,
#   618236270,
#   618241944,
#   629074252,
#   647780777,
#   652520524,
#   652520525,
#   669792213,
#   676097300,
#   684933071,
#   706156472,
#   706156479,
#   729640757,
#   733591167,
#   733591168,
#   733591169,
#   740204301,
#   740477974,
#   740477977,
#   740478110,
#   740488267,
#   753367467,
#   753372146,
#   753372151,
#   753372159,
#   754006766,
#   754006882,
#   754380507,
#   779249248,
#   781685896,
#   781687121,
#   781687138,
#   781687165,
#   781688307,
#   781688678,
#   783418042,
#   790391805,
#   796149948,
#   811058072,
#   811094944,
#   811426819,
#   814638218,
#   824062568,
#   824062732,
#   824062733,
#   824062895,
#   827113934,
#   827113942,
#   847609003,
#   847609122,
#   847609171,
#   847609213,
#   847609240,
#   851336310,
#   851336483,
#   865963950,
#   870147515,
#   921152052,
#   933027806,
#   943110876,
#   946829341,
#   946829348,
#   947744677,
#   982219224,
#   982219225,
#   983036899,
#   983036915,
#   983037179,
#   1017681974,
#   1017682164,
#   1029205891,
#   1029205901,
#   1029205930,
#   1033990782,
#   1065008515,
#   1065298643,
#   1065299289,
#   1077526564,
#   1413604615},
#  'активиа йогурт питьевой': {1052317042,
#   1052317244,
#   1052317463,
#   1052317477,
#   1052317817,
#   1052317833,
#   1052318167,
#   1052318752,
#   1052318880,
#   1052318887,
#   1052318904,
#   1052319121,
#   1052319336,
#   1052320846,
#   1052320851},
#  'гоколад': {137733992,
#   138860210,
#   138860233,
#   141133764,
#   141133767,
#   141133769,
#   141133772,
#   141520191,
#   227234829,
#   227234831,
#   240122958,
#   286356513,
#   300751105,
#   300751340,
#   471728734,
#   692591720,
#   692591759,
#   692591762,
#   800823864,
#   800825957,
#   800828054,
#   1427748156,
#   1427748338},
#  'корм жидкий для кошек': {142895313,
#   143743744,
#   169587856,
#   169587859,
#   169587860,
#   169587862,
#   230756178,
#   235204228,
#   277802933,
#   277802977,
#   277802978,
#   285949159,
#   296082824,
#   297713998,
#   322109394,
#   322109396,
#   322109397,
#   322109399,
#   322109403,
#   387906515,
#   387906561,
#   538184653,
#   563280062,
#   563280247,
#   563280302,
#   563280358,
#   635662432,
#   653996167,
#   677234758,
#   714958413,
#   714958579,
#   714958800,
#   714959015,
#   714959096,
#   714959197,
#   851351957,
#   1016762904,
#   1239522010,
#   1239522297,
#   1290281435},
#  'лезвия для бритвы': {4788804,
#   4788805,
#   4788809,
#   4788814,
#   4788815,
#   4789070,
#   4789072,
#   4789073,
#   4789079,
#   4789089,
#   4789090,
#   7297998,
#   32858184,
#   136090189,
#   144505500,
#   161674517,
#   175653381,
#   220414750,
#   275803661,
#   305543242,
#   446818503,
#   448276053,
#   448371485,
#   622046598,
#   987745764,
#   1617891977},
#  'яипсы': {135166226,
#   135166227,
#   137557446,
#   138134248,
#   143825149,
#   143825150,
#   143825151,
#   148233999,
#   148234002,
#   148234009,
#   148234012,
#   148234013,
#   148234014,
#   148234016,
#   148234018,
#   148234020,
#   148234021,
#   148234043,
#   148234046,
#   149266027,
#   149266028,
#   149678148,
#   149678149,
#   149678150,
#   149678151,
#   154443131,
#   170421039,
#   170421040,
#   186531661,
#   186531662,
#   186531663,
#   231705688,
#   255101393,
#   255101451,
#   269240044,
#   269240134,
#   273349075,
#   381208528,
#   381208550,
#   381208579,
#   462800160,
#   554955274,
#   697340510,
#   1203985836,
#   1303083809,
#   1303083822,
#   1437392051,
#   1525488857,
#   1525488861,
#   1525488863,
#   1525488864,
#   1525502737,
#   1525502741,
#   1525503021,
#   1525507136,
#   1560846731,
#   1595541578,
#   1595541580},
#  'для посуды средство мытья': {34635445,
#   135747632,
#   137986404,
#   138342424,
#   138342427,
#   138342428,
#   138342429,
#   138342430,
#   138342431,
#   138342432,
#   142120791,
#   146212648,
#   147887695,
#   147887697,
#   150036199,
#   154336077,
#   169586415,
#   169586417,
#   181790523,
#   248363792,
#   279097663,
#   288772224,
#   289657309,
#   309137784,
#   540230018,
#   540242339,
#   540246408,
#   540246714,
#   540270565,
#   540297327,
#   540298426,
#   540316000,
#   562879956,
#   562968650,
#   597031571,
#   597169662,
#   597687453,
#   598073683,
#   599328557,
#   602288581,
#   634937643,
#   665943774,
#   756183185,
#   856563143,
#   856563150,
#   856563518,
#   884034728,
#   930843532,
#   993947975,
#   996405699,
#   996405704,
#   996405707,
#   1040744188,
#   1041192915,
#   1056389706,
#   1061471733,
#   1061471795,
#   1061471809,
#   1097161104,
#   1097241358,
#   1160108251,
#   1611747098,
#   1612582097,
#   1615974046},
#  'котлеты овощные замороженные': {144070141,
#   149372998,
#   149373001,
#   150642337,
#   202278021,
#   664335152,
#   912741286,
#   912741298,
#   1456092369,
#   1456092384,
#   1456092394},
#  'майка женская': {25343361,
#   176988019,
#   590973850,
#   590975043,
#   590975395,
#   590975801,
#   590980302,
#   590980315,
#   1130023391,
#   1144372666,
#   1570292478},
#  'мачло': {138876653,
#   139814438,
#   140485906,
#   140485926,
#   145923184,
#   189741636,
#   305484273,
#   380156074,
#   1065298643,
#   1065299289,
#   1164390209},
#  'няня фруто': {141822580,
#   141822591,
#   141822594,
#   141822595,
#   141861405,
#   142586781,
#   144967330,
#   144967336,
#   146427167,
#   147359787,
#   154599313,
#   154599321,
#   154599323,
#   154599325,
#   695659544,
#   695659551,
#   864376510,
#   864376703,
#   864376721,
#   1467157006,
#   1482358493},
#  'молоко агуша': {135653559,
#   135984964,
#   141822587,
#   142120791,
#   143259875,
#   145923182,
#   145923211,
#   146439821,
#   146763500,
#   146763517,
#   146763526,
#   146763544,
#   146763546,
#   146763549,
#   146763552,
#   146764195,
#   146764197,
#   154599318,
#   154599323,
#   159241544,
#   164861574,
#   164862552,
#   170380618,
#   175341662,
#   263098162,
#   267897492,
#   284394993,
#   302876044,
#   308946349,
#   320400213,
#   358897930,
#   398644623,
#   425405844,
#   486954898,
#   488417254,
#   536509373,
#   600850837,
#   623145431,
#   733591169,
#   742535011,
#   871445282,
#   1467157006,
#   1482358493,
#   1508285042,
#   1508285059,
#   1615756322,
#   1616233399}}

# %% [markdown]
# ### Точность (precision) и Полнота (recall)
#
# $$ precision = {relevant\_retrieved \over retrieved},\ recall = {relevant\_retrieved \over all\_relevant} $$

# %%
@dataclass
class Metrics:
    precision: float
    recall: float
    f1_score: float
        
    def __repr__(self):
        return f"precision = {self.precision}\nrecall = {self.recall}\nf1_score = {self.f1_score}"

# %%
def calculate_metrics(ground_truth_set: set[int], search_results_set: set[int]):
    
    # True positives: items that are both in ground truth and search results
    tp = len(ground_truth_set.intersection(search_results_set))
    
    # Precision: tp / (tp + fp)
    precision = tp / len(search_results_set) if len(search_results_set) > 0 else 0.0
    
    # Recall: tp / (tp + fn)
    recall = tp / len(ground_truth_set) if len(ground_truth_set) > 0 else 0.0
    
    # F1-score: harmonic mean of precision and recall
    f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0.0
    
    return Metrics(precision=precision, recall=recall, f1_score=f1_score)

# %%
def calculate_validation_metrics(search_function: Callable, limit: int = 20):
    metrics = []
    search_results = {}
    for query, positives in validation_query_positives.items():
        search_results[query] = search_function(query=query, limit=limit)
        metrics.append(
            calculate_metrics(positives, [x.doc_id for x in search_results[query]])
        )
    
    return Metrics(
        precision=np.mean([x.precision for x in metrics]),
        recall=np.mean([x.recall for x in metrics]),
        f1_score=np.mean([x.f1_score for x in metrics]),
    )

# %% [markdown]
# ## Случайный поиск

# %%
def search_random(documents: list[Document], query: str, limit: int = 10):
    return np.random.choice(documents, size=limit).tolist()

# %%
random_search_results = search_random(documents, "молоко", limit=20)
random_search_results
# Out:
# [Document(doc_id=24962121, name='Бумажные полотенца Zewa Premium Декор, 4 рулона'),
#  Document(doc_id=1563909748, name='Vichy Dercos Densi-Solutions Cыворотка для роста, объема и густоты волос со стемоксидином, ресвератролом и рамнозой, 100 мл. Уцененный товар'),
#  Document(doc_id=205154973, name='FitnesShock Протеиновое печенье без сахара Crispy Кокос-гречка, набор 12 шт'),
#  Document(doc_id=401708866, name='Отривин Бэби Комфорт насадки сменные для детского назального аспиратора, одноразовые и экстрамягкие, 10 шт.'),
#  Document(doc_id=584788724, name='Хумус Ozon fresh, с перчиком халапеньо, 110 г'),
#  Document(doc_id=1467225146, name='Наполнитель Древесный PET PRIDE Впитывающий Без отдушки 9000г. Уцененный товар'),
#  Document(doc_id=1487842550, name='Порошок стиральный Автомат Tide Color 60 стирок 9 кг. Уцененный товар'),
#  Document(doc_id=1574052493, name='Детские одноразовые пеленки YokoSun 20 шт, размер 60*90 (10 шт* 2 уп). Уцененный товар'),
#  Document(doc_id=1639893650, name='Сухой корм для собак крупных пород Brit Premium Dog Adult Large and Giant, курица, 15 кг. Уцененный товар'),
#  Document(doc_id=745798689, name='Внутренний коаксиальный (антенный телевизионный) кабель 100 метров, TWIST, CCS/Al/Al, 45% (RG6) + коннекторы, 100 м, для передачи тв и видео сигнала'),
#  Document(doc_id=1579698918, name='Зефир воздушный для барбекю "Зефирюшки BBQ XXL", Сладкая Сказка, 200 г. Уцененный товар'),
#  Document(doc_id=160467818, name='Вентилятор Arctic P12 Black'),
#  Document(doc_id=1514307461, name='Влажный корм для кошек Sheba Ломтики в соусе с телятиной и языком, 28 шт по 75 г. Уцененный товар'),
#  Document(doc_id=1514251124, name='Scarlett Погружной блендер SC-HB42M47, 4 в 1 – измельчение, взбивание, смешивание, приготовление картофельного пюре, черный. Уцененный товар'),
#  Document(doc_id=487215610, name='Колбаса вареная Телячья Премиум 350-400 г, Oltmanns'),
#  Document(doc_id=779249248, name='Круассан с миндальным кремом 100 г, от Ozon fresh'),
#  Document(doc_id=1406497740, name='Xiaomi Смартфон Redmi Note 13 8/256 ГБ, зеленый'),
#  Document(doc_id=569177608, name='Филе лопатки говядины 450 г, Бифстори, охлажденное'),
#  Document(doc_id=624654664, name='Шампунь SYNERGETIC Интенсивное увлажнение и блеск 3,5 л'),
#  Document(doc_id=1474192565, name='Швабра с отжимом и ведром RidbergHome 8 литров, белый/синий, 2 тряпки/насадки в комплекте. Уцененный товар')]

# %%
calculate_validation_metrics(partial(search_random, documents))
# Out:
# precision = 0.0005
# recall = 0.0002702702702702703
# f1_score = 0.0003508771929824561

# %% [markdown]
# ## Простейший поиск

# %%
def search_dummy(documents: list[Document], query: str, limit: int = 10):
    return [doc for doc in documents if query in doc.name][:limit]

[doc for doc in search_dummy(documents, 'яблоко', limit=5)]
# Out:
# [Document(doc_id=141141355, name='Matti мюсли с орехом и яблоком, 250 г'),
#  Document(doc_id=147218137, name='Сок Добрый, яблоко персик, 0,2 л х 27'),
#  Document(doc_id=147677673, name='Компот детский Агуша, яблоко, черноплодная рябина, клубника, 0,2 л'),
#  Document(doc_id=225491326, name='Конфеты Ирис SOLENTO, без глютена, Ассорти двухцветный, яблоко, клубника, манго, арбуз, 250г'),
#  Document(doc_id=250287549, name='Сок Сады Придонья Exclusive Зелёное яблоко без сахара, 1 л')]

# %%
calculate_validation_metrics(partial(search_dummy, documents), limit=20)
# Out:
# precision = 0.0075
# recall = 0.004725482906149134
# f1_score = 0.005338843038887443

# %% [markdown]
# ### Проблемы:
# - учет регистра
# - пунктуация
# - словоформы
# - стоп-слова
# - опечатки

# %%
search_dummy(documents, 'Яблоко', limit=2)
# Out:
# [Document(doc_id=140676424, name='Пюре детское Fleur Alpine Яблоко, с 4 месяцев, 90 г'),
#  Document(doc_id=142625167, name='Бабушкино Лукошко Кабачок Яблоко пюре с 5 месяцев, 100 г')]

# %%
search_dummy(documents, 'яблоко,', limit=2)
# Out:
# [Document(doc_id=147677673, name='Компот детский Агуша, яблоко, черноплодная рябина, клубника, 0,2 л'),
#  Document(doc_id=225491326, name='Конфеты Ирис SOLENTO, без глютена, Ассорти двухцветный, яблоко, клубника, манго, арбуз, 250г')]

# %%
search_dummy(documents, 'яблоки', limit=2)
# Out:
# [Document(doc_id=1554768232, name='Российские яблоки Агроном-сад, отборные, 4 шт'),
#  Document(doc_id=420836847, name='Набор: капуста брокколи, цветная капуста, тыква, яблоки быстрозамороженные THE LEATLES для приготовления детского питания')]

# %%
search_dummy(documents, 'для', limit=2)
# Out:
# [Document(doc_id=4788809, name='Сменные Кассеты Для Мужской Бритвы Gillette Mach3, с 3 лезвиями, прочнее, чем сталь, для точного бритья, 2 шт'),
#  Document(doc_id=4789070, name='Gillette Fusion5 мужская бритва, 2 кассеты, с 5 лезвиями, уменьшающими трение, с точным триммером для бороды и усов')]

# %%
search_dummy(documents, 'яблако', limit=2)
# Out:
# []

# %% [markdown]
# # Пайплайн представления документов:
# 1. Обработка текста
# 2. Индексация

# %% [markdown]
# ## 1. Обработка текста

# %%
sample_documents = list(dataset.loc[:5, "name"])
sample_documents
# Out:
# ['Модуль сменный фильтрующий Аквафор КН, 208731',
#  'Водоочиститель Аквафор модель Кристалл Н, 205963 //с краном',
#  'Развиваем мышление (2-3 года) | Земцова Ольга',
#  'Lacoste Вода парфюмерная Pour Femme 50 мл',
#  'Сменные Кассеты Для Мужской Бритвы Gillette Mach3, с 3 лезвиями, прочнее, чем сталь, для точного бритья, 2 шт',
#  'Gillette Fusion5 мужская бритва, 2 кассеты, с 5 лезвиями, уменьшающими трение, с точным триммером для бороды и усов']

# %% [markdown]
# ### Этапы
# - обработка текста
# - лингвистический анализ

# %% [markdown]
# ## 1.1 Обработка текста:
# - приведение к нижнему регистру
# - обработка от знаков препинания
# - токенизация
# - избавление от стоп-слов

# %% [markdown]
# ### 1.1.1 Приведение к нижнему регистру

# %%
def lowercase_text(text: str) -> str:
    return text.lower()

# %%
documents_lowercased = [lowercase_text(doc) for doc in sample_documents]
documents_lowercased
# Out:
# ['модуль сменный фильтрующий аквафор кн, 208731',
#  'водоочиститель аквафор модель кристалл н, 205963 //с краном',
#  'развиваем мышление (2-3 года) | земцова ольга',
#  'lacoste вода парфюмерная pour femme 50 мл',
#  'сменные кассеты для мужской бритвы gillette mach3, с 3 лезвиями, прочнее, чем сталь, для точного бритья, 2 шт',
#  'gillette fusion5 мужская бритва, 2 кассеты, с 5 лезвиями, уменьшающими трение, с точным триммером для бороды и усов']

# %% [markdown]
# ### 1.1.2 Замена символов на эквивалентные

# %%
symbols_to_replace = {"ё": "е"}

def replace_symbols(text: str, symbols_to_replace: dict[str, str]) -> str:
    for old, new in symbols_to_replace.items():
        text = text.replace(old, new)
    return text

# %%
documents_replaced = [lowercase_text(doc) for doc in documents_lowercased]
documents_replaced
# Out:
# ['модуль сменный фильтрующий аквафор кн, 208731',
#  'водоочиститель аквафор модель кристалл н, 205963 //с краном',
#  'развиваем мышление (2-3 года) | земцова ольга',
#  'lacoste вода парфюмерная pour femme 50 мл',
#  'сменные кассеты для мужской бритвы gillette mach3, с 3 лезвиями, прочнее, чем сталь, для точного бритья, 2 шт',
#  'gillette fusion5 мужская бритва, 2 кассеты, с 5 лезвиями, уменьшающими трение, с точным триммером для бороды и усов']

# %% [markdown]
# ### 1.1.3 Избавление от знаков препинания

# %%
import string

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
def process_punctuation_simple(text: str) -> str:
    translation_table = str.maketrans(string.punctuation, ' ' * len(string.punctuation))
    text_without_punc = text.translate(translation_table)
    text_without_double_spaces = ' '.join(text_without_punc.split())
    return text_without_double_spaces

# %%
process_punctuation_simple("молоко пастеризованное, 2.5 л")
# Out:
# 'молоко пастеризованное 2 5 л'

# %%
documents_processed_punct = [
    process_punctuation_simple(doc) for doc in documents_replaced
]
documents_processed_punct
# Out:
# ['модуль сменный фильтрующий аквафор кн 208731',
#  'водоочиститель аквафор модель кристалл н 205963 с краном',
#  'развиваем мышление 2 3 года земцова ольга',
#  'lacoste вода парфюмерная pour femme 50 мл',
#  'сменные кассеты для мужской бритвы gillette mach3 с 3 лезвиями прочнее чем сталь для точного бритья 2 шт',
#  'gillette fusion5 мужская бритва 2 кассеты с 5 лезвиями уменьшающими трение с точным триммером для бороды и усов']

# %%
def process_punctuation_smart(text: str) -> str:
    #TODO: придумать более хорошую обработку знаков препинания
    pass

# %% [markdown]
# ### 1.1.4 Токенизация

# %%
def tokenize_simple(text: str) -> list[str]:
    return text.split()

# %%
documents_tokenized = [tokenize_simple(doc) for doc in documents_processed_punct]
documents_tokenized
# Out:
# [['модуль', 'сменный', 'фильтрующий', 'аквафор', 'кн', '208731'],
#  ['водоочиститель',
#   'аквафор',
#   'модель',
#   'кристалл',
#   'н',
#   '205963',
#   'с',
#   'краном'],
#  ['развиваем', 'мышление', '2', '3', 'года', 'земцова', 'ольга'],
#  ['lacoste', 'вода', 'парфюмерная', 'pour', 'femme', '50', 'мл'],
#  ['сменные',
#   'кассеты',
#   'для',
#   'мужской',
#   'бритвы',
#   'gillette',
#   'mach3',
#   'с',
#   '3',
#   'лезвиями',
#   'прочнее',
#   'чем',
#   'сталь',
#   'для',
#   'точного',
#   'бритья',
#   '2',
#   'шт'],
#  ['gillette',
#   'fusion5',
#   'мужская',
#   'бритва',
#   '2',
#   'кассеты',
#   'с',
#   '5',
#   'лезвиями',
#   'уменьшающими',
#   'трение',
#   'с',
#   'точным',
#   'триммером',
#   'для',
#   'бороды',
#   'и',
#   'усов']]

# %% [markdown]
# #### Альтернатива - обработка текста с пунктуацией:

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /Users/dandrosov/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/dandrosov/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize

def tokenize_with_punct(text: str) -> list[str]:
    return word_tokenize(text, language="russian")

# %%
tokenize_with_punct(documents_replaced[2])
# Out:
# ['развиваем', 'мышление', '(', '2-3', 'года', ')', '|', 'земцова', 'ольга']

# %% [markdown]
# ### 1.1.5 Удаление стоп-слов

# %%
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/dandrosov/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
russian_stopwords = set(stopwords.words("russian"))

# %%
russian_stopwords
# Out:
# {'а',
#  'без',
#  'более',
#  'больше',
#  'будет',
#  'будто',
#  'бы',
#  'был',
#  'была',
#  'были',
#  'было',
#  'быть',
#  'в',
#  'вам',
#  'вас',
#  'вдруг',
#  'ведь',
#  'во',
#  'вот',
#  'впрочем',
#  'все',
#  'всегда',
#  'всего',
#  'всех',
#  'всю',
#  'вы',
#  'где',
#  'да',
#  'даже',
#  'два',
#  'для',
#  'до',
#  'другой',
#  'его',
#  'ее',
#  'ей',
#  'ему',
#  'если',
#  'есть',
#  'еще',
#  'ж',
#  'же',
#  'за',
#  'зачем',
#  'здесь',
#  'и',
#  'из',
#  'или',
#  'им',
#  'иногда',
#  'их',
#  'к',
#  'как',
#  'какая',
#  'какой',
#  'когда',
#  'конечно',
#  'кто',
#  'куда',
#  'ли',
#  'лучше',
#  'между',
#  'меня',
#  'мне',
#  'много',
#  'может',
#  'можно',
#  'мой',
#  'моя',
#  'мы',
#  'на',
#  'над',
#  'надо',
#  'наконец',
#  'нас',
#  'не',
#  'него',
#  'нее',
#  'ней',
#  'нельзя',
#  'нет',
#  'ни',
#  'нибудь',
#  'никогда',
#  'ним',
#  'них',
#  'ничего',
#  'но',
#  'ну',
#  'о',
#  'об',
#  'один',
#  'он',
#  'она',
#  'они',
#  'опять',
#  'от',
#  'перед',
#  'по',
#  'под',
#  'после',
#  'потом',
#  'потому',
#  'почти',
#  'при',
#  'про',
#  'раз',
#  'разве',
#  'с',
#  'сам',
#  'свою',
#  'себе',
#  'себя',
#  'сейчас',
#  'со',
#  'совсем',
#  'так',
#  'такой',
#  'там',
#  'тебя',
#  'тем',
#  'теперь',
#  'то',
#  'тогда',
#  'того',
#  'тоже',
#  'только',
#  'том',
#  'тот',
#  'три',
#  'тут',
#  'ты',
#  'у',
#  'уж',
#  'уже',
#  'хорошо',
#  'хоть',
#  'чего',
#  'чем',
#  'через',
#  'что',
#  'чтоб',
#  'чтобы',
#  'чуть',
#  'эти',
#  'этого',
#  'этой',
#  'этом',
#  'этот',
#  'эту',
#  'я'}

# %%
def remove_stopwords_from_doc(doc: list[str], stopwords: set[str]) -> list[str]:
    return [token for token in doc if token not in stopwords]

# %%
documents_processed = [remove_stopwords_from_doc(doc, russian_stopwords) for doc in documents_tokenized]
documents_processed
# Out:
# [['модуль', 'сменный', 'фильтрующий', 'аквафор', 'кн', '208731'],
#  ['водоочиститель', 'аквафор', 'модель', 'кристалл', 'н', '205963', 'краном'],
#  ['развиваем', 'мышление', '2', '3', 'года', 'земцова', 'ольга'],
#  ['lacoste', 'вода', 'парфюмерная', 'pour', 'femme', '50', 'мл'],
#  ['сменные',
#   'кассеты',
#   'мужской',
#   'бритвы',
#   'gillette',
#   'mach3',
#   '3',
#   'лезвиями',
#   'прочнее',
#   'сталь',
#   'точного',
#   'бритья',
#   '2',
#   'шт'],
#  ['gillette',
#   'fusion5',
#   'мужская',
#   'бритва',
#   '2',
#   'кассеты',
#   '5',
#   'лезвиями',
#   'уменьшающими',
#   'трение',
#   'точным',
#   'триммером',
#   'бороды',
#   'усов']]

# %% [markdown]
# ## 1.2 Лингвистический анализ

# %% [markdown]
# ### 1.2.1 Стемминг

# %% [markdown]
# #### Для английского языка

# %%
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()
text = "The stemmed form of leaves is leaf"
tokens = word_tokenize(text)
stemmed_words = [stemmer.stem(word) for word in tokens]
stemmed_words
# Out:
# ['the', 'stem', 'form', 'of', 'leav', 'is', 'leaf']

# %% [markdown]
# #### Для русского языка

# %%
from nltk.stem.snowball import SnowballStemmer

stemmer = SnowballStemmer("russian")

def stem(token: str, stemmer: SnowballStemmer) -> str:
    return stemmer.stem(token)

# %%
documents_processed
# Out:
# [['модуль', 'сменный', 'фильтрующий', 'аквафор', 'кн', '208731'],
#  ['водоочиститель', 'аквафор', 'модель', 'кристалл', 'н', '205963', 'краном'],
#  ['развиваем', 'мышление', '2', '3', 'года', 'земцова', 'ольга'],
#  ['lacoste', 'вода', 'парфюмерная', 'pour', 'femme', '50', 'мл'],
#  ['сменные',
#   'кассеты',
#   'мужской',
#   'бритвы',
#   'gillette',
#   'mach3',
#   '3',
#   'лезвиями',
#   'прочнее',
#   'сталь',
#   'точного',
#   'бритья',
#   '2',
#   'шт'],
#  ['gillette',
#   'fusion5',
#   'мужская',
#   'бритва',
#   '2',
#   'кассеты',
#   '5',
#   'лезвиями',
#   'уменьшающими',
#   'трение',
#   'точным',
#   'триммером',
#   'бороды',
#   'усов']]

# %%
documents_stemmed = [[stem(token, stemmer) for token in doc] for doc in documents_processed]
documents_stemmed
# Out:
# [['модул', 'смен', 'фильтр', 'аквафор', 'кн', '208731'],
#  ['водоочистител', 'аквафор', 'модел', 'кристалл', 'н', '205963', 'кран'],
#  ['развива', 'мышлен', '2', '3', 'год', 'земцов', 'ольг'],
#  ['lacoste', 'вод', 'парфюмерн', 'pour', 'femme', '50', 'мл'],
#  ['смен',
#   'кассет',
#   'мужск',
#   'бритв',
#   'gillette',
#   'mach3',
#   '3',
#   'лезв',
#   'прочн',
#   'стал',
#   'точн',
#   'брит',
#   '2',
#   'шт'],
#  ['gillette',
#   'fusion5',
#   'мужск',
#   'бритв',
#   '2',
#   'кассет',
#   '5',
#   'лезв',
#   'уменьша',
#   'трен',
#   'точн',
#   'триммер',
#   'бород',
#   'ус']]

# %% [markdown]
# ### 1.2.2 Лемматизация

# %% [markdown]
# #### Для английского языка

# %%
nltk.download('omw-1.4')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/dandrosov/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/dandrosov/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

# %%
text = "The lemmatized form of leaves is leaf"
tokens = word_tokenize(text)
lemmatized_words = [lemmatizer.lemmatize(word) for word in tokens]
print(lemmatized_words)
# Out:
# ['The', 'lemmatized', 'form', 'of', 'leaf', 'is', 'leaf']

# %% [markdown]
# #### Для русского языка

# %%
from pymorphy3 import MorphAnalyzer

morph = MorphAnalyzer()

# %%
morph.parse("лабуба")
# Out:
# [Parse(word='лабуба', tag=OpencorporaTag('NOUN,anim,masc,Name sing,nomn'), normal_form='лабуба', score=0.5, methods_stack=((DictionaryAnalyzer(), 'буба', 32, 0), (UnknownPrefixAnalyzer(score_multiplier=0.5), 'ла'))),
#  Parse(word='лабуба', tag=OpencorporaTag('NOUN,inan,femn,Sgtm,Geox sing,nomn'), normal_form='лабуба', score=0.5, methods_stack=((DictionaryAnalyzer(), 'уба', 36, 0), (UnknownPrefixAnalyzer(score_multiplier=0.5), 'лаб')))]

# %%
def lemmatize_token(token: str, lemmatizer: MorphAnalyzer) -> str:
    return lemmatizer.normal_forms(token)[0]

def lemmatize_document(doc: list[str], lemmatizer: MorphAnalyzer) -> list[str]:
    return [lemmatize_token(token, lemmatizer) for token in doc]

# %%
documents_processed
# Out:
# [['модуль', 'сменный', 'фильтрующий', 'аквафор', 'кн', '208731'],
#  ['водоочиститель', 'аквафор', 'модель', 'кристалл', 'н', '205963', 'краном'],
#  ['развиваем', 'мышление', '2', '3', 'года', 'земцова', 'ольга'],
#  ['lacoste', 'вода', 'парфюмерная', 'pour', 'femme', '50', 'мл'],
#  ['сменные',
#   'кассеты',
#   'мужской',
#   'бритвы',
#   'gillette',
#   'mach3',
#   '3',
#   'лезвиями',
#   'прочнее',
#   'сталь',
#   'точного',
#   'бритья',
#   '2',
#   'шт'],
#  ['gillette',
#   'fusion5',
#   'мужская',
#   'бритва',
#   '2',
#   'кассеты',
#   '5',
#   'лезвиями',
#   'уменьшающими',
#   'трение',
#   'точным',
#   'триммером',
#   'бороды',
#   'усов']]

# %%
documents_lemmatized = [lemmatize_document(doc, morph) for doc in documents_processed]
documents_lemmatized
# Out:
# [['модуль', 'сменный', 'фильтровать', 'аквафора', 'кн', '208731'],
#  ['водоочиститель', 'аквафора', 'модель', 'кристалл', 'н', '205963', 'кран'],
#  ['развивать', 'мышление', '2', '3', 'год', 'земцов', 'ольга'],
#  ['lacoste', 'вода', 'парфюмерный', 'pour', 'femme', '50', 'мл'],
#  ['сменный',
#   'кассета',
#   'мужской',
#   'бритва',
#   'gillette',
#   'mach3',
#   '3',
#   'лезвие',
#   'прочный',
#   'сталь',
#   'точный',
#   'бритьё',
#   '2',
#   'шт'],
#  ['gillette',
#   'fusion5',
#   'мужской',
#   'бритва',
#   '2',
#   'кассета',
#   '5',
#   'лезвие',
#   'уменьшать',
#   'трение',
#   'точный',
#   'триммер',
#   'борода',
#   'усов']]

# %% [markdown]
# ## 1.3 Собираем всё вместе

# %%
def process_document(
    doc: str,
    symbols_to_replace: dict[str, str],
    russian_stopwords: set[str],
    lemmatizer: MorphAnalyzer,
) -> list[str]:
    doc = lowercase_text(doc)
    doc = replace_symbols(doc, symbols_to_replace)
    doc = process_punctuation_simple(doc)
    doc_tokens = tokenize_simple(doc)
    doc_tokens = remove_stopwords_from_doc(doc_tokens, russian_stopwords)
    return lemmatize_document(doc_tokens, lemmatizer)

def process_documents(
    docs: list[Document],
    symbols_to_replace: dict[str, str], 
    russian_stopwords: set[str],
    lemmatizer: MorphAnalyzer,
    progress_bar: bool = True
) -> list[tuple[int, list[str]]]:
    iterator = docs
    if progress_bar:
        iterator = tqdm(docs)
    
    return [
        (doc.doc_id, process_document(doc.name, symbols_to_replace, russian_stopwords, lemmatizer))
        for doc in iterator
    ]

# %%
documents[1000]
# Out:
# Document(doc_id=166282743, name='Кухонная вытяжка Weissgauff Aura 850 BL, черный')

# %%
process_document(documents[1000].name, symbols_to_replace, russian_stopwords, morph)
# Out:
# ['кухонный', 'вытяжка', 'weissgauff', 'aura', '850', 'bl', 'чёрный']

# %%
documents_processed = process_documents(documents, symbols_to_replace, russian_stopwords, morph)
# Out:
#   4%|██████▏                                                                                                                                                                 | 8768/238443 [00:04<01:51, 2068.77it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 documents_processed = process_documents(documents, symbols_to_replace, russian_stopwords, morph)
#
# Cell In[66], line 26, in process_documents(docs, symbols_to_replace, russian_stopwords, lemmatizer, progress_bar)
#      22 if progress_bar:
#      23     iterator = tqdm(docs)
#      25 return [
# ---> 26     (doc.doc_id, process_document(doc.name, symbols_to_replace, russian_stopwords, lemmatizer))
#      27     for doc in iterator
#      28 ]
#
# Cell In[66], line 12, in process_document(doc, symbols_to_replace, russian_stopwords, lemmatizer)
#      10 doc_tokens = tokenize_simple(doc)
#      11 doc_tokens = remove_stopwords_from_doc(doc_tokens, russian_stopwords)
# ---> 12 return lemmatize_document(doc_tokens, lemmatizer)
#
# Cell In[61], line 5, in lemmatize_document(doc, lemmatizer)
#       4 def lemmatize_document(doc: list[str], lemmatizer: MorphAnalyzer) -> list[str]:
# ----> 5     return [lemmatize_token(token, lemmatizer) for token in doc]
#
# Cell In[61], line 2, in lemmatize_token(token, lemmatizer)
#       1 def lemmatize_token(token: str, lemmatizer: MorphAnalyzer) -> str:
# ----> 2     return lemmatizer.normal_forms(token)[0]
#
# File ~/Desktop/recsys_ir_2026/venvs/venv/lib/python3.13/site-packages/pymorphy3/analyzer.py:366, in MorphAnalyzer.normal_forms(self, word)
#     363 seen = set()
#     364 result = []
# --> 366 for p in self.parse(word):
#     367     normal_form = p[2]
#     368     if normal_form not in seen:
#
# File ~/Desktop/recsys_ir_2026/venvs/venv/lib/python3.13/site-packages/pymorphy3/analyzer.py:331, in MorphAnalyzer.parse(self, word)
#     328 word_lower = word.lower()
#     330 for analyzer, is_terminal in self._units:
# --> 331     res.extend(analyzer.parse(word, word_lower, seen))
#     333     if is_terminal and res:
#     334         break
#
# File ~/Desktop/recsys_ir_2026/venvs/venv/lib/python3.13/site-packages/pymorphy3/units/by_lookup.py:23, in DictionaryAnalyzer.parse(self, word, word_lower, seen_parses)
#      19 """
#      20 Parse a word using this dictionary.
#      21 """
#      22 res = []
# ---> 23 para_data = self.dict.words.similar_items(word_lower, self.morph.char_substitutes)
#      25 for fixed_word, parses in para_data:
#      26     # `fixed_word` is a word with proper substitute (e.g. ё) letters
#      28     for para_id, idx in parses:
#
# File ~/Desktop/recsys_ir_2026/venvs/venv/lib/python3.13/site-packages/dawg_python/dawgs.py:331, in BytesDAWG.similar_items(self, key, replaces)
#     321 def similar_items(self, key: str, replaces: CompiledReplaces) -> list[tuple[str, bytes]]:
#     322     """
#     323     Returns a list of (key, value) tuples for all variants of ``key``
#     324     in this DAWG according to ``replaces``.
#    (...)    329     unicode strings.
#     330     """
# --> 331     return self._similar_items("", key, self.dct.ROOT, replaces)
#
# File ~/Desktop/recsys_ir_2026/venvs/venv/lib/python3.13/site-packages/dawg_python/dawgs.py:304, in BytesDAWG._similar_items(self, current_prefix, key, index, replace_chars)
#     302         if next_index:
#     303             prefix = current_prefix + key[start_pos:word_pos] + u_replace_char
# --> 304             extra_items = self._similar_items(prefix, key, next_index, replace_chars)
#     305             res += extra_items
#     307 index = self.dct.follow_bytes(b_step, index)
#
# File ~/Desktop/recsys_ir_2026/venvs/venv/lib/python3.13/site-packages/dawg_python/dawgs.py:316, in BytesDAWG._similar_items(self, current_prefix, key, index, replace_chars)
#     314     if index:
#     315         found_key = current_prefix + key[start_pos:]
# --> 316         value = self._value_for_index(index)
#     317         res.insert(0, (found_key, value))
#     319 return res
#
# File ~/Desktop/recsys_ir_2026/venvs/venv/lib/python3.13/site-packages/dawg_python/dawgs.py:390, in RecordDAWG._value_for_index(self, index)
#     389 def _value_for_index(self, index: int) -> list[tuple[Any, ...]]:
# --> 390     value = super()._value_for_index(index)
#     391     return [self._struct.unpack(val) for val in value]
#
# File ~/Desktop/recsys_ir_2026/venvs/venv/lib/python3.13/site-packages/dawg_python/dawgs.py:223, in BytesDAWG._value_for_index(self, index)
#     220 completer = wrapper.Completer(self.dct, self.guide)
#     222 completer.start(index)
# --> 223 while completer.next():
#     224     b64_data = completer.key
#     225     res.append(a2b_base64(b64_data))
#
# File ~/Desktop/recsys_ir_2026/venvs/venv/lib/python3.13/site-packages/dawg_python/wrapper.py:143, in Completer.next(self)
#     141 else:
#     142     while True:
# --> 143         sibling_label = self._guide.sibling(index)
#     144         # Moves to the previous node.
#     145         if len(self.key) > 0:
#
# File ~/Desktop/recsys_ir_2026/venvs/venv/lib/python3.13/site-packages/dawg_python/wrapper.py:94, in Guide.sibling(self, index)
#      91 def child(self, index: int) -> int:
#      92     return self._units[index * 2]
# ---> 94 def sibling(self, index: int) -> int:
#      95     return self._units[index * 2 + 1]
#      97 def read(self, fp: BytesIO) -> None:
#
# KeyboardInterrupt:

# %%
with open("documents_processed.json", "w") as f:
    json.dump(documents_processed, f)

# %%
with open("documents_processed.json", "r") as f:
    documents_processed = json.load(f)

# %%
documents_processed[0]
# Out:
# [4036767, ['модуль', 'сменный', 'фильтровать', 'аквафора', 'кн', '208731']]

# %% [markdown]
# ## 2. Формирование индекса

# %%
sample_documents_processed = documents_processed[:10]
sample_documents_processed
# Out:
# [[4036767, ['модуль', 'сменный', 'фильтровать', 'аквафора', 'кн', '208731']],
#  [4050873,
#   ['водоочиститель', 'аквафора', 'модель', 'кристалл', 'н', '205963', 'кран']],
#  [4226160, ['развивать', 'мышление', '2', '3', 'год', 'земцов', 'ольга']],
#  [4644911, ['lacoste', 'вода', 'парфюмерный', 'pour', 'femme', '50', 'мл']],
#  [4788809,
#   ['сменный',
#    'кассета',
#    'мужской',
#    'бритва',
#    'gillette',
#    'mach3',
#    '3',
#    'лезвие',
#    'прочный',
#    'сталь',
#    'точный',
#    'бритьё',
#    '2',
#    'шт']],
#  [4789070,
#   ['gillette',
#    'fusion5',
#    'мужской',
#    'бритва',
#    '2',
#    'кассета',
#    '5',
#    'лезвие',
#    'уменьшать',
#    'трение',
#    'точный',
#    'триммер',
#    'борода',
#    'усов']],
#  [5176579, ['lady', 'speed', 'stick', 'дезодорант']],
#  [5501348,
#   ['bourjois',
#    'volume',
#    'glamour',
#    'тушь',
#    'ресница',
#    'объёмный',
#    'чёрный',
#    '12',
#    'мл']],
#  [5543514, ['wella', 'краска', 'волос', '110', 'мл']],
#  [5629579,
#   ['кислородный',
#    'жидкий',
#    'пятновыводитель',
#    'хлор',
#    'vanish',
#    'ваниш',
#    'oxi',
#    'action',
#    'цветной',
#    'бельё',
#    'ткань',
#    '2',
#    'л']]]

# %% [markdown]
# #### Составление пар (token, doc_id)

# %%
corpus_tokens = [
    (token, doc_id) for doc_id, doc_tokens in sample_documents_processed for token in doc_tokens
]

# %%
corpus_tokens
# Out:
# [('модуль', 4036767),
#  ('сменный', 4036767),
#  ('фильтровать', 4036767),
#  ('аквафора', 4036767),
#  ('кн', 4036767),
#  ('208731', 4036767),
#  ('водоочиститель', 4050873),
#  ('аквафора', 4050873),
#  ('модель', 4050873),
#  ('кристалл', 4050873),
#  ('н', 4050873),
#  ('205963', 4050873),
#  ('кран', 4050873),
#  ('развивать', 4226160),
#  ('мышление', 4226160),
#  ('2', 4226160),
#  ('3', 4226160),
#  ('год', 4226160),
#  ('земцов', 4226160),
#  ('ольга', 4226160),
#  ('lacoste', 4644911),
#  ('вода', 4644911),
#  ('парфюмерный', 4644911),
#  ('pour', 4644911),
#  ('femme', 4644911),
#  ('50', 4644911),
#  ('мл', 4644911),
#  ('сменный', 4788809),
#  ('кассета', 4788809),
#  ('мужской', 4788809),
#  ('бритва', 4788809),
#  ('gillette', 4788809),
#  ('mach3', 4788809),
#  ('3', 4788809),
#  ('лезвие', 4788809),
#  ('прочный', 4788809),
#  ('сталь', 4788809),
#  ('точный', 4788809),
#  ('бритьё', 4788809),
#  ('2', 4788809),
#  ('шт', 4788809),
#  ('gillette', 4789070),
#  ('fusion5', 4789070),
#  ('мужской', 4789070),
#  ('бритва', 4789070),
#  ('2', 4789070),
#  ('кассета', 4789070),
#  ('5', 4789070),
#  ('лезвие', 4789070),
#  ('уменьшать', 4789070),
#  ('трение', 4789070),
#  ('точный', 4789070),
#  ('триммер', 4789070),
#  ('борода', 4789070),
#  ('усов', 4789070),
#  ('lady', 5176579),
#  ('speed', 5176579),
#  ('stick', 5176579),
#  ('дезодорант', 5176579),
#  ('bourjois', 5501348),
#  ('volume', 5501348),
#  ('glamour', 5501348),
#  ('тушь', 5501348),
#  ('ресница', 5501348),
#  ('объёмный', 5501348),
#  ('чёрный', 5501348),
#  ('12', 5501348),
#  ('мл', 5501348),
#  ('wella', 5543514),
#  ('краска', 5543514),
#  ('волос', 5543514),
#  ('110', 5543514),
#  ('мл', 5543514),
#  ('кислородный', 5629579),
#  ('жидкий', 5629579),
#  ('пятновыводитель', 5629579),
#  ('хлор', 5629579),
#  ('vanish', 5629579),
#  ('ваниш', 5629579),
#  ('oxi', 5629579),
#  ('action', 5629579),
#  ('цветной', 5629579),
#  ('бельё', 5629579),
#  ('ткань', 5629579),
#  ('2', 5629579),
#  ('л', 5629579)]

# %% [markdown]
# #### Сортировка по token, doc_id

# %%
corpus_tokens.sort()

# %%
corpus_tokens
# Out:
# [('110', 5543514),
#  ('12', 5501348),
#  ('2', 4226160),
#  ('2', 4788809),
#  ('2', 4789070),
#  ('2', 5629579),
#  ('205963', 4050873),
#  ('208731', 4036767),
#  ('3', 4226160),
#  ('3', 4788809),
#  ('5', 4789070),
#  ('50', 4644911),
#  ('action', 5629579),
#  ('bourjois', 5501348),
#  ('femme', 4644911),
#  ('fusion5', 4789070),
#  ('gillette', 4788809),
#  ('gillette', 4789070),
#  ('glamour', 5501348),
#  ('lacoste', 4644911),
#  ('lady', 5176579),
#  ('mach3', 4788809),
#  ('oxi', 5629579),
#  ('pour', 4644911),
#  ('speed', 5176579),
#  ('stick', 5176579),
#  ('vanish', 5629579),
#  ('volume', 5501348),
#  ('wella', 5543514),
#  ('аквафора', 4036767),
#  ('аквафора', 4050873),
#  ('бельё', 5629579),
#  ('борода', 4789070),
#  ('бритва', 4788809),
#  ('бритва', 4789070),
#  ('бритьё', 4788809),
#  ('ваниш', 5629579),
#  ('вода', 4644911),
#  ('водоочиститель', 4050873),
#  ('волос', 5543514),
#  ('год', 4226160),
#  ('дезодорант', 5176579),
#  ('жидкий', 5629579),
#  ('земцов', 4226160),
#  ('кассета', 4788809),
#  ('кассета', 4789070),
#  ('кислородный', 5629579),
#  ('кн', 4036767),
#  ('кран', 4050873),
#  ('краска', 5543514),
#  ('кристалл', 4050873),
#  ('л', 5629579),
#  ('лезвие', 4788809),
#  ('лезвие', 4789070),
#  ('мл', 4644911),
#  ('мл', 5501348),
#  ('мл', 5543514),
#  ('модель', 4050873),
#  ('модуль', 4036767),
#  ('мужской', 4788809),
#  ('мужской', 4789070),
#  ('мышление', 4226160),
#  ('н', 4050873),
#  ('объёмный', 5501348),
#  ('ольга', 4226160),
#  ('парфюмерный', 4644911),
#  ('прочный', 4788809),
#  ('пятновыводитель', 5629579),
#  ('развивать', 4226160),
#  ('ресница', 5501348),
#  ('сменный', 4036767),
#  ('сменный', 4788809),
#  ('сталь', 4788809),
#  ('ткань', 5629579),
#  ('точный', 4788809),
#  ('точный', 4789070),
#  ('трение', 4789070),
#  ('триммер', 4789070),
#  ('тушь', 5501348),
#  ('уменьшать', 4789070),
#  ('усов', 4789070),
#  ('фильтровать', 4036767),
#  ('хлор', 5629579),
#  ('цветной', 5629579),
#  ('чёрный', 5501348),
#  ('шт', 4788809)]

# %% [markdown]
# #### Построение dictionary и posting lists

# %%
index = {}

for token, doc_id in corpus_tokens:
    if token in index:
        if doc_id == index[token][-1]:
            continue
        index[token].append(doc_id)
    else:
        index[token] = [doc_id]

# %%
index
# Out:
# {'110': [5543514],
#  '12': [5501348],
#  '2': [4226160, 4788809, 4789070, 5629579],
#  '205963': [4050873],
#  '208731': [4036767],
#  '3': [4226160, 4788809],
#  '5': [4789070],
#  '50': [4644911],
#  'action': [5629579],
#  'bourjois': [5501348],
#  'femme': [4644911],
#  'fusion5': [4789070],
#  'gillette': [4788809, 4789070],
#  'glamour': [5501348],
#  'lacoste': [4644911],
#  'lady': [5176579],
#  'mach3': [4788809],
#  'oxi': [5629579],
#  'pour': [4644911],
#  'speed': [5176579],
#  'stick': [5176579],
#  'vanish': [5629579],
#  'volume': [5501348],
#  'wella': [5543514],
#  'аквафора': [4036767, 4050873],
#  'бельё': [5629579],
#  'борода': [4789070],
#  'бритва': [4788809, 4789070],
#  'бритьё': [4788809],
#  'ваниш': [5629579],
#  'вода': [4644911],
#  'водоочиститель': [4050873],
#  'волос': [5543514],
#  'год': [4226160],
#  'дезодорант': [5176579],
#  'жидкий': [5629579],
#  'земцов': [4226160],
#  'кассета': [4788809, 4789070],
#  'кислородный': [5629579],
#  'кн': [4036767],
#  'кран': [4050873],
#  'краска': [5543514],
#  'кристалл': [4050873],
#  'л': [5629579],
#  'лезвие': [4788809, 4789070],
#  'мл': [4644911, 5501348, 5543514],
#  'модель': [4050873],
#  'модуль': [4036767],
#  'мужской': [4788809, 4789070],
#  'мышление': [4226160],
#  'н': [4050873],
#  'объёмный': [5501348],
#  'ольга': [4226160],
#  'парфюмерный': [4644911],
#  'прочный': [4788809],
#  'пятновыводитель': [5629579],
#  'развивать': [4226160],
#  'ресница': [5501348],
#  'сменный': [4036767, 4788809],
#  'сталь': [4788809],
#  'ткань': [5629579],
#  'точный': [4788809, 4789070],
#  'трение': [4789070],
#  'триммер': [4789070],
#  'тушь': [5501348],
#  'уменьшать': [4789070],
#  'усов': [4789070],
#  'фильтровать': [4036767],
#  'хлор': [5629579],
#  'цветной': [5629579],
#  'чёрный': [5501348],
#  'шт': [4788809]}

# %%
def create_index(documents_processed: list[list[str]], limit: Optional[int] = None):
    sample_documents_processed = documents_processed[:limit]
    corpus_tokens = [
        (token, doc_id) for doc_id, doc_tokens in sample_documents_processed for token in doc_tokens
    ]
    corpus_tokens.sort()

    index = {}

    for token, doc_id in corpus_tokens:
        if token in index:
            if doc_id == index[token][-1]:
                continue
            index[token].append(doc_id)
        else:
            index[token] = [doc_id]

    return index

# %%
documents_index = create_index(documents_processed)

# %%
with open("documents_index.json", "w") as f:
    json.dump(documents_index, f)

# %%
with open("documents_index.json", "r") as f:
    documents_index = json.load(f)

# %% [markdown]
# ## 3. Поиск по обратному индексу

# %%
def search_single_token_query(
    query: str, 
    index: dict[str, list[int]], 
    documents_dict: dict[int, str],
    symbols_to_replace: dict[str, str],
    russian_stopwords: set[str],
    lemmatizer: MorphAnalyzer, 
    limit: Optional[int] = None,
) -> list[str]:
    query = process_document(query, symbols_to_replace, russian_stopwords, lemmatizer)[0]
    return [(result_doc_id, documents_dict[result_doc_id]) for result_doc_id in index[query]][:limit]

# %%
search_single_token_query(
    "диван",
    documents_index,
    documents_dict,
    symbols_to_replace,
    russian_stopwords,
    morph,
    10,
)
# Out:
# [(28876761,
#   'Держатель пялец для вышивания на диване, кресле или за столом, Hobby Nurge'),
#  (169810294,
#   'Наматрасник 160х200 непромокаемый с резинками по углам, простыня водонепроницаемая непромокаемая, наматрацник водонепроницаемый, чехол на матрас или диван, наматрасник защитный махровый, топпер.'),
#  (169810305,
#   'Наматрасник 80х200 непромокаемый с резинками по углам, простыня водонепроницаемая непромокаемая, наматрацник водонепроницаемый, чехол на матрас или диван, наматрасник защитный махровый, топпер.'),
#  (169810314,
#   'Наматрасник 90х200 непромокаемый с резинками по углам, простыня водонепроницаемая непромокаемая, наматрацник водонепроницаемый, чехол на матрас или диван, наматрасник защитный махровый, топпер.'),
#  (170627411,
#   'Наматрасник 180х200 непромокаемый с резинками по углам, простыня водонепроницаемая непромокаемая, наматрацник водонепроницаемый, чехол на матрас или диван, наматрасник защитный махровый, топпер.'),
#  (170627453,
#   'Наматрасник 140х200 непромокаемый с резинками по углам, простыня водонепроницаемая непромокаемая, наматрацник водонепроницаемый, чехол на матрас или диван, наматрасник защитный махровый, топпер.'),
#  (170627456,
#   'Наматрасник 100х200 непромокаемый с резинками по углам, простыня водонепроницаемая непромокаемая, наматрацник водонепроницаемый, чехол на матрас или диван, наматрасник защитный махровый, топпер.'),
#  (172686265,
#   'Наматрасник 90х200 непромокаемый с бортом на резинке, чехол на матрас или диван аквастоп, простынь непромокаемая водонепроницаемая на резинке, наматрасник топпер'),
#  (172686268,
#   'Наматрасник 140х200 непромокаемый с бортом на резинке, чехол на матрас или диван аквастоп, простынь непромокаемая водонепроницаемая на резинке, наматрасник топпер, наматрацник'),
#  (172686269,
#   'Наматрасник 120х200 непромокаемый с бортом на резинке, чехол на матрас или диван аквастоп, простынь непромокаемая водонепроницаемая на резинке, наматрасник топпер, наматрацник')]

# %% [markdown]
# ### Максимизируем точность

# %% [markdown]
# #### Реализуем функцию, которая получает для каждого токена запроса список документов и реализует слияние списков через оператор AND

# %%
def merge_and(posting_lists: list[list[int]]):
    posting_lists.sort(key=len)
    result = posting_lists[0]

    for i in range(1, len(posting_lists)):
        current_list = posting_lists[i]
        new_result = []
        ptr1, ptr2 = 0, 0

        while ptr1 < len(result) and ptr2 < len(current_list):
            if result[ptr1] == current_list[ptr2]:
                new_result.append(result[ptr1])
                ptr1 += 1
                ptr2 += 1
            elif result[ptr1] < current_list[ptr2]:
                ptr1 += 1
            else:
                ptr2 += 1
        result = new_result

    return result

# %%
def search_with_and_condition(
    index: dict[str, list[int]], 
    documents_dict: dict[int, str],
    symbols_to_replace: dict[str, str],
    russian_stopwords: set[str],
    lemmatizer: MorphAnalyzer,
    query: str, 
    limit: Optional[int] = None,
) -> list[str]:
    
    # 1. Обработка текста запроса
    # 2. Получение posting lists для каждого токена
    # 3. Слияние posting lists

    query_processed = process_document(query, symbols_to_replace, russian_stopwords, lemmatizer)

    merged_posting_lists = merge_and([index.get(token, []) for token in query_processed])

    return [
        Document(doc_id=doc_id, name=documents_dict[doc_id]) for doc_id in merged_posting_lists
    ]

# %%
search_with_and_condition(
    documents_index,
    documents_dict,
    symbols_to_replace,
    russian_stopwords,
    morph,
    "диван кровать",
    10,
)
# Out:
# [Document(doc_id=177310072, name='Плед Павлайн Ирен какао 150х200 , плед на кровать; плед на диван; покрывало на кровать; покрывало на диван; плед 150 на 200; плед 200 на 220; 150*200; плед 200х220; плед 150х200; полуторка'),
#  Document(doc_id=229424677, name='Пылесос для дома Jimmy WB55, ручной, для мебели и для удаления пылевых клещей, от шерсти животных, с контейнером, для диванов и кроватей, ультрафиолетовая и ультразвуковая чистка, мощный 600Вт'),
#  Document(doc_id=229425205, name='Пылесос для дома Jimmy JV35, ручной, для мебели, для удаления пылевых клещей, от шерсти животных, с контейнером, для диванов и кроватей, ультрафиолетовая чистка и обработка горячим воздухом'),
#  Document(doc_id=245377779, name='Покрывало на диван/кровать MIX 140х210 см'),
#  Document(doc_id=255343578, name='Покрывало "Сладкий Сон" 220х240 см, двустороннее, однотонное, стеганое Ультрастеп. На кровать, на диван.'),
#  Document(doc_id=262376994, name='Наматрасник стеганый 160 200 водонепроницаемый непромокаемый Мягкость&Комфорт, наматрасник стеганный мягкий 160х200 с резинкой по углам на кровать 160, на диван, хлопок'),
#  Document(doc_id=279745854, name='Подвесной карман-органайзер для кровати с карманами, на диван, кресло, для пульта, журналов, телефона, хранения книг и очков'),
#  Document(doc_id=367354212, name='Плед из хлопка с кисточками односпальный для дивана и на кровать бежевый и коричневый 125х152см, Desert'),
#  Document(doc_id=496408166, name='Покрывало на кровать и диван 117х200 см стеганое, плед для дивана детской и спальни в подарок, бархат, серое АМИ МЕБЕЛЬ Беларусь'),
#  Document(doc_id=514356916, name='Плед флисовый 1,5 спальный на кровать и диван плюшевый Экономь и Я Желтый 150*200см, плотность 160 г/м2, 100% полиэстер'),
#  Document(doc_id=565236463, name='Хлопковый плед покрывало на кровать и диван, пр-во Турция, цвет бежевый, р-р 200*220.'),
#  Document(doc_id=567905258, name='Покрывало на кровать и диван 140х220 см стеганое 1,5 спальное, плед для дивана детской и спальни в подарок, бархат, АМИ МЕБЕЛЬ Беларусь'),
#  Document(doc_id=579348175, name='Покрывало, плед на кровать, на диван 210х240, хлопок 100%'),
#  Document(doc_id=627844666, name='Покрывало плед шерстяной 200х220 см PLEDICO "Скандинавский стиль" на кровать диван евро, серый белый, накидка на диван шерсть, подарочная упаковка, производство Россия'),
#  Document(doc_id=643881579, name='Покрывало на кровать Nikma, Плед на диван 210x240'),
#  Document(doc_id=655012125, name='Плед 200х220 на кровать BARIEL, для дивана, двухсторонний, 60% хлопок, синий с бежевым'),
#  Document(doc_id=655012387, name='Плед для дивана BARIEL, покрывало на кровать, 150x200 см, двухсторонний плед 1,5 спальный, 60% хлопок, синий с бежевым'),
#  Document(doc_id=655015636, name='Плед новогодний 200х220 на кровать Karna FROLANCE, для дивана, двухсторонний, 60% хлопок, серый с красным, подарок на Новый год'),
#  Document(doc_id=655019087, name='Плед Новогодний FROLANCE для дивана, покрывало на кровать, 150x200 см, двухсторонний плед 1,5 спальный, 60% хлопок, серый с красным'),
#  Document(doc_id=655020030, name='Плед для дивана LUZIA, покрывало на кровать, двухсторонний плед 150x200 см, 1,5 спальный, 60% хлопок, бежевый'),
#  Document(doc_id=655020385, name='Плед 200х220 на кровать LUZIA, покрывало на кровать, для дивана, двухсторонний, 60% хлопок, бежевый'),
#  Document(doc_id=760196459, name='Плед для дивана LAVAL, покрывало на кровать, 150x200 см, двухсторонний плед 1,5 спальный, 60% хлопок, серо-бежевый'),
#  Document(doc_id=760196461, name='Плед 200х220 для дивана LAVAL, покрывало на кровать, для дивана, двухсторонний, 60% хлопок, бежевый'),
#  Document(doc_id=799296380, name='Покрывало на кровать Nikma, Плед на диван 150х210 с наволочками 50x70 Стеганая накидка 1,5 спальная'),
#  Document(doc_id=866927709, name='Пылесос для дома Jimmy WB55, ручной, для мебели и для удаления пылевых клещей, от шерсти животных, с контейнером, для диванов и кроватей, ультрафиолетовая и ультразвуковая чистка, мощный 600Вт'),
#  Document(doc_id=974487185, name='Плед 200х220 для дивана MORENA, покрывало на кровать, двухсторонний, 60% хлопок'),
#  Document(doc_id=974488377, name='Плед для дивана MORENA, покрывало на кровать, 150x200 см, двухсторонний плед 1,5 спальный, 60% хлопок'),
#  Document(doc_id=974490770, name='Плед для дивана WILMA, покрывало на кровать, 150x200 см, двухсторонний плед 1,5 спальный, 60% хлопок'),
#  Document(doc_id=1055891680, name='Покрывало на кровать Nikma, Плед на диван 210x240'),
#  Document(doc_id=1055941717, name='Покрывало на кровать Nikma, Плед на диван 150х210 с наволочками 50x70 Стеганая накидка 1,5 спальная'),
#  Document(doc_id=1164247722, name='Плед 200х220 на кровать GRAYSEN, для дивана, двухсторонний, 60% хлопок'),
#  Document(doc_id=1164394329, name='Плед для дивана VIOLE, покрывало на кровать, 150x200 см, двухсторонний плед 1,5 спальный, 60% хлопок'),
#  Document(doc_id=1164401998, name='Плед для дивана BELEZZA, покрывало на кровать, 150x200 см, двухсторонний плед 1,5 спальный, 60% хлопок'),
#  Document(doc_id=1164402222, name='Плед 200х220 на кровать BELEZZA, для дивана, двухсторонний, 60% хлопок'),
#  Document(doc_id=1577994943, name='Плед 200х220 на кровать LUZIA, покрывало на кровать, для дивана, двухсторонний, 60% хлопок, бежевый. Уцененный товар')]

# %%
search_with_and_condition(
    documents_index,
    documents_dict,
    symbols_to_replace,
    russian_stopwords,
    morph,
    "двухъярусная кровать",
    10,
)
# Out:
# [Document(doc_id=355105396, name='Двухъярусная кровать для кукол 46 см Our genration'),
#  Document(doc_id=355115836, name="Набор мебели игровой Li'l Woodzeez Детская и двухъярусная кровать")]

# %%
search_with_and_condition(
    documents_index,
    documents_dict,
    symbols_to_replace,
    russian_stopwords,
    morph,
    "молоко ультрапастеризованное",
    10,
)
# Out:
# [Document(doc_id=140987734, name='Valio Молоко Ультрапастеризованное 1.5% 250мл. 1шт.'),
#  Document(doc_id=140987737, name='Valio Молоко Ультрапастеризованное 2.5% 1000мл. 1шт.'),
#  Document(doc_id=140987742, name='Valio Молоко Ультрапастеризованное 3.5% 1000мл. 1шт.'),
#  Document(doc_id=141165025, name='Молоко ультрапастеризованное Простоквашино, 3,2%, 950 мл'),
#  Document(doc_id=141270536, name='Молоко Вкуснотеево ультрапастеризованное, 2,5%, 950 мл'),
#  Document(doc_id=141270537, name='Молоко ультрапастеризованное, 3,2%, 950 мл, Вкуснотеево'),
#  Document(doc_id=141580513, name='Молоко ультрапастеризованное 3,5%, 1 л, Parmalat'),
#  Document(doc_id=141580514, name='Молоко ультрапастеризованное 1,8% 1 л, Parmalat'),
#  Document(doc_id=141580515, name='Parmalat Молоко Ультрапастеризованное 0.5% 1000мл. 1шт.'),
#  Document(doc_id=141580516, name='Parmalat Молоко Ультрапастеризованное 3.5% 200мл. 1шт.'),
#  Document(doc_id=141580518, name='Молоко Белый Город ультрапастеризованное 3,2%, 1 л'),
#  Document(doc_id=141580519, name='Белый Город Молоко Ультрапастеризованное 2.5% 1000мл. 1шт.'),
#  Document(doc_id=141580524, name='Parmalat Молоко Ультрапастеризованное 0.5% 1000мл. 1шт.'),
#  Document(doc_id=141876199, name='Молоко ультрапастеризованное 3,5%, 12 шт х 1 л, Parmalat'),
#  Document(doc_id=141876200, name='Молоко ультрапастеризованное 1,8% 12 шт х 1 л, Parmalat'),
#  Document(doc_id=141876201, name='Молоко Parmalat ультрапастеризованное 0,5%, 12 шт х 1 л'),
#  Document(doc_id=142731191, name='Из Вологды Молоко Ультрапастеризованное 3.2% 1000мл. 1шт.'),
#  Document(doc_id=142731192, name='Из Вологды Молоко Ультрапастеризованное 3.2% 200мл. 1шт.'),
#  Document(doc_id=143412236, name='Arla Natura Молоко безлактозное, ультрапастеризованное, 1,5%, 1 л'),
#  Document(doc_id=144311416, name='Большая Кружка Молоко Ультрапастеризованное 2.5%'),
#  Document(doc_id=144311417, name='Большая Кружка Молоко Ультрапастеризованное 3.2% 980мл.'),
#  Document(doc_id=144311421, name='Большая Кружка Молоко Ультрапастеризованное 2.5%'),
#  Document(doc_id=144311422, name='Большая Кружка Молоко Ультрапастеризованное 3.2%'),
#  Document(doc_id=146215073, name='Молоко питьевое ультрапастеризованное 3,2% 950 г, Село Зеленое'),
#  Document(doc_id=146885506, name='Домик в Деревне Молоко Ультрапастеризованное 0.5% 950мл. 1шт.'),
#  Document(doc_id=146885507, name='Домик в Деревне Молоко Ультрапастеризованное 1.5% 950мл. 1шт.'),
#  Document(doc_id=146885508, name='Домик в Деревне Молоко Ультрапастеризованное 2.5% 950мл. 1шт.'),
#  Document(doc_id=146885509, name='Домик в Деревне Молоко Ультрапастеризованное 3.5% 950мл. 1шт.'),
#  Document(doc_id=146885510, name='Домик в Деревне Молоко Ультрапастеризованное 6% 950мл. 1шт.'),
#  Document(doc_id=146885570, name='Лианозовское Молоко Ультрапастеризованное 3.2% 950мл. 1шт.'),
#  Document(doc_id=146885579, name='Домик в Деревне Молоко Ультрапастеризованное 3.5% 200мл. 1шт.'),
#  Document(doc_id=146885636, name='Домик в Деревне Молоко Ультрапастеризованное 3.2% 950мл. 1шт.'),
#  Document(doc_id=155942494, name='Молоко питьевое ультрапастеризованное 3,2% 950 г, Село Зеленое'),
#  Document(doc_id=156418189, name='Молоко ультрапастеризованное 3,5%, 12 шт х 1 л, Parmalat'),
#  Document(doc_id=156418190, name='Молоко ультрапастеризованное 1,8% 12 шт х 1 л, Parmalat'),
#  Document(doc_id=156418192, name='Молоко ультрапастеризованное 3,5%, 1 л, Parmalat'),
#  Document(doc_id=156418193, name='Молоко Белый Город ультрапастеризованное 3,2%, 1 л'),
#  Document(doc_id=156418195, name='Молоко ультрапастеризованное 1,8% 1 л, Parmalat'),
#  Document(doc_id=157806650, name='Parmalat Молоко Ультрапастеризованное 0.5% 1000мл. 1шт.'),
#  Document(doc_id=157943187, name='Valio Молоко Ультрапастеризованное 3.5% 1000мл. 1шт.'),
#  Document(doc_id=158022995, name='Молоко Вкуснотеево ультрапастеризованное, 2,5%, 950 мл'),
#  Document(doc_id=158022999, name='Молоко ультрапастеризованное, 3,2%, 950 мл, Вкуснотеево'),
#  Document(doc_id=169111013, name='Молоко Parmalat, ультрапастеризованное 3,5%, 0,2 л х 24 шт'),
#  Document(doc_id=169111014, name='Молоко Parmalat, ультрапастеризованное 1,8%, 0,2 л х 24 шт'),
#  Document(doc_id=172173227, name='Домик в Деревне Молоко Ультрапастеризованное 3.2% 950мл. 12шт.'),
#  Document(doc_id=172173229, name='Домик в Деревне Молоко Ультрапастеризованное 2.5% 950мл. 12шт.'),
#  Document(doc_id=172173236, name='Домик в Деревне Молоко Ультрапастеризованное 3.5% 950мл. 12шт.'),
#  Document(doc_id=172554143, name='Молоко безлактозное, 1,5 % 970 мл, Простоквашино, ультрапастеризованное'),
#  Document(doc_id=172605781, name='Домик в Деревне Молоко Ультрапастеризованное 3.2% 950мл. 12шт.'),
#  Document(doc_id=208092633, name='Parmalat Молоко Ультрапастеризованное 0.05% 1000мл. 1шт.'),
#  Document(doc_id=266965216, name='Веселый Молочник Молоко Ультрапастеризованное 3.2% 1450мл. 1шт.'),
#  Document(doc_id=289313231, name='Большая Кружка Молоко Ультрапастеризованное 2.5%'),
#  Document(doc_id=301021293, name='Молоко 900 г, 3,2%, Вкуснотеево, ультрапастеризованное'),
#  Document(doc_id=301021300, name='Молоко ультрапастеризованное 2,5% 900 г, Вкуснотеево'),
#  Document(doc_id=303734339, name='Молоко 1 л, 3,2%, ЭкоНива, ультрапастеризованное'),
#  Document(doc_id=303734349, name='Молоко 200 мл х 18 шт, 3,2%, ЭкоНива, детское, ультрапастеризованное'),
#  Document(doc_id=303734515, name='Молоко ультрапастеризованное 2,5% 1 л, ЭкоНива'),
#  Document(doc_id=303734524, name='Молоко детское ультрапастеризованное ЭкоНива, 3,2%, 1 л'),
#  Document(doc_id=303734526, name='Молоко 1 л, 3,2%, ЭкоНива, Professional Line, ультрапастеризованное'),
#  Document(doc_id=303734531, name='Молоко ультрапастеризованное 3,5% 1 л, ЭкоНива, Professional Line'),
#  Document(doc_id=303734538, name='Молоко ультрапастеризованное ЭкоНива Professional Line, 3,5%, 1 л х 12 шт'),
#  Document(doc_id=303734539, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт'),
#  Document(doc_id=303734541, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт'),
#  Document(doc_id=318804655, name='Молоко ультрапастеризованное топленое Клевер 4%, 1 л'),
#  Document(doc_id=318804656, name='Молоко ультрапастеризованное Клевер 1,5%, 1 л'),
#  Document(doc_id=320362149, name='Молоко 2,5% 950 мл, Село Зеленое, ультрапастеризованное'),
#  Document(doc_id=320362153, name='Молочная речка Молоко Ультрапастеризованное 3.2% 973мл. 1шт.'),
#  Document(doc_id=321880207, name='Кубанская Буренка Молоко Ультрапастеризованное 3.5% 950мл. 1шт.'),
#  Document(doc_id=355402233, name='Село Зеленое Молоко Ультрапастеризованное 0.032% 950мл.'),
#  Document(doc_id=431422043, name='Мое Любимое Лето Молоко Ультрапастеризованное 2.5% 1шт.'),
#  Document(doc_id=431422050, name='Мое Любимое Лето Молоко Ультрапастеризованное 3.2% 1шт.'),
#  Document(doc_id=487182273, name='Молоко 3,2%, 1 л, Вкусняев, ультрапастеризованное'),
#  Document(doc_id=519534352, name='Кубанская Буренка Молоко Ультрапастеризованное 6.0% 950мл. 1шт.'),
#  Document(doc_id=661216265, name='Молоко Солнышко Кубани ультрапастеризованное 2,5 %, 1 л'),
#  Document(doc_id=661216778, name='Молоко Солнышко Кубани ультрапастеризованное 3,2 % , 1 л'),
#  Document(doc_id=709372520, name='Молоко Очень важная корова ультрапастеризованное 1,5%, 1л'),
#  Document(doc_id=709373794, name='Молоко Очень важная корова ультрапастеризованное 2,5%, 1л'),
#  Document(doc_id=709373807, name='Молоко Очень важная корова ультрапастеризованное 3,2%, 1л'),
#  Document(doc_id=763959430, name='Молоко Калория питьевое ультрапастеризованное  2,5%, 1л'),
#  Document(doc_id=763959466, name='Молоко Калория СуперМилк ультрапастеризованные 3,2%, 200мл'),
#  Document(doc_id=765198754, name='Молоко ультрапастеризованное 3,2%  950 мл, Фрау Му'),
#  Document(doc_id=793483322, name='Снежок Молоко Ультрапастеризованное 3.2% 1000мл. 1шт.'),
#  Document(doc_id=822006157, name='Домик в Деревне Молоко Ультрапастеризованное 3.2% 950мл. 12шт.'),
#  Document(doc_id=943235402, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт'),
#  Document(doc_id=1178201851, name='Молоко питьевое 1,8% 950 мл, Село Зеленое, ультрапастеризованное, безлактозное'),
#  Document(doc_id=1197864792, name='Молоко ФрутоНяня ультрапастеризованное (м.д.ж. 2,5%), 0.2 л'),
#  Document(doc_id=1197864822, name='Молоко ФрутоНяня ультрапастеризованное (м.д.ж. 2,5%), 0.2 л х 12 шт'),
#  Document(doc_id=1404633830, name='Молоко Село Зеленое ультрапастеризованное 2,5%, 12 шт х 0,95 л'),
#  Document(doc_id=1404933336, name='Молоко безлактозное 1,8%, 12 шт х 0,95 л, Село Зеленое, ультрапастеризованное'),
#  Document(doc_id=1411761534, name='Молоко ультрапастеризованное 3,2% 1 л, Милушка'),
#  Document(doc_id=1411761674, name='Молоко ультрапастеризованное 2,5% 1 л, Милушка'),
#  Document(doc_id=1417503471, name='Молоко ультрапастеризованное Славянские Кружева 3,2% 973 мл '),
#  Document(doc_id=1417503473, name='Молоко ультрапастеризованное Славянские Кружева 2,5% 973 мл '),
#  Document(doc_id=1417503475, name='Молоко ультрапастеризованное Славянские Кружева 1,5 % 973 мл '),
#  Document(doc_id=1422856703, name='Parmalat Молоко Ультрапастеризованное 3.5% 1000мл. 12шт. Уцененный товар'),
#  Document(doc_id=1430259029, name='Parmalat Молоко Ультрапастеризованное 1.8% 1000мл. 12шт. Уцененный товар'),
#  Document(doc_id=1436596325, name='Parmalat Молоко Ультрапастеризованное 1.8% 1000мл. 12шт. Уцененный товар'),
#  Document(doc_id=1439965285, name='Parmalat Молоко Ультрапастеризованное 3.5% 1000мл. 12шт. Уцененный товар'),
#  Document(doc_id=1442689601, name='Село Зеленое Молоко Ультрапастеризованное 3.2% 950мл. 12шт. Уцененный товар'),
#  Document(doc_id=1442791428, name='Parmalat Молоко Ультрапастеризованное 3.5% 1000мл. 12шт. Уцененный товар'),
#  Document(doc_id=1444538668, name='Parmalat Молоко Ультрапастеризованное 1.8% 1000мл. 12шт. Уцененный товар'),
#  Document(doc_id=1446236762, name='Село Зеленое Молоко Ультрапастеризованное 3.2% 950мл. 12шт. Уцененный товар'),
#  Document(doc_id=1446524430, name='Parmalat Молоко Ультрапастеризованное 3.5% 1000мл. 12шт. Уцененный товар'),
#  Document(doc_id=1452713977, name='Parmalat Молоко Ультрапастеризованное 1.8% 1000мл. 12шт. Уцененный товар'),
#  Document(doc_id=1461502847, name='Село Зеленое Молоко Ультрапастеризованное 3.2% 950мл. 12шт. Уцененный товар'),
#  Document(doc_id=1463426860, name='Село Зеленое Молоко Ультрапастеризованное 3.2% 950мл. 12шт. Уцененный товар'),
#  Document(doc_id=1465121977, name='Parmalat Молоко Ультрапастеризованное 3.5% 1000мл. 12шт. Уцененный товар'),
#  Document(doc_id=1465448672, name='Село Зеленое Молоко Ультрапастеризованное 3.2% 950мл. 12шт. Уцененный товар'),
#  Document(doc_id=1465449986, name='Село Зеленое Молоко Ультрапастеризованное 3.2% 950мл. 12шт. Уцененный товар'),
#  Document(doc_id=1465450465, name='Село Зеленое Молоко Ультрапастеризованное 3.2% 950мл. 12шт. Уцененный товар'),
#  Document(doc_id=1465450737, name='Село Зеленое Молоко Ультрапастеризованное 3.2% 950мл. 12шт. Уцененный товар'),
#  Document(doc_id=1465451154, name='Село Зеленое Молоко Ультрапастеризованное 3.2% 950мл. 12шт. Уцененный товар'),
#  Document(doc_id=1467305014, name='Село Зеленое Молоко Ультрапастеризованное 3.2% 950мл. 12шт. Уцененный товар'),
#  Document(doc_id=1467976151, name='Село Зеленое Молоко Ультрапастеризованное 3.2% 950мл. 12шт. Уцененный товар'),
#  Document(doc_id=1476367039, name='Parmalat Молоко Ультрапастеризованное 1.8% 1000мл. 12шт. Уцененный товар'),
#  Document(doc_id=1477900510, name='Молоко ФрутоНяня ультрапастеризованное (м.д.ж. 2,5%), 0.2 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1480005547, name='Parmalat Молоко Ультрапастеризованное 1.8% 1000мл. 12шт. Уцененный товар'),
#  Document(doc_id=1480606225, name='Parmalat Молоко Ультрапастеризованное 1.8% 1000мл. 12шт. Уцененный товар'),
#  Document(doc_id=1483397132, name='Село Зеленое Молоко Ультрапастеризованное 3.2% 950мл. 12шт. Уцененный товар'),
#  Document(doc_id=1485668349, name='Parmalat Молоко Ультрапастеризованное 1.8% 1000мл. 12шт. Уцененный товар'),
#  Document(doc_id=1492015575, name='Село Зеленое Молоко Ультрапастеризованное 3.2% 950мл. 12шт. Уцененный товар'),
#  Document(doc_id=1492617881, name='Село Зеленое Молоко Ультрапастеризованное 3.2% 950мл. 12шт. Уцененный товар'),
#  Document(doc_id=1492617890, name='Село Зеленое Молоко Ультрапастеризованное 3.2% 950мл. 12шт. Уцененный товар'),
#  Document(doc_id=1492617900, name='Село Зеленое Молоко Ультрапастеризованное 3.2% 950мл. 12шт. Уцененный товар'),
#  Document(doc_id=1492976818, name='Село Зеленое Молоко Ультрапастеризованное 3.2% 950мл. 12шт. Уцененный товар'),
#  Document(doc_id=1492976826, name='Село Зеленое Молоко Ультрапастеризованное 3.2% 950мл. 12шт. Уцененный товар'),
#  Document(doc_id=1492979173, name='Молоко ФрутоНяня ультрапастеризованное (м.д.ж. 2,5%), 0.2 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1511721311, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1511956975, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1511957022, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1512455472, name='Молоко питьевое ультрапастеризованное Село Зеленое Edge, безлактозное м.д.ж. 1,8%, 0,95 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1512471094, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1514735257, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1520023933, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1523091784, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1523312703, name='Молоко ультрапастеризованное 1,8% Parmalat, 12 шт х 1 л. Уцененный товар'),
#  Document(doc_id=1526933417, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1529160264, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1532950512, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1533926045, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1533926765, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1533927210, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1537040146, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1538223039, name='Домик в Деревне Молоко Ультрапастеризованное 3.2% 950мл. 12шт. Уцененный товар'),
#  Document(doc_id=1539307125, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1539496356, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1540130732, name='Молоко ультрапастеризованное 1,8% Parmalat, 12 шт х 1 л. Уцененный товар'),
#  Document(doc_id=1540797530, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1543591670, name='Молоко ультрапастеризованное 1,8% Parmalat, 12 шт х 1 л. Уцененный товар'),
#  Document(doc_id=1543591678, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1544492466, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1545839409, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1547872421, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1549575429, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1550670142, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1551041038, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1551634307, name='Молоко ФрутоНяня ультрапастеризованное (м.д.ж. 2,5%), 0.2 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1554822397, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1555237222, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1555760500, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1557552585, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1558601740, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1558673027, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1558809126, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1558814225, name='Молоко ультрапастеризованное 1,8% Parmalat, 12 шт х 1 л. Уцененный товар'),
#  Document(doc_id=1560787797, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1561505581, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1562851720, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1562851751, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1563431201, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1564275349, name='Молоко ультрапастеризованное 1,8% Parmalat, 12 шт х 1 л. Уцененный товар'),
#  Document(doc_id=1564806263, name='Молоко ФрутоНяня ультрапастеризованное (м.д.ж. 2,5%), 0.2 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1565093554, name='Молоко ультрапастеризованное 1,8% Parmalat, 12 шт х 1 л. Уцененный товар'),
#  Document(doc_id=1565706330, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1565743928, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1566846788, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1566851288, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1567269783, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1567854144, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1568946360, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1569065798, name='Молоко ультрапастеризованное Вологжанка, 3,2 %, 1 л'),
#  Document(doc_id=1569065801, name='Молоко ультрапастеризованное Вологжанка, 2,5 %, 1 л'),
#  Document(doc_id=1569208599, name='Parmalat молоко ультрапастеризованное 3,5%, 1 л. Уцененный товар'),
#  Document(doc_id=1569871000, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1569900799, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1572319266, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1573313916, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1573804461, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1574223795, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1574224279, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1574785779, name='Молоко питьевое ультрапастеризованное 3,2% 950 г, Село Зеленое'),
#  Document(doc_id=1575355603, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1575368343, name='Молоко питьевое ультрапастеризованное Село Зеленое Edge, безлактозное м.д.ж. 1,8%, 0,95 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1575793516, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1575795512, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1577541194, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1578097446, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1578097450, name='Молоко ФрутоНяня ультрапастеризованное (м.д.ж. 2,5%), 0.2 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1578129464, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1578196630, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1578470020, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1578579473, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1578653235, name='Молоко ультрапастеризованное 1,8% Parmalat, 12 шт х 1 л. Уцененный товар'),
#  Document(doc_id=1581058334, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1581101929, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1581164434, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1581452058, name='Молоко ультрапастеризованное Клевер, 6%, 1 л'),
#  Document(doc_id=1581541759, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1581556729, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1581835108, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1582995272, name='Молоко ультрапастеризованное ЭкоНива, для питания детей с 3-х лет, 3,2%, 200 мл х 18 шт. Уцененный товар'),
#  Document(doc_id=1583858814, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1585616002, name='Молоко питьевое ультрапастеризованное Село Зеленое Edge, безлактозное м.д.ж. 1,8%, 0,95 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1585623440, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1586789869, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1587314622, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1587314641, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1587586228, name='Молоко ФрутоНяня ультрапастеризованное (м.д.ж. 2,5%), 0.2 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1590320867, name='Молоко ультрапастеризованное 1,8% Parmalat, 12 шт х 1 л. Уцененный товар'),
#  Document(doc_id=1590320868, name='Молоко ультрапастеризованное 1,8% Parmalat, 12 шт х 1 л. Уцененный товар'),
#  Document(doc_id=1591065518, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1591065761, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1591167346, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1594642188, name='Молоко ультрапастеризованное 1,8% Parmalat, 12 шт х 1 л. Уцененный товар'),
#  Document(doc_id=1595577880, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1596960176, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1597656828, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1597658114, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1599204338, name='Молоко ФрутоНяня ультрапастеризованное (м.д.ж. 2,5%), 0.2 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1599204460, name='Молоко ФрутоНяня ультрапастеризованное (м.д.ж. 2,5%), 0.2 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1599943274, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1603889300, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1605277391, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1605277438, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1605561938, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1605913048, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1606276985, name='Молоко ультрапастеризованное 1,8% Parmalat, 12 шт х 1 л. Уцененный товар'),
#  Document(doc_id=1608597259, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1609917305, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1610189477, name='Молоко ультрапастеризованное 1,8% Parmalat, 12 шт х 1 л. Уцененный товар'),
#  Document(doc_id=1610189478, name='Молоко ультрапастеризованное 1,8% Parmalat, 12 шт х 1 л. Уцененный товар'),
#  Document(doc_id=1610933888, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1611692855, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1611704998, name='Молоко ультрапастеризованное 1,8% Parmalat, 12 шт х 1 л. Уцененный товар'),
#  Document(doc_id=1612356071, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1612532267, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1612554787, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1612554788, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1612554790, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1612581374, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1613680258, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1613733203, name='Молоко питьевое ультрапастеризованное Село Зеленое Edge, безлактозное м.д.ж. 1,8%, 0,95 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1615880294, name='Молоко ультрапастеризованное Просто Молоко, 3,2 %, 1 л'),
#  Document(doc_id=1615880309, name='Молоко ультрапастеризованное Я ем с умом, низколактозное, 1,5 %, 1 л'),
#  Document(doc_id=1615880546, name='Молоко ультрапастеризованное Просто Молоко, 2,5 %, 1 л'),
#  Document(doc_id=1615880547, name='Молоко ультрапастеризованное Агросила, Халяль, 3,2%, 1 л'),
#  Document(doc_id=1616566545, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1616566547, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1617019308, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1617167003, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1618765125, name='Молоко ультрапастеризованное 1,8% Parmalat, 12 шт х 1 л. Уцененный товар'),
#  Document(doc_id=1621428928, name='Молоко ультрапастеризованное 1,8% Parmalat, 12 шт х 1 л. Уцененный товар'),
#  Document(doc_id=1622678331, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1622678335, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1622834326, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1622837052, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1623287651, name='Молоко ультрапастеризованное 2,8% - 5,6% 200 г, Козочка с Облачка'),
#  Document(doc_id=1624204872, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1626511610, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1626512553, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1626992558, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1627307012, name='Молоко питьевое ультрапастеризованное Село Зеленое Edge, безлактозное м.д.ж. 1,8%, 0,95 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1627939217, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1629712408, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1630581991, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1631438060, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1632173877, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1632188382, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1633865330, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1634382837, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1636026718, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1636103618, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1636118419, name='Молоко питьевое ультрапастеризованное Село Зеленое Edge, безлактозное м.д.ж. 1,8%, 0,95 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1636235359, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1638791212, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1639520820, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1639521599, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1639779872, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1639941483, name='Молоко ультрапастеризованное 1,8% Parmalat, 12 шт х 1 л. Уцененный товар'),
#  Document(doc_id=1639942368, name='Молоко ультрапастеризованное 1,8% Parmalat, 12 шт х 1 л. Уцененный товар'),
#  Document(doc_id=1640069547, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1640467180, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1640587938, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1640587956, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1640947112, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1641808489, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1645498967, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1647610417, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1649003270, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1649927966, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1650484886, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1652238389, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1653065596, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1654313704, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1655485625, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1659569699, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1659571613, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1661338779, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1661803721, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1662824430, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1663006486, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1664324957, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1664997541, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1667898825, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1668056870, name='Молоко питьевое ультрапастеризованное Село Зеленое Edge, безлактозное м.д.ж. 1,8%, 0,95 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1668793469, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1669100477, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1669369282, name='Молоко ультрапастеризованное 1,8% Parmalat, 12 шт х 1 л. Уцененный товар'),
#  Document(doc_id=1670883963, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1670884967, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1670936544, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1670938889, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1671081664, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1671195012, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1671196753, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1671214380, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1671926601, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1674343566, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1674682660, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1675517627, name='Молоко ультрапастеризованное 1,8% Parmalat, 12 шт х 1 л. Уцененный товар'),
#  Document(doc_id=1675799137, name='Молоко ФрутоНяня ультрапастеризованное (м.д.ж. 2,5%), 0.2 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1676019329, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1676887645, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1677123233, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар')]

# %%
search_with_and_condition(
    documents_index,
    documents_dict,
    symbols_to_replace,
    russian_stopwords,
    morph,
    "молоко ультрапастеризованное 1 л",
    10,
)
# Out:
# [Document(doc_id=141580513, name='Молоко ультрапастеризованное 3,5%, 1 л, Parmalat'),
#  Document(doc_id=141580514, name='Молоко ультрапастеризованное 1,8% 1 л, Parmalat'),
#  Document(doc_id=141580518, name='Молоко Белый Город ультрапастеризованное 3,2%, 1 л'),
#  Document(doc_id=141876199, name='Молоко ультрапастеризованное 3,5%, 12 шт х 1 л, Parmalat'),
#  Document(doc_id=141876200, name='Молоко ультрапастеризованное 1,8% 12 шт х 1 л, Parmalat'),
#  Document(doc_id=141876201, name='Молоко Parmalat ультрапастеризованное 0,5%, 12 шт х 1 л'),
#  Document(doc_id=143412236, name='Arla Natura Молоко безлактозное, ультрапастеризованное, 1,5%, 1 л'),
#  Document(doc_id=156418189, name='Молоко ультрапастеризованное 3,5%, 12 шт х 1 л, Parmalat'),
#  Document(doc_id=156418190, name='Молоко ультрапастеризованное 1,8% 12 шт х 1 л, Parmalat'),
#  Document(doc_id=156418192, name='Молоко ультрапастеризованное 3,5%, 1 л, Parmalat'),
#  Document(doc_id=156418193, name='Молоко Белый Город ультрапастеризованное 3,2%, 1 л'),
#  Document(doc_id=156418195, name='Молоко ультрапастеризованное 1,8% 1 л, Parmalat'),
#  Document(doc_id=169111014, name='Молоко Parmalat, ультрапастеризованное 1,8%, 0,2 л х 24 шт'),
#  Document(doc_id=303734339, name='Молоко 1 л, 3,2%, ЭкоНива, ультрапастеризованное'),
#  Document(doc_id=303734515, name='Молоко ультрапастеризованное 2,5% 1 л, ЭкоНива'),
#  Document(doc_id=303734524, name='Молоко детское ультрапастеризованное ЭкоНива, 3,2%, 1 л'),
#  Document(doc_id=303734526, name='Молоко 1 л, 3,2%, ЭкоНива, Professional Line, ультрапастеризованное'),
#  Document(doc_id=303734531, name='Молоко ультрапастеризованное 3,5% 1 л, ЭкоНива, Professional Line'),
#  Document(doc_id=303734538, name='Молоко ультрапастеризованное ЭкоНива Professional Line, 3,5%, 1 л х 12 шт'),
#  Document(doc_id=303734539, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт'),
#  Document(doc_id=303734541, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт'),
#  Document(doc_id=318804655, name='Молоко ультрапастеризованное топленое Клевер 4%, 1 л'),
#  Document(doc_id=318804656, name='Молоко ультрапастеризованное Клевер 1,5%, 1 л'),
#  Document(doc_id=487182273, name='Молоко 3,2%, 1 л, Вкусняев, ультрапастеризованное'),
#  Document(doc_id=661216265, name='Молоко Солнышко Кубани ультрапастеризованное 2,5 %, 1 л'),
#  Document(doc_id=661216778, name='Молоко Солнышко Кубани ультрапастеризованное 3,2 % , 1 л'),
#  Document(doc_id=1404933336, name='Молоко безлактозное 1,8%, 12 шт х 0,95 л, Село Зеленое, ультрапастеризованное'),
#  Document(doc_id=1411761534, name='Молоко ультрапастеризованное 3,2% 1 л, Милушка'),
#  Document(doc_id=1411761674, name='Молоко ультрапастеризованное 2,5% 1 л, Милушка'),
#  Document(doc_id=1512455472, name='Молоко питьевое ультрапастеризованное Село Зеленое Edge, безлактозное м.д.ж. 1,8%, 0,95 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1514735257, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1520023933, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1523091784, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1523312703, name='Молоко ультрапастеризованное 1,8% Parmalat, 12 шт х 1 л. Уцененный товар'),
#  Document(doc_id=1532950512, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1533926045, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1533926765, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1533927210, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1537040146, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1539307125, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1539496356, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1540130732, name='Молоко ультрапастеризованное 1,8% Parmalat, 12 шт х 1 л. Уцененный товар'),
#  Document(doc_id=1543591670, name='Молоко ультрапастеризованное 1,8% Parmalat, 12 шт х 1 л. Уцененный товар'),
#  Document(doc_id=1543591678, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1545839409, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1547872421, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1550670142, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1554822397, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1555237222, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1555760500, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1558673027, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1558814225, name='Молоко ультрапастеризованное 1,8% Parmalat, 12 шт х 1 л. Уцененный товар'),
#  Document(doc_id=1561505581, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1562851720, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1562851751, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1564275349, name='Молоко ультрапастеризованное 1,8% Parmalat, 12 шт х 1 л. Уцененный товар'),
#  Document(doc_id=1565093554, name='Молоко ультрапастеризованное 1,8% Parmalat, 12 шт х 1 л. Уцененный товар'),
#  Document(doc_id=1565706330, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1566846788, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1566851288, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1569065798, name='Молоко ультрапастеризованное Вологжанка, 3,2 %, 1 л'),
#  Document(doc_id=1569065801, name='Молоко ультрапастеризованное Вологжанка, 2,5 %, 1 л'),
#  Document(doc_id=1569208599, name='Parmalat молоко ультрапастеризованное 3,5%, 1 л. Уцененный товар'),
#  Document(doc_id=1569871000, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1569900799, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1572319266, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1573313916, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1574223795, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1575368343, name='Молоко питьевое ультрапастеризованное Село Зеленое Edge, безлактозное м.д.ж. 1,8%, 0,95 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1575793516, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1575795512, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1577541194, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1578196630, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1578653235, name='Молоко ультрапастеризованное 1,8% Parmalat, 12 шт х 1 л. Уцененный товар'),
#  Document(doc_id=1581058334, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1581101929, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1581164434, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1581452058, name='Молоко ультрапастеризованное Клевер, 6%, 1 л'),
#  Document(doc_id=1581541759, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1581556729, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1581835108, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1583858814, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1585616002, name='Молоко питьевое ультрапастеризованное Село Зеленое Edge, безлактозное м.д.ж. 1,8%, 0,95 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1585623440, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1586789869, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1590320867, name='Молоко ультрапастеризованное 1,8% Parmalat, 12 шт х 1 л. Уцененный товар'),
#  Document(doc_id=1590320868, name='Молоко ультрапастеризованное 1,8% Parmalat, 12 шт х 1 л. Уцененный товар'),
#  Document(doc_id=1591065761, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1591167346, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1594642188, name='Молоко ультрапастеризованное 1,8% Parmalat, 12 шт х 1 л. Уцененный товар'),
#  Document(doc_id=1595577880, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1596960176, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1605277391, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1605277438, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1605913048, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1606276985, name='Молоко ультрапастеризованное 1,8% Parmalat, 12 шт х 1 л. Уцененный товар'),
#  Document(doc_id=1608597259, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1610189477, name='Молоко ультрапастеризованное 1,8% Parmalat, 12 шт х 1 л. Уцененный товар'),
#  Document(doc_id=1610189478, name='Молоко ультрапастеризованное 1,8% Parmalat, 12 шт х 1 л. Уцененный товар'),
#  Document(doc_id=1610933888, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1611692855, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1611704998, name='Молоко ультрапастеризованное 1,8% Parmalat, 12 шт х 1 л. Уцененный товар'),
#  Document(doc_id=1612356071, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1612554787, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1612554788, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1612554790, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1612581374, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1613733203, name='Молоко питьевое ультрапастеризованное Село Зеленое Edge, безлактозное м.д.ж. 1,8%, 0,95 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1615880294, name='Молоко ультрапастеризованное Просто Молоко, 3,2 %, 1 л'),
#  Document(doc_id=1615880309, name='Молоко ультрапастеризованное Я ем с умом, низколактозное, 1,5 %, 1 л'),
#  Document(doc_id=1615880546, name='Молоко ультрапастеризованное Просто Молоко, 2,5 %, 1 л'),
#  Document(doc_id=1615880547, name='Молоко ультрапастеризованное Агросила, Халяль, 3,2%, 1 л'),
#  Document(doc_id=1617019308, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1617167003, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1618765125, name='Молоко ультрапастеризованное 1,8% Parmalat, 12 шт х 1 л. Уцененный товар'),
#  Document(doc_id=1621428928, name='Молоко ультрапастеризованное 1,8% Parmalat, 12 шт х 1 л. Уцененный товар'),
#  Document(doc_id=1622678331, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1622678335, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1622837052, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1624204872, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1626992558, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1627307012, name='Молоко питьевое ультрапастеризованное Село Зеленое Edge, безлактозное м.д.ж. 1,8%, 0,95 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1627939217, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1629712408, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1636026718, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1636103618, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1636118419, name='Молоко питьевое ультрапастеризованное Село Зеленое Edge, безлактозное м.д.ж. 1,8%, 0,95 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1636235359, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1638791212, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1639779872, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1639941483, name='Молоко ультрапастеризованное 1,8% Parmalat, 12 шт х 1 л. Уцененный товар'),
#  Document(doc_id=1639942368, name='Молоко ультрапастеризованное 1,8% Parmalat, 12 шт х 1 л. Уцененный товар'),
#  Document(doc_id=1641808489, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1647610417, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1649003270, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1649927966, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1650484886, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1653065596, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1654313704, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1655485625, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1659569699, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1661803721, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1662824430, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1663006486, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1664324957, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1664997541, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1667898825, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1668056870, name='Молоко питьевое ультрапастеризованное Село Зеленое Edge, безлактозное м.д.ж. 1,8%, 0,95 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1668793469, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1669369282, name='Молоко ультрапастеризованное 1,8% Parmalat, 12 шт х 1 л. Уцененный товар'),
#  Document(doc_id=1670883963, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1670884967, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1671195012, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1671196753, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1671926601, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1674343566, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1674682660, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1675517627, name='Молоко ультрапастеризованное 1,8% Parmalat, 12 шт х 1 л. Уцененный товар'),
#  Document(doc_id=1676019329, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1676887645, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар')]

# %%
search_with_and_condition(
    documents_index,
    documents_dict,
    symbols_to_replace,
    russian_stopwords,
    morph,
    "для",
    10,
)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[91], line 1
# ----> 1 search_with_and_condition(
#       2     documents_index,
#       3     documents_dict,
#       4     symbols_to_replace,
#       5     russian_stopwords,
#       6     morph,
#       7     "для",
#       8     10,
#       9 )
#
# Cell In[86], line 17, in search_with_and_condition(index, documents_dict, symbols_to_replace, russian_stopwords, lemmatizer, query, limit)
#       1 def search_with_and_condition(
#       2     index: dict[str, list[int]],
#       3     documents_dict: dict[int, str],
#    (...)     12     # 2. Получение posting lists для каждого токена
#      13     # 3. Слияние posting lists
#      15     query_processed = process_document(query, symbols_to_replace, russian_stopwords, lemmatizer)
# ---> 17     merged_posting_lists = merge_and([index.get(token, []) for token in query_processed])
#      19     return [
#      20         Document(doc_id=doc_id, name=documents_dict[doc_id]) for doc_id in merged_posting_lists
#      21     ]
#
# Cell In[85], line 3, in merge_and(posting_lists)
#       1 def merge_and(posting_lists: list[list[int]]):
#       2     posting_lists.sort(key=len)
# ----> 3     result = posting_lists[0]
#       5     for i in range(1, len(posting_lists)):
#       6         current_list = posting_lists[i]
#
# IndexError: list index out of range

# %%
search_with_and_condition(
    documents_index,
    documents_dict,
    symbols_to_replace,
    russian_stopwords,
    morph,
    "средство для мытья посуды",
    10,
)
# Out:
# [Document(doc_id=6106583, name='Средство для мытья посуды "Frosch Лимон", 500 мл'),
#  Document(doc_id=6106584, name='Средство для мытья посуды "Frosch", с ароматом лимона, 1 л'),
#  Document(doc_id=23772174, name='LION Chamgreen Средство для мытья посуды, овощей и фруктов Зеленый чай 1200 мл'),
#  Document(doc_id=26431422, name='Средство для мытья посуды, овощей и фруктов BioMio Bio-Care, гипоаллергенное, экологичное, без запаха, 450 мл'),
#  Document(doc_id=26431424, name='Средство для мытья посуды, овощей и\xa0фруктов BioMio Bio-Care, гипоаллергенное, экологичное, с\xa0эфирным маслом мяты, 450\xa0мл'),
#  Document(doc_id=26431428, name='Средство для мытья посуды, овощей и фруктов BioMio Bio-Care, гипоаллергенное, экологичное, с эфирным маслом мандарина, 450 мл'),
#  Document(doc_id=29287948, name='LION Chamgreen Средство для мытья посуды, овощей и\xa0фруктов Японский абрикос, мягкая упаковка, 960\xa0мл'),
#  Document(doc_id=33319465, name='Средство для мытья посуды SYNERGETIC антибактериальное,\xa0 с ароматом лимона, 0,5л'),
#  Document(doc_id=33319466, name='Средство для мытья посуды SYNERGETIC антибактериальное, с ароматом лимона, 1л'),
#  Document(doc_id=34093319, name='Средство для мытья посуды LION Японский абрикос концентрированное 960 мл'),
#  Document(doc_id=138342419, name='Средство для мытья посуды Fairy Platinum Ледяная свежесть, 430 мл'),
#  Document(doc_id=138342421, name='Средство для мытья посуды Fairy Platinum "Ледяная свежесть", 650 мл'),
#  Document(doc_id=138342424, name='Средство для мытья посуды Fairy "Сочный лимон", 450 мл'),
#  Document(doc_id=138342425, name='Средство для мытья посуды Fairy "Зеленое яблоко", 450 мл'),
#  Document(doc_id=138342427, name='Средство для мытья посуды Fairy Сочный лимон, 900 мл'),
#  Document(doc_id=138342428, name='Средство для мытья посуды Fairy Зеленое яблоко, 900 мл'),
#  Document(doc_id=138342429, name='Средство для мытья посуды Fairy Апельсин и лимонник 900 мл'),
#  Document(doc_id=138342430, name='Средство для мытья посуды Fairy Нежные руки. Чайное дерево и мята, 900 мл'),
#  Document(doc_id=138342431, name='Средство для мытья посуды Fairy "Нежные руки. Чайное дерево и мята", 450 мл'),
#  Document(doc_id=138342432, name='Средство для мытья посуды Fairy Нежные руки Ромашка и витамин E 900 мл.'),
#  Document(doc_id=138342433, name='Средство для мытья посуды Fairy Нежные руки Ромашка и витамин E 450 мл.'),
#  Document(doc_id=141529817, name='Порошок для посудомоечной машины Сомат Классик, базовое средство для мытья посуды в посудомойке в виде порошка, 1,5кг (50 моек)'),
#  Document(doc_id=141529818, name='Порошок для посудомоечной машины Сомат Классик, базовое средство для мытья посуды в посудомойке в виде порошка, 3кг (100 моек)'),
#  Document(doc_id=142444252, name='Средство для мытья посуды SYNERGETIC антибактериальное, с ароматом лимона, 5л'),
#  Document(doc_id=142444260, name='Средство для мытья посуды SYNERGETIC антибактериальное, с ароматом алоэ, 1л'),
#  Document(doc_id=145349143, name='Средство для мытья посуды SYNERGETIC антибактериальное,с ароматом апельсина, 1л'),
#  Document(doc_id=145349144, name='Средство для мытья посуды SYNERGETIC антибактериальное, с ароматом арбуза, 1л'),
#  Document(doc_id=145349145, name='Средство для мытья посуды SYNERGETIC антибактериальное, с ароматом арбуза, 0,5л'),
#  Document(doc_id=146212647, name='Средство для мытья посуды Fairy "Pure & Clean", 450 мл'),
#  Document(doc_id=146212648, name='Средство для мытья посуды Fairy Pure & Clean, 650 мл'),
#  Document(doc_id=146300675, name='Порошок для посудомоечной машины Сомат Классик, базовое средство для мытья посуды в посудомойке в виде порошка, 3кг (100 моек)'),
#  Document(doc_id=146340596, name='Средство для мытья посуды SYNERGETIC антибактериальное, с ароматом алоэ, 5л'),
#  Document(doc_id=146340597, name='Средство для мытья посуды SYNERGETIC антибактериальное,\xa0 с ароматом апельсина, 0,5л'),
#  Document(doc_id=146340598, name='Средство для мытья посуды SYNERGETIC антибактериальное,\xa0 с ароматом апельсина, 5л'),
#  Document(doc_id=146340599, name='Средство для мытья посуды SYNERGETIC антибактериальное, с ароматом арбуза, 5л'),
#  Document(doc_id=146340600, name='Средство для мытья посуды SYNERGETIC антибактериальное, с ароматом яблока, 5л'),
#  Document(doc_id=147887695, name='Средство для мытья посуды Fairy Нежные руки. Розовый Жасмин и Алоэ Вера, 900 мл'),
#  Document(doc_id=147887697, name='Средство для мытья посуды Fairy Нежные руки. Розовый Жасмин и Алоэ Вера, 450 мл'),
#  Document(doc_id=149480837, name='Гель для мытья посуды, фруктов и овощей Safsu 500мл, Мастерская Олеси Мустаевой Экологичное средство для мытья посуды'),
#  Document(doc_id=149720988, name='Средство для мытья посуды Jundo Green Tea With Mint, 800мл, концентрированный, ЭКО-гель для мытья фруктов, овощей, детской посуды и игрушек'),
#  Document(doc_id=149720990, name='Средство для мытья посуды Jundo Juicy Lemon 800мл, концентрированный, ЭКО-гель для мытья фруктов, овощей, детской посуды и игрушек'),
#  Document(doc_id=149720991, name='Средство для мытья посуды Jundo Juicy Lemon 1л, концентрированный, ЭКО-гель для мытья фруктов, овощей, детской посуды и игрушек'),
#  Document(doc_id=149766826, name='Средство для мытья посуды, овощей и фруктов BioMio Bio-Care, гипоаллергенное, экологичное, без запаха, 750 мл'),
#  Document(doc_id=149766827, name='BIOMIO Экологичное средство для мытья посуды, овощей и фруктов BIO-CARE, антибактериальное,  с эфирным маслом МАНДАРИНА, 750 мл'),
#  Document(doc_id=149821798, name='Средство для мытья посуды Pril Секреты настроения, маракуйя и гибискус, 450 мл'),
#  Document(doc_id=150036199, name='Средство для мытья посуды Fairy Сочный лимон 1.35 л'),
#  Document(doc_id=153929234, name='Порошок для посудомоечной машины Сомат Классик Лимон и Лайм, базовое средство для мытья посуды в посудомойке в виде порошка, 3кг (100 моек)'),
#  Document(doc_id=153976894, name='Средство для мытья посуды Grass Crispi, с маслами белого хлопка, 550 мл'),
#  Document(doc_id=154045794, name='Средство Synergetic (Синергетик), для мытья посуды, Арбуз, 5 л.'),
#  Document(doc_id=155946489, name='Средство для мытья посуды SYNERGETIC антибактериальное, с ароматом арбуза, 1л'),
#  Document(doc_id=158050003, name='LION Chamgreen Средство для мытья посуды, овощей и\xa0фруктов Японский абрикос, мягкая упаковка, 960\xa0мл'),
#  Document(doc_id=158050918, name='Средство для мытья посуды SYNERGETIC антибактериальное, с ароматом алоэ, 1л'),
#  Document(doc_id=158298512, name='Средство для мытья посуды "Frosch Лимон", 500 мл'),
#  Document(doc_id=158316974, name='Средство для мытья посуды, овощей и фруктов BioMio Bio-Care, гипоаллергенное, экологичное, без запаха, 450 мл'),
#  Document(doc_id=161044008, name='Средство для мытья посуды 5 литров, Любаша "Яблоко", 604782'),
#  Document(doc_id=162397284, name='Средство для мытья посуды SYNERGETIC антибактериальное,\xa0 с ароматом лимона, 0,5л'),
#  Document(doc_id=163214557, name='Таблетки для посудомоечной машины Frau Schmidt Средство для мытья посуды с функцией соли и ополаскивателя "Все в 1"в водорастворимой оболочке 40 таблеток'),
#  Document(doc_id=164214774, name='Средство для мытья посуды Fairy "Нежные руки. Розовый Жасмин и Алоэ Вера", 900 мл'),
#  Document(doc_id=167297566, name='Порошок для посудомоечной машины Сомат Классик, базовое средство для мытья посуды в посудомойке в виде порошка, 3кг (100 моек)'),
#  Document(doc_id=169586413, name='Средство для мытья посуды Fairy Pure & Clean Бергамот и Имбирь, 450 мл'),
#  Document(doc_id=169586415, name='Средство для мытья посуды Fairy Pure & Clean Бергамот и Имбирь, 650 мл'),
#  Document(doc_id=169586417, name='Средство для мытья посуды Fairy Pure & Clean, 900 мл'),
#  Document(doc_id=170069490, name='Средство для мытья посуды SYNERGETIC антибактериальное, с ароматом алоэ, 5л'),
#  Document(doc_id=172178942, name='Гель для посудомоечной машины Somat All in 1,мультифункциональное средство для мытья посуды в посудомойке, 936 мл, 52 мойки'),
#  Document(doc_id=172428941, name='LION Chamgreen ЭКО Средство для мытья посуды, овощей и фруктов, биоразлагаемый бальзам-гель для мытья детской посуды Зеленый чай 1200 мл'),
#  Document(doc_id=172428944, name='LION Chamgreen ЭКО Средство для мытья посуды, овощей и фруктов, биоразлагаемый бальзам-гель для мытья детской посуды Зеленый чай 965 мл'),
#  Document(doc_id=225187262, name='Гель для мытья посуды Ника Супер плюс 5 кг, концентрат, средство для мытья посуды 5л Ника'),
#  Document(doc_id=231861304, name='Экологичное средство для мытья посуды Sugar Bubble лимон, 940 мл'),
#  Document(doc_id=231861308, name='Экологичное средство для мытья посуды Sugar Bubble черный рис, 1,200 мл'),
#  Document(doc_id=246852991, name='Набор губок 6шт металлических с мылом, для мытья посуды чистки плит раковин ванн и кафеля, мочалка щетка от нагара сажи копоти налёта накипи извести ржавчины, средство универсальное для дома и дачи'),
#  Document(doc_id=248363792, name='Средство бальзам для мытья посуды Mama Ultimate лимон 1 л'),
#  Document(doc_id=268172648, name='Synergetic Средство для мытья детской посуды, игрушек, сосок и бутылочек 3.5 л'),
#  Document(doc_id=269881729, name='Средство для мытья посуды SYNERGETIC антибактериальное, с ароматом алоэ, 5л'),
#  Document(doc_id=275230939, name='Капсулы для посудомоечной машины Сомат Excellence, мультифункциональное средство для мытья посуды в посудомойке в форме капсул (60 капсул)'),
#  Document(doc_id=279097663, name='Средство гель для мытья посуды концентрат Mama Ultimate лимон 5 л.'),
#  Document(doc_id=285998756, name='Таблетки для посудомоечной машины Herr Klee CG Silver Line, 100 шт (102 штуки), бесфосфатные капсулы для пмм, освежающее моющее средство для чистки и мытья посуды'),
#  Document(doc_id=289657309, name='Средство для мытья посуды 2 шт GRASS CRISPI 1100мл (550мл х 2шт.) пенка для мытья овощей и фруктов с соком груши и с ценными маслами белого хлопка'),
#  Document(doc_id=293880764, name='Дозатор для моющего средства на кухню c губкой и щеткой "Minimal", керамический кухонный диспенсер средства для мытья посуды, дозатор для мыла для кухни, 350 мл'),
#  Document(doc_id=295671591, name='MUKUNGHWA Средство для мытья посуды Apple Mango & Rosemary, 1,2 л'),
#  Document(doc_id=309088152, name='Щетка для мытья посуды с дозатором моющего средства, синяя, NJoy '),
#  Document(doc_id=309137784, name='Средство для мытья посуды Fairy Platinum Арбуз, 650 мл'),
#  Document(doc_id=311620506, name='Таблетки для посудомоечной машины Purmat 7в1, 100 шт (102 штуки), освежающее средство для чистки и мытья посуды'),
#  Document(doc_id=366776407, name='Комплект кассет для фильтров-кувшинов БАРЬЕР Стандарт, 4 шт,удаляет хлор.В комплекте:Средство для мытья посуды и фруктов Пенка Grass Crispi'),
#  Document(doc_id=388375101, name='Средство бальзам для мытья посуды Mama Ultimate зеленый чай 1 л'),
#  Document(doc_id=415359605, name='Средство для мытья посуды, профессиональное, без запаха, от жира и загрязнений, 5 л'),
#  Document(doc_id=501571688, name='Средство для мытья посуды Frosch Лимон, канистра 5 литров, универсальное чистящее жидкое гель-мыло для кухни, антижир для плит и духовок Фрош'),
#  Document(doc_id=505875974, name='Дозатор для моющего средства на кухню "Kitchen", кухонный диспенсер средства для мытья посуды c губкой, дозатор для кухни'),
#  Document(doc_id=511020123, name='Средство для мытья посуды 5 л "Алоэ" SEPTIVIT'),
#  Document(doc_id=525007170, name='Дозатор для моющего средства на кухню "Kitchen", кухонный диспенсер средства для мытья посуды c губкой, дозатор для кухни'),
#  Document(doc_id=601436148, name='Средство для мытья посуды, фруктов, овощей и детских принадлежностей "Mama Lemon", концентрат, цитрусовый, 1 л'),
#  Document(doc_id=601789005, name='Таблетки для посудомоечной машины Frau Schmidt Эко с функцией соли и ополаскивателя средство для мытья посуды "Все в 1" без фосфатов 90 таб'),
#  Document(doc_id=601965379, name='Средство для мытья посуды овощей и фруктов WONDER LAB, экологичный гель для посуды, с сочным ароматом яблочного цвета, 1000 мл'),
#  Document(doc_id=602288581, name='Средство для мытья посуды, овощей и фруктов WONDER LAB, экологичное, с нежным ароматом сливочных фруктов, 3780 мл'),
#  Document(doc_id=609285193, name='Средство для мытья посуды 5 л "Маракуйя" SEPTIVIT. Гипоаллергенное, биоразлагаемое, густое'),
#  Document(doc_id=616101683, name='Clovin/ Набор (Гель для стирки PUROX Color 5,3л + 2 шт. Средство для мытья посуды dr.Prakti Sensitive+Witaminy (для чувствительной кожи с витаминами) 650 мл'),
#  Document(doc_id=628554491, name='Капсулы для посудомоечной машины FINISH Quantum с ароматом ЛИМОНА, 100 шт, ФИНИШ, бесфосфатные, моющее средство для чистки и мытья посуды в ПММ, оболочка растворяется в воде, не нужно разворачивать'),
#  Document(doc_id=628951657, name='Таблетки для посудомоечной машины Finish POWER ESSENTIAL, 140 шт, без отдушки и резкого запаха, бесфосфатные, в обычной пленке, средство для чистки и мытья посуды в ПММ, Польша'),
#  Document(doc_id=633434611, name='Моющее антибактериальное средство гель для мытья и чистки посуды, детских игрушек, соски и бутылочек, а также фруктов с Алоэ Вера и облепихой Simple Line 7 Aloe, 3л'),
#  Document(doc_id=634937643, name='Средство для мытья посуды SYNERGETIC Алоэ вера 0,5 л, антибактериальное, гипоаллергенное, биоразлагаемое, эко, моющее'),
#  Document(doc_id=634957487, name='Средство для мытья посуды SYNERGETIC Сочный лимон 0,5л моющее средство для посуды'),
#  Document(doc_id=640325954, name='Кухонный механический дозатор для моющего средства, диспенсер для жидкого мыла c губкой (дозатор для кухни для мытья посуды, подставка держатель для губки)'),
#  Document(doc_id=654900876, name='Средство для мытья посуды DUTYBOX Фруктовый аромат 5л, пенка для мытья детской посуды, овощей и фруктов + бутылочка с пенным дозатором В ПОДАРОК'),
#  Document(doc_id=659725989, name='Дозатор для моющего средства на кухню "Kitchen", кухонный диспенсер средства для мытья посуды c губкой, дозатор для кухни'),
#  Document(doc_id=665043662, name='Дозатор средства для мытья посуды/диспенсер для моющего средства'),
#  Document(doc_id=665943774, name='Средство для мытья посуды GRASS Velly 5л с ароматом АРБУЗА, антибактериальное, гипоаллергенное моющее средство / гель для мытья посуды'),
#  Document(doc_id=667034987, name='Средство для мытья посуды GRASS Velly light с ароматом Зеленого яблока 5 л (ПЭТ канистра), моющее средство / гель для мытья посуды'),
#  Document(doc_id=667080413, name='Таблетки для посудомоечной машины FINISH CLASSIC бесфосфатные капсулы, без резкого запаха, 90 шт в обычной пленке, ФИНИШ, моющее средство для чистки и мытья посуды в ПММ, Польша'),
# %%
search_with_and_condition(
    documents_index,
    documents_dict,
    symbols_to_replace,
    russian_stopwords,
    morph,
    "скатерть на стол",
    10,
)
# Out:
# [Document(doc_id=148827514, name='Скатерть на стол 145х180 см из хлопка водоотталкивающая, скатерть кухонная на стол с пропиткой для праздника кухни дома сада и дачи пятнозащитная кухонный декор в подарок, белая с розами прованс'),
#  Document(doc_id=148827515, name='Скатерть на стол Fresca Design 145х220 см'),
#  Document(doc_id=149750466, name='Скатерть круглая 185 см на стол из хлопка водоотталкивающая, скатерть на круглый стол кухонная с пропиткой от воды для праздника кухни дома сада и дачи пятнозащитная кухонный текстиль декор в подарок'),
#  Document(doc_id=151998971, name='Скатерть на стол UNTERZO home прямоугольная 145х180 см хлопок'),
#  Document(doc_id=155432339, name='Скатерть на стол круглая Fresca Design 185х185 см хлопок'),
#  Document(doc_id=155523748, name='Скатерть на стол овальная 160х220 см хлопок не боится пятен'),
#  Document(doc_id=155523854, name='Скатерть на стол Fresca Design 145х220 см'),
#  Document(doc_id=155523861, name='Скатерть на стол квадратная 145 см хлопок'),
#  Document(doc_id=155523863, name='Скатерть на стол UNTERZO home прямоугольная 145х180 см хлопок'),
#  Document(doc_id=155523867, name='Скатерть на стол UNTERZO home прямоугольная 145х180 см хлопок'),
#  Document(doc_id=166566934, name='Mia Cara Скатерть на стол 145х220 14056-1 Душистый пион'),
#  Document(doc_id=169022279, name='Скатерть клеенка на стол в кухню из ПВХ на нетканой основе размер 130х165 см'),
#  Document(doc_id=169022280, name='Скатерть клеенка на стол в кухню из ПВХ на нетканой основе размер 130х165 см'),
#  Document(doc_id=169854739, name='Скатерть на стол UNTERZO home прямоугольная 145х180 см хлопок'),
#  Document(doc_id=169987030, name='Скатерть на стол Fresca Design 145х220 см'),
#  Document(doc_id=178195687, name='Скатерть на стол круглая тканевая 145х145 см хлопок'),
#  Document(doc_id=178196021, name='Скатерть круглая 145 см на стол из хлопка водоотталкивающая, скатерть на обеденный круглый стол кухонная с пропиткой от воды для праздника кухни дома сада и дачи пятнозащитная, кухонный текстиль декор в подарок бежевая'),
#  Document(doc_id=178196031, name='Скатерть на стол круглая тканевая 145х145 см хлопок'),
#  Document(doc_id=178203245, name='Скатерть на стол круглая тканевая 145х145 см хлопок'),
#  Document(doc_id=183267913, name='Скатерть клеенка ПВХ на стол, REN277-13/1, размер 180х140см'),
#  Document(doc_id=183267923, name='Скатерть клеенка ПВХ на стол, REN277-12, размер 140х110см'),
#  Document(doc_id=185039888, name='Скатерть круглая на стол водоотталкивающая диаметр 145 см / Кухонная круглая скатерть  на стол до 4-х чел. / Праздничная скатерть / Идеальная скатерть для подарка / Цветочки'),
#  Document(doc_id=186076579, name='Скатерть на стол, клеенка новогодняя прозрачная с рисунком "Ажурная" ПВХ 132х160 см'),
#  Document(doc_id=186076595, name='Скатерть на стол, клеенка новогодняя прозрачная с рисунком "Ажурная" ПВХ 110х132 см'),
#  Document(doc_id=186630735, name='Скатерть овальная на стол водоотталкивающая 200*145 см / Кухонная скатерть на большой овальный стол на 6-10 чел / Скатерть в дом / Праздничная скатерть / Подходит для подарка / Скатерть для пикника / Соты бежевые'),
#  Document(doc_id=186630738, name='Кухонная скатерть на стол водоотталкивающая 200*145 см / Скатерть на большой прямоугольный стол на 6-10 чел / Скатерть в дом / Праздничная скатерть / Идеальная скатерть для подарка / Скатерть для пикника / Соты бежевые'),
#  Document(doc_id=194557710, name='Скатерть на прямоугольный стол, KDK, 160х220, кружевная, тканевая, праздничная, белая'),
#  Document(doc_id=194986545, name='Скатерть на овальный стол CARAMEL,160x220, тканевая, праздничная, белая'),
#  Document(doc_id=195195966, name='Скатерть на овальный стол, KDK, 160х220,кружевная, тканевая, праздничная, кремовая'),
#  Document(doc_id=195195970, name='Скатерть на овальный стол, KDK, 160х220,кружевная, тканевая, праздничная, кремовая'),
#  Document(doc_id=199415897, name='Кухонная скатерть на стол водоотталкивающая 200*145 см / Скатерть на большой прямоугольный стол на 6-10 чел / Скатерть в дом / Праздничная скатерть / Идеальная скатерть для подарка / Скатерть для пикника / Цветочки бежевые'),
#  Document(doc_id=199415961, name='Кухонная скатерть на стол водоотталкивающая 250*145 см / Скатерть на большой прямоугольный стол на 8-12 чел / Скатерть в дом / Праздничная скатерть / Идеальная скатерть для подарка / Скатерть для пикника / Цветочки бежевые'),
#  Document(doc_id=199657535, name='Скатерть на стол круглая водоотталкивающая диаметр 145 см / Кухонная круглая скатерть  на стол до 4-х чел. / Праздничная скатерть / Идеальная скатерть для подарка / Цветочки серые'),
#  Document(doc_id=199792224, name='Скатерть на стол 110*145 см прямоугольная водоотталкивающая'),
#  Document(doc_id=205048696, name='Скатерть овальная водоотталкивающая 200*145 см / Кухонная скатерть на стол до 10-ти чел / Овальная скатерть в дом / Праздничная скатерть / Идеальная скатерть для подарка / Клетка'),
#  Document(doc_id=210411588, name='Новогодняя дорожка на стол,тканевая,45х145,скатерть,хлопок,новый год,подарок'),
#  Document(doc_id=210411641, name='Новогодняя дорожка на стол,тканевая,45х145,скатерть,хлопок,новый год,подарок'),
#  Document(doc_id=215002145, name='Новогодняя дорожка на стол,тканевая,45х145,скатерть,хлопок, новый год,подарок'),
#  Document(doc_id=215002151, name='Новогодняя дорожка на стол,тканевая,50х145,скатерть,хлопок,новый год,подарок'),
#  Document(doc_id=223443962, name='Скатерть на стол, водоотталкивающая, хлопок 260 г/кв.м'),
#  Document(doc_id=223447577, name='Скатерть на стол, водоотталкивающая, хлопок 260 г/кв.м'),
#  Document(doc_id=223456642, name='Скатерть на стол, водоотталкивающая, хлопок 260 г/кв.м'),
#  Document(doc_id=226076236, name='Силиконовая скатерть Decosave Эконом на стол, толщина 0,8 мм. (мягкое стекло/защитная пленка/гибкое) прозрачная, 70*110 см'),
#  Document(doc_id=228991921, name='Силиконовая скатерть прозрачная на стол, клеенка овальная ПВХ 190х130 см'),
#  Document(doc_id=235154366, name='Скатерть на стол, серо-голубая, водоотталкивающая, хлопок 260 г/кв.м'),
#  Document(doc_id=251857072, name='Скатерть дорожка на стол, водоотталкивающая, хлопок 260 г/кв. м'),
#  Document(doc_id=282422511, name='Mia Cara Новогодняя Скатерть на стол 145х145 Альпийская сказка 30196-1'),
#  Document(doc_id=289246807, name='Круглая силиконовая скатерть 90см 1.8мм на стол, гибкое стекло круглое'),
#  Document(doc_id=291589179, name='Круглая силиконовая скатерть 100см 1.8мм на стол, гибкое стекло круглое'),
#  Document(doc_id=291594183, name='Круглая силиконовая скатерть 90см 1мм на стол, гибкое стекло круглое'),
#  Document(doc_id=294300603, name='Скатерть кружевная 137х180 см, непромокаемая ажурная клеенка на стол'),
#  Document(doc_id=317131604, name='Скатерть на стол Круглая Новогодняя 220x220 Этель Сhristmas bells Влагоотталкивающая'),
#  Document(doc_id=317133671, name='Скатерть на стол Новогодняя 150x220 Этель Forest animals Влагооталкивающая'),
#  Document(doc_id=323126331, name='Скатерть на стол тканевая, водоотталкивающая, хлопок 260 г/кв.м'),
#  Document(doc_id=336568892, name='Скатерть на стол Ren629-6 клеенка ПВХ 140х110см'),
#  Document(doc_id=337528788, name='Скатерть на стол Ren393-6-7 клеенка ПВХ 140х110см'),
#  Document(doc_id=340203868, name='Скатерть дорожка на стол, водоотталкивающая, хлопок 260 г/кв. м'),
#  Document(doc_id=360125828, name='Скатерть на стол Моготекс хлопок 120х150'),
#  Document(doc_id=373564411, name='Скатерть дорожка на стол, водоотталкивающая, хлопок 260 г/кв. м'),
#  Document(doc_id=373565511, name='Скатерть дорожка на стол, водоотталкивающая, хлопок 260 г/кв. м'),
#  Document(doc_id=384514443, name='Скатерть на стол клеёнка "Элегия" 110х135 см / скатерть праздничная ПВХ, водоотталкивающая'),
#  Document(doc_id=384825184, name='Скатерть на стол Моготекс хлопок 150х150'),
#  Document(doc_id=412146923, name='Скатерть на стол, водоотталкивающая, серая, хлопок 260 г/кв. м'),
#  Document(doc_id=426104545, name='Скатерть на стол, принт райская птичка, водоотталкивающая, хлопок 260 г/кв. м'),
#  Document(doc_id=458642633, name='Скатерть на стол Моготекс хлопок145х145'),
#  Document(doc_id=465232053, name='Скатерть на стол DOMOZON тканевая водоотталкивающая прямоугольная 145х220 см'),
#  Document(doc_id=465510986, name='Скатерть на стол DOMOZON тканевая водоотталкивающая прямоугольная 145х220 см'),
#  Document(doc_id=465579714, name='Скатерть на стол DOMOZON тканевая водоотталкивающая прямоугольная 110х145 см'),
#  Document(doc_id=469257962, name='Скатерть на стол Моготекс хлопок 145х145'),
#  Document(doc_id=505805613, name='Скатерть на стол DOMOZON тканевая водоотталкивающая круглая 145 см'),
#  Document(doc_id=509036974, name='Скатерть на стол Моготекс хлопок 200х145'),
#  Document(doc_id=515827134, name='Скатерть, Клеенка на стол Райхан 140x100см'),
#  Document(doc_id=518708978, name='Скатерть на стол овальная 160х220 см хлопок не боится пятен'),
#  Document(doc_id=536984218, name='Скатерть на стол 145х180 "Унисон" рис 30004-15 Basic бежевый'),
#  Document(doc_id=563958937, name='Гибкое стекло на стол 120х80 см, прозрачная силиконовая скатерть клеенка мягкая декоративная, в любой интерьер, в тубусе без заломов и складок, на кухню, в детскую, в беседку на дачу, в кабинет на работу, на подарок, прочная гипоаллергенная и экологичная'),
#  Document(doc_id=568911626, name='Скатерть, Клеенка на стол Райхан 140x100см'),
#  Document(doc_id=570085132, name='Скатерть на стол DOMOZON тканевая водоотталкивающая прямоугольная 145х220 см'),
#  Document(doc_id=579094641, name='Скатерть на стол круглая Fresca Design 185х185 см хлопок'),
#  Document(doc_id=588630680, name='Скатерть на стол DOMOZON тканевая водоотталкивающая прямоугольная 145х220 см'),
#  Document(doc_id=597725476, name='Гибкое стекло на стол скатерть силиконовая прозрачная 80х60 см, 60х80 см толщина 0,5 мм'),
#  Document(doc_id=597734204, name='Гибкое стекло на стол скатерть силиконовая прозрачная 110х70 см, 70х110 см, толщина 0,5 мм'),
#  Document(doc_id=603887937, name='Скатерть на стол 120х145 см холопок не линяет, не садится'),
#  Document(doc_id=604925476, name='Скатерть на стол 120х145 см холопок не линяет, не садится'),
#  Document(doc_id=650217417, name='Скатерть на стол 120х145 см холопок не линяет, не садится'),
#  Document(doc_id=653433796, name='Держатель для наушников/ универсальный крючок на стол/ вешалка для сумки/ фиксатор для скатерти/ Кронштейн'),
#  Document(doc_id=669654082, name='Скатерть на стол клеёнка "Элегия" 110х135 см / скатерть праздничная ПВХ, водоотталкивающая'),
#  Document(doc_id=728948990, name='Скатерть на стол 145х220 "Mia Cara" 30416 Новогодние сказки'),
#  Document(doc_id=759031938, name='Скатерть клеёнка на стол ПВХ "Муза" 132х180 см / скатерть на стол праздничная и на каждый день'),
#  Document(doc_id=818521189, name='Скатерть Royal Skaterty овальная силиконовая кружевная на стол'),
#  Document(doc_id=825823939, name='Скатерть на стол хлопок Worldacces 200х145 см (белоснежная)'),
#  Document(doc_id=1352532876, name='Скатерть на прямоугольный стол MAYA, 120x150 см, с кисточками, 80% хлопок'),
#  Document(doc_id=1352532971, name='Скатерть на прямоугольный стол MAYA,150х200 см, с кисточками, 80% хлопок'),
#  Document(doc_id=1352552613, name='Скатерть на прямоугольный стол LOLA 150x200 см, с вышивкой, 100% хлопок')]

# %%
search_with_and_condition(
    documents_index,
    documents_dict,
    symbols_to_replace,
    russian_stopwords,
    morph,
    "скатерть для стола",
    10,
)
# Out:
# [Document(doc_id=148827514, name='Скатерть на стол 145х180 см из хлопка водоотталкивающая, скатерть кухонная на стол с пропиткой для праздника кухни дома сада и дачи пятнозащитная кухонный декор в подарок, белая с розами прованс'),
#  Document(doc_id=148827515, name='Скатерть на стол Fresca Design 145х220 см'),
#  Document(doc_id=149750466, name='Скатерть круглая 185 см на стол из хлопка водоотталкивающая, скатерть на круглый стол кухонная с пропиткой от воды для праздника кухни дома сада и дачи пятнозащитная кухонный текстиль декор в подарок'),
#  Document(doc_id=151998971, name='Скатерть на стол UNTERZO home прямоугольная 145х180 см хлопок'),
#  Document(doc_id=155432339, name='Скатерть на стол круглая Fresca Design 185х185 см хлопок'),
#  Document(doc_id=155523748, name='Скатерть на стол овальная 160х220 см хлопок не боится пятен'),
#  Document(doc_id=155523854, name='Скатерть на стол Fresca Design 145х220 см'),
#  Document(doc_id=155523861, name='Скатерть на стол квадратная 145 см хлопок'),
#  Document(doc_id=155523863, name='Скатерть на стол UNTERZO home прямоугольная 145х180 см хлопок'),
#  Document(doc_id=155523867, name='Скатерть на стол UNTERZO home прямоугольная 145х180 см хлопок'),
#  Document(doc_id=166566934, name='Mia Cara Скатерть на стол 145х220 14056-1 Душистый пион'),
#  Document(doc_id=169022279, name='Скатерть клеенка на стол в кухню из ПВХ на нетканой основе размер 130х165 см'),
#  Document(doc_id=169022280, name='Скатерть клеенка на стол в кухню из ПВХ на нетканой основе размер 130х165 см'),
#  Document(doc_id=169854739, name='Скатерть на стол UNTERZO home прямоугольная 145х180 см хлопок'),
#  Document(doc_id=169987030, name='Скатерть на стол Fresca Design 145х220 см'),
#  Document(doc_id=178195687, name='Скатерть на стол круглая тканевая 145х145 см хлопок'),
#  Document(doc_id=178196021, name='Скатерть круглая 145 см на стол из хлопка водоотталкивающая, скатерть на обеденный круглый стол кухонная с пропиткой от воды для праздника кухни дома сада и дачи пятнозащитная, кухонный текстиль декор в подарок бежевая'),
#  Document(doc_id=178196031, name='Скатерть на стол круглая тканевая 145х145 см хлопок'),
#  Document(doc_id=178203245, name='Скатерть на стол круглая тканевая 145х145 см хлопок'),
#  Document(doc_id=183267913, name='Скатерть клеенка ПВХ на стол, REN277-13/1, размер 180х140см'),
#  Document(doc_id=183267923, name='Скатерть клеенка ПВХ на стол, REN277-12, размер 140х110см'),
#  Document(doc_id=185039888, name='Скатерть круглая на стол водоотталкивающая диаметр 145 см / Кухонная круглая скатерть  на стол до 4-х чел. / Праздничная скатерть / Идеальная скатерть для подарка / Цветочки'),
#  Document(doc_id=186076579, name='Скатерть на стол, клеенка новогодняя прозрачная с рисунком "Ажурная" ПВХ 132х160 см'),
#  Document(doc_id=186076595, name='Скатерть на стол, клеенка новогодняя прозрачная с рисунком "Ажурная" ПВХ 110х132 см'),
#  Document(doc_id=186630735, name='Скатерть овальная на стол водоотталкивающая 200*145 см / Кухонная скатерть на большой овальный стол на 6-10 чел / Скатерть в дом / Праздничная скатерть / Подходит для подарка / Скатерть для пикника / Соты бежевые'),
#  Document(doc_id=186630738, name='Кухонная скатерть на стол водоотталкивающая 200*145 см / Скатерть на большой прямоугольный стол на 6-10 чел / Скатерть в дом / Праздничная скатерть / Идеальная скатерть для подарка / Скатерть для пикника / Соты бежевые'),
#  Document(doc_id=194557710, name='Скатерть на прямоугольный стол, KDK, 160х220, кружевная, тканевая, праздничная, белая'),
#  Document(doc_id=194986545, name='Скатерть на овальный стол CARAMEL,160x220, тканевая, праздничная, белая'),
#  Document(doc_id=195195966, name='Скатерть на овальный стол, KDK, 160х220,кружевная, тканевая, праздничная, кремовая'),
#  Document(doc_id=195195970, name='Скатерть на овальный стол, KDK, 160х220,кружевная, тканевая, праздничная, кремовая'),
#  Document(doc_id=199415897, name='Кухонная скатерть на стол водоотталкивающая 200*145 см / Скатерть на большой прямоугольный стол на 6-10 чел / Скатерть в дом / Праздничная скатерть / Идеальная скатерть для подарка / Скатерть для пикника / Цветочки бежевые'),
#  Document(doc_id=199415961, name='Кухонная скатерть на стол водоотталкивающая 250*145 см / Скатерть на большой прямоугольный стол на 8-12 чел / Скатерть в дом / Праздничная скатерть / Идеальная скатерть для подарка / Скатерть для пикника / Цветочки бежевые'),
#  Document(doc_id=199657535, name='Скатерть на стол круглая водоотталкивающая диаметр 145 см / Кухонная круглая скатерть  на стол до 4-х чел. / Праздничная скатерть / Идеальная скатерть для подарка / Цветочки серые'),
#  Document(doc_id=199792224, name='Скатерть на стол 110*145 см прямоугольная водоотталкивающая'),
#  Document(doc_id=205048696, name='Скатерть овальная водоотталкивающая 200*145 см / Кухонная скатерть на стол до 10-ти чел / Овальная скатерть в дом / Праздничная скатерть / Идеальная скатерть для подарка / Клетка'),
#  Document(doc_id=210411588, name='Новогодняя дорожка на стол,тканевая,45х145,скатерть,хлопок,новый год,подарок'),
#  Document(doc_id=210411641, name='Новогодняя дорожка на стол,тканевая,45х145,скатерть,хлопок,новый год,подарок'),
#  Document(doc_id=215002145, name='Новогодняя дорожка на стол,тканевая,45х145,скатерть,хлопок, новый год,подарок'),
#  Document(doc_id=215002151, name='Новогодняя дорожка на стол,тканевая,50х145,скатерть,хлопок,новый год,подарок'),
#  Document(doc_id=223443962, name='Скатерть на стол, водоотталкивающая, хлопок 260 г/кв.м'),
#  Document(doc_id=223447577, name='Скатерть на стол, водоотталкивающая, хлопок 260 г/кв.м'),
#  Document(doc_id=223456642, name='Скатерть на стол, водоотталкивающая, хлопок 260 г/кв.м'),
#  Document(doc_id=226076236, name='Силиконовая скатерть Decosave Эконом на стол, толщина 0,8 мм. (мягкое стекло/защитная пленка/гибкое) прозрачная, 70*110 см'),
#  Document(doc_id=228991921, name='Силиконовая скатерть прозрачная на стол, клеенка овальная ПВХ 190х130 см'),
#  Document(doc_id=235154366, name='Скатерть на стол, серо-голубая, водоотталкивающая, хлопок 260 г/кв.м'),
#  Document(doc_id=251857072, name='Скатерть дорожка на стол, водоотталкивающая, хлопок 260 г/кв. м'),
#  Document(doc_id=282422511, name='Mia Cara Новогодняя Скатерть на стол 145х145 Альпийская сказка 30196-1'),
#  Document(doc_id=289246807, name='Круглая силиконовая скатерть 90см 1.8мм на стол, гибкое стекло круглое'),
#  Document(doc_id=291589179, name='Круглая силиконовая скатерть 100см 1.8мм на стол, гибкое стекло круглое'),
#  Document(doc_id=291594183, name='Круглая силиконовая скатерть 90см 1мм на стол, гибкое стекло круглое'),
#  Document(doc_id=294300603, name='Скатерть кружевная 137х180 см, непромокаемая ажурная клеенка на стол'),
#  Document(doc_id=317131604, name='Скатерть на стол Круглая Новогодняя 220x220 Этель Сhristmas bells Влагоотталкивающая'),
#  Document(doc_id=317133671, name='Скатерть на стол Новогодняя 150x220 Этель Forest animals Влагооталкивающая'),
#  Document(doc_id=323126331, name='Скатерть на стол тканевая, водоотталкивающая, хлопок 260 г/кв.м'),
#  Document(doc_id=336568892, name='Скатерть на стол Ren629-6 клеенка ПВХ 140х110см'),
#  Document(doc_id=337528788, name='Скатерть на стол Ren393-6-7 клеенка ПВХ 140х110см'),
#  Document(doc_id=340203868, name='Скатерть дорожка на стол, водоотталкивающая, хлопок 260 г/кв. м'),
#  Document(doc_id=360125828, name='Скатерть на стол Моготекс хлопок 120х150'),
#  Document(doc_id=373564411, name='Скатерть дорожка на стол, водоотталкивающая, хлопок 260 г/кв. м'),
#  Document(doc_id=373565511, name='Скатерть дорожка на стол, водоотталкивающая, хлопок 260 г/кв. м'),
#  Document(doc_id=384514443, name='Скатерть на стол клеёнка "Элегия" 110х135 см / скатерть праздничная ПВХ, водоотталкивающая'),
#  Document(doc_id=384825184, name='Скатерть на стол Моготекс хлопок 150х150'),
#  Document(doc_id=412146923, name='Скатерть на стол, водоотталкивающая, серая, хлопок 260 г/кв. м'),
#  Document(doc_id=426104545, name='Скатерть на стол, принт райская птичка, водоотталкивающая, хлопок 260 г/кв. м'),
#  Document(doc_id=458642633, name='Скатерть на стол Моготекс хлопок145х145'),
#  Document(doc_id=465232053, name='Скатерть на стол DOMOZON тканевая водоотталкивающая прямоугольная 145х220 см'),
#  Document(doc_id=465510986, name='Скатерть на стол DOMOZON тканевая водоотталкивающая прямоугольная 145х220 см'),
#  Document(doc_id=465579714, name='Скатерть на стол DOMOZON тканевая водоотталкивающая прямоугольная 110х145 см'),
#  Document(doc_id=469257962, name='Скатерть на стол Моготекс хлопок 145х145'),
#  Document(doc_id=505805613, name='Скатерть на стол DOMOZON тканевая водоотталкивающая круглая 145 см'),
#  Document(doc_id=509036974, name='Скатерть на стол Моготекс хлопок 200х145'),
#  Document(doc_id=515827134, name='Скатерть, Клеенка на стол Райхан 140x100см'),
#  Document(doc_id=518708978, name='Скатерть на стол овальная 160х220 см хлопок не боится пятен'),
#  Document(doc_id=536984218, name='Скатерть на стол 145х180 "Унисон" рис 30004-15 Basic бежевый'),
#  Document(doc_id=563958937, name='Гибкое стекло на стол 120х80 см, прозрачная силиконовая скатерть клеенка мягкая декоративная, в любой интерьер, в тубусе без заломов и складок, на кухню, в детскую, в беседку на дачу, в кабинет на работу, на подарок, прочная гипоаллергенная и экологичная'),
#  Document(doc_id=568911626, name='Скатерть, Клеенка на стол Райхан 140x100см'),
#  Document(doc_id=570085132, name='Скатерть на стол DOMOZON тканевая водоотталкивающая прямоугольная 145х220 см'),
#  Document(doc_id=579094641, name='Скатерть на стол круглая Fresca Design 185х185 см хлопок'),
#  Document(doc_id=588630680, name='Скатерть на стол DOMOZON тканевая водоотталкивающая прямоугольная 145х220 см'),
#  Document(doc_id=597725476, name='Гибкое стекло на стол скатерть силиконовая прозрачная 80х60 см, 60х80 см толщина 0,5 мм'),
#  Document(doc_id=597734204, name='Гибкое стекло на стол скатерть силиконовая прозрачная 110х70 см, 70х110 см, толщина 0,5 мм'),
#  Document(doc_id=603887937, name='Скатерть на стол 120х145 см холопок не линяет, не садится'),
#  Document(doc_id=604925476, name='Скатерть на стол 120х145 см холопок не линяет, не садится'),
#  Document(doc_id=650217417, name='Скатерть на стол 120х145 см холопок не линяет, не садится'),
#  Document(doc_id=653433796, name='Держатель для наушников/ универсальный крючок на стол/ вешалка для сумки/ фиксатор для скатерти/ Кронштейн'),
#  Document(doc_id=669654082, name='Скатерть на стол клеёнка "Элегия" 110х135 см / скатерть праздничная ПВХ, водоотталкивающая'),
#  Document(doc_id=728948990, name='Скатерть на стол 145х220 "Mia Cara" 30416 Новогодние сказки'),
#  Document(doc_id=759031938, name='Скатерть клеёнка на стол ПВХ "Муза" 132х180 см / скатерть на стол праздничная и на каждый день'),
#  Document(doc_id=818521189, name='Скатерть Royal Skaterty овальная силиконовая кружевная на стол'),
#  Document(doc_id=825823939, name='Скатерть на стол хлопок Worldacces 200х145 см (белоснежная)'),
#  Document(doc_id=1352532876, name='Скатерть на прямоугольный стол MAYA, 120x150 см, с кисточками, 80% хлопок'),
#  Document(doc_id=1352532971, name='Скатерть на прямоугольный стол MAYA,150х200 см, с кисточками, 80% хлопок'),
#  Document(doc_id=1352552613, name='Скатерть на прямоугольный стол LOLA 150x200 см, с вышивкой, 100% хлопок')]

# %%
calculate_validation_metrics(
    partial(
        search_with_and_condition,
        documents_index,
        documents_dict,
        symbols_to_replace,
        russian_stopwords,
        morph,
    ),
    limit=20
)
# Out:
# precision = 0.09579784216969496
# recall = 0.2862654838254138
# f1_score = 0.0971321719689694

# %% [markdown]
# ### Максимизируем полноту

# %% [markdown]
# #### Реализуем функцию, которая получает для каждого токена запроса список документов и реализует слияние списков через оператор OR

# %%
def merge_or(posting_lists: list[list[int]]):
    result = set()
    for lst in posting_lists:
        result.update(lst)

    return result

# %%
def search_with_or_condition(
    index: dict[str, list[int]], 
    documents_dict: dict[int, str],
    symbols_to_replace: dict[str, str],
    russian_stopwords: set[str],
    lemmatizer: MorphAnalyzer, 
    query: str, 
    limit: Optional[int] = None,
) -> list[str]:
    
    # 1. Обработка запроса
    # 2. Получение posting lists для каждого токена
    # 3. Слияние posting lists
    
    query_processed = process_document(query, symbols_to_replace, russian_stopwords, lemmatizer)

    merged_posting_lists = merge_or([index.get(token, []) for token in query_processed])

    return [
        Document(doc_id=doc_id, name=documents_dict[doc_id]) for doc_id in merged_posting_lists
    ]

# %%
search_with_or_condition(
    documents_index,
    documents_dict,
    symbols_to_replace,
    russian_stopwords,
    morph,
    "молоко ультрапастеризованное",
    10,
)
# Out:
# [Document(doc_id=1442791428, name='Parmalat Молоко Ультрапастеризованное 3.5% 1000мл. 12шт. Уцененный товар'),
#  Document(doc_id=1558601740, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=148054037, name='Zeitun Скраб для тела с маслами, питательный, сахарный "Шоколад и молоко" 250 мл'),
#  Document(doc_id=1593598002, name='Молочная смесь Nestle NAN с рождения до 12 месяцев, на козьем молоке, 400 г. Уцененный товар'),
#  Document(doc_id=175415348, name='Молоко цельное сгущенное с сахаром, Рогачевъ, ГОСТ, 8,5 %, дой-пак, 270 гр., 3 штуки'),
#  Document(doc_id=1525588024, name='Молоко Стерилизованное Село Зеленое 2,5 % 0,95 л х 12 шт. Уцененный товар'),
#  Document(doc_id=472080455, name='Сок с молоком Мажитэль Папайя-Манго-Ананас 0,05%, 950 г'),
#  Document(doc_id=231555166, name='Молочко детское Kabrita Gold 4, с 18 месяцев, на козьем молоке для комфортного пищеварения, 800 г'),
#  Document(doc_id=1439965285, name='Parmalat Молоко Ультрапастеризованное 3.5% 1000мл. 12шт. Уцененный товар'),
#  Document(doc_id=1615880294, name='Молоко ультрапастеризованное Просто Молоко, 3,2 %, 1 л'),
#  Document(doc_id=1615880309, name='Молоко ультрапастеризованное Я ем с умом, низколактозное, 1,5 %, 1 л'),
#  Document(doc_id=302121080, name='Торт "Черничное молоко" 750 г, Mirel'),
#  Document(doc_id=1514905725, name='Вспениватель молока Kitfort КТ-758, серый металлик. Уцененный товар'),
#  Document(doc_id=1419042942, name='Мороженое Птичье молоко с шоколадным топпингом 450 г, Вкусландия'),
#  Document(doc_id=321880201, name='Молоко пастеризованное Кубанская буренка 2.5% 930мл'),
#  Document(doc_id=321880202, name='Молоко пастеризованное Кубанская буренка Отборное 930мл'),
#  Document(doc_id=321880203, name='Молоко пастеризованное Кубанская буренка Отборное 1,4л'),
#  Document(doc_id=321880204, name='Молоко пастеризованное Кубанская буренка 2.5% 1,4л'),
#  Document(doc_id=156418189, name='Молоко ультрапастеризованное 3,5%, 12 шт х 1 л, Parmalat'),
#  Document(doc_id=156418190, name='Молоко ультрапастеризованное 1,8% 12 шт х 1 л, Parmalat'),
#  Document(doc_id=321880207, name='Кубанская Буренка Молоко Ультрапастеризованное 3.5% 950мл. 1шт.'),
#  Document(doc_id=156418192, name='Молоко ультрапастеризованное 3,5%, 1 л, Parmalat'),
#  Document(doc_id=156418193, name='Молоко Белый Город ультрапастеризованное 3,2%, 1 л'),
#  Document(doc_id=156418195, name='Молоко ультрапастеризованное 1,8% 1 л, Parmalat'),
#  Document(doc_id=167297178, name='Шоколад Ritter Sport "Альпийское молоко" с альпийским молоком, 100 г'),
#  Document(doc_id=173023395, name='KUNDER Бутылочка для кормления новорожденных от 3 месяцев 240мл. силиконовая антиколиковая ортодонтическая детская с соской антивакуумным клапаном для молока воды смеси, непроливайка для малышей'),
#  Document(doc_id=162259117, name='Капучинатор, вспениватель молока, электрический, MELL, цвет черный'),
#  Document(doc_id=916701361, name='Мороженое молочное с кокосовым молоком ведёрко, 272 г, Bounty'),
#  Document(doc_id=765886652, name='Молоко пастеризованное Parmalat отборное, 900 мл ПЭТ'),
#  Document(doc_id=765886655, name='Молоко пастеризованное Безлактозное 1,8% Parmalat Comfort, 900 мл ПЭТ'),
#  Document(doc_id=765886656, name='Молоко пастеризованное Безлактозное 3,5% Parmalat Comfort, 900 мл ПЭТ'),
#  Document(doc_id=1145651403, name='Капучинатор электрический SIMPLE KITCHEN, вспениватель молока, Серия - Премиум (SK_MF1)'),
#  Document(doc_id=1533657294, name='Молоко Parmalat Comfort, безлактозное, 1,8%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1566851288, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=749895900, name='Вафельная трубочка молочный крем с молоком сгущённым с сахаром, 65 г, ЗГДиОП им.В.П.Пастухова'),
#  Document(doc_id=1527234785, name='Молоко Агуша обогащенное витаминами и йодом 2.5% 200мл с 8 месяцев X18. Уцененный товар'),
#  Document(doc_id=1599848678, name='Молоко Parmalat Comfort, безлактозное, 1,8%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1626824934, name='Каша рисовая с вишней на кокосовом молоке 250 г, без сахара и глютена Азбука Вкуса'),
#  Document(doc_id=1465450737, name='Село Зеленое Молоко Ультрапастеризованное 3.2% 950мл. 12шт. Уцененный товар'),
#  Document(doc_id=577069307, name='Ряженка Домик в деревне Для тебя Топленое молоко 2.5% 270г'),
#  Document(doc_id=1504485629, name='Молоко 2,5%, 930 мл, Экомилк'),
#  Document(doc_id=1670938889, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=259531020, name='Вафли Рот Фронт Коровка топленое молоко, 300 г'),
#  Document(doc_id=160055577, name='Молочная смесь Kabrita Gold 1, с рождения, на козьем молоке для комфортного пищеварения, 400 г'),
#  Document(doc_id=160055580, name='Молочная смесь Kabrita Gold 2, с 6 месяцев, на козьем молоке для комфортного пищеварения, 400 г'),
#  Document(doc_id=160055582, name='Молочная смесь Kabrita Gold 1, с рождения, на козьем молоке для комфортного пищеварения, 800 г'),
#  Document(doc_id=160055584, name='Молочная смесь Kabrita Gold 2, с 6 месяцев, на козьем молоке для комфортного пищеварения, 800 г'),
#  Document(doc_id=160055585, name='Молочко детское Kabrita Gold 3, с 12 месяцев, на козьем молоке для комфортного пищеварения, 800 г'),
#  Document(doc_id=589947169, name='Молоко сгущенное Главпродукт ГОСТ, дой пак дозатор, 270 г'),
#  Document(doc_id=1674682660, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1543569704, name='Молоко пастеризованное 2,5% 900 г, Новая Деревня'),
#  Document(doc_id=1543569708, name='Молоко пастеризованное 3,2% 900 г, Новая Деревня'),
#  Document(doc_id=943235402, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт'),
#  Document(doc_id=172605781, name='Домик в Деревне Молоко Ультрапастеризованное 3.2% 950мл. 12шт.'),
#  Document(doc_id=630604122, name='Вспениватель молока Oursson MF3500D/IV, 3 режима работы, подогрев молока, антипригарное внутреннее покрытие'),
#  Document(doc_id=1615880546, name='Молоко ультрапастеризованное Просто Молоко, 2,5 %, 1 л'),
#  Document(doc_id=1615880547, name='Молоко ультрапастеризованное Агросила, Халяль, 3,2%, 1 л'),
#  Document(doc_id=1159577966, name='Капучинатор и вспениватель молока электрический для капучино Oberhof Milchschumer IX-17 / вспениватель молочной пенки, 3 скорости, емкость батареи 1200 мАч'),
#  Document(doc_id=564773232, name='EVELINE Крем для лица КОЗЬЕ МОЛОКО омолаживающий, дневной, 75 мл'),
#  Document(doc_id=589947269, name='Молоко сгущенное Главпродукт ГОСТ, ж.б., 380 г'),
#  Document(doc_id=173392263, name='Растительное молоко овсяное Take a Bite, без сахара, безлактозное, 6 шт по 1 л'),
#  Document(doc_id=1575354761, name='Хлопья Быстров овсяные с малиной и молоком, не требующие варки, 240 г'),
#  Document(doc_id=1627939217, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=138133907, name='Sen Soy Кокосовое молоко 5-7%, 400 мл'),
#  Document(doc_id=605053331, name='Творожный продукт из козьего молока "Творожный крем" с черникой, 11%-18%, LavkaLavka, 150 г'),
#  Document(doc_id=1574224279, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=765198754, name='Молоко ультрапастеризованное 3,2%  950 мл, Фрау Му'),
#  Document(doc_id=1576485283, name='Молоко Агрокомплекс питьевое пастеризованное, 1%, 900 мл'),
#  Document(doc_id=1597153707, name='Сливки ультрапастеризованные 10%, 125 мл, Вкуснотеево'),
#  Document(doc_id=174416300, name='Молоко Viola UHT, 3,2%, 1 л х 12 шт'),
#  Document(doc_id=1617019308, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1597153708, name='Сливки ультрапастеризованные 20%, 125 мл, Вкуснотеево'),
#  Document(doc_id=600850869, name='Сырок творожный глазированный в молочном шоколаде с молоком сгущенным вареным 26% 50 г, А.РОСТАГРОКОМПЛЕКС'),
#  Document(doc_id=1575780815, name='Молоко Parmalat Comfort, безлактозное, 1,8%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=641991132, name='Шоколад Карамельный натуральный полезный  веган веганский без сахара без глютена без сои без молока 50 гр'),
#  Document(doc_id=1576288733, name='Молоко Стерилизованное Село Зеленое 2,5 % 0,95 л х 12 шт. Уцененный товар'),
#  Document(doc_id=141165025, name='Молоко ультрапастеризованное Простоквашино, 3,2%, 950 мл'),
#  Document(doc_id=180437474, name='Молоко Parmalat Comfort 1,8%, безлактозное, 200 мл х 24 шт'),
#  Document(doc_id=141165031, name='Молоко детское Тема 3,2%, 200 мл'),
#  Document(doc_id=141165033, name='Молоко Тема детское 3,2% с 3 лет, 500мл'),
#  Document(doc_id=1145651693, name='Капучинатор с подставкой SIMPLE KITCHEN, электрический вспениватель молока и взбиватель яиц, ручной мощный электровенчик (SK_MF1)'),
#  Document(doc_id=384532974, name='"Питьевой йогурт" на кокосовом "молоке" Sooperfoods, клубника-банан, 300 мл'),
#  Document(doc_id=1511956975, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=141165038, name='Сливки Петмол, ультрапастеризованные, 11%, 500 мл'),
#  Document(doc_id=170222065, name='Торт Птичье молоко Советская классика 600 г, Черемушки'),
#  Document(doc_id=170222066, name='Торт "Птичье молоко", с халвой 600 г, Черемушки'),
#  Document(doc_id=1440080370, name='Сыр твердый по-итальянски Гаудита Ешь Деревенское, 45%, из коровьего молока, 210 г'),
#  Document(doc_id=1440080372, name='Сыр полутвердый Хавартио по-итальянски Ешь Деревенское, 55%, из коровьего молока, 210 г'),
#  Document(doc_id=141165041, name='Сливки Петмол, ультрапастеризованные, 22%, 1 л'),
#  Document(doc_id=355402233, name='Село Зеленое Молоко Ультрапастеризованное 0.032% 950мл.'),
#  Document(doc_id=1551041038, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1480606225, name='Parmalat Молоко Ультрапастеризованное 1.8% 1000мл. 12шт. Уцененный товар'),
#  Document(doc_id=357245459, name='Капучинатор и вспениватель для молока и кофе ( электрический, ручной, беспроводной мини миксер )'),
#  Document(doc_id=1511957022, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1613578786, name='Молочная смесь Nestle NAN 3 с 1 года, на основе козьего молока, 400 г. Уцененный товар'),
#  Document(doc_id=1612554787, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1612554788, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1612554790, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1575117352, name='Каша быстрого приготовления Увелка овсяная Ассорти с ягодами и молоком, 6 пакетиков по 40 г, 240 г. Уцененный товар'),
#  Document(doc_id=1145651761, name='Капучинатор с подставкой SIMPLE KITCHEN, электрический вспениватель молока и взбиватель яиц, ручной мощный электровенчик (SK_MF1)'),
#  Document(doc_id=1529160264, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=724894287, name='Кокосовая сгущенка без сахара с лавандой ORGANIC LAB пп сладости, сгущенное молоко из кокосового урбеча, 220 гр.'),
#  Document(doc_id=1479058023, name='Растительное молоко кокосовое, 2,0% 1 л, Zinus Barista'),
#  Document(doc_id=1641808489, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1479058028, name='Растительное молоко миндальное 2,0% 1 л Zinus Barista'),
#  Document(doc_id=1479058030, name='Растительное молоко банановое 2,0%, 1 л, Zinus Barista, на кокосовом молоке'),
#  Document(doc_id=1479058032, name='Растительное молоко кокосовое 1,8% 1 л Zinus'),
#  Document(doc_id=1655014006, name='Каша быстрого приготовления Ясно солнышко овсяная с клубникой и молоком, 45 г х 15 шт. Уцененный товар'),
#  Document(doc_id=1465451154, name='Село Зеленое Молоко Ультрапастеризованное 3.2% 950мл. 12шт. Уцененный товар'),
#  Document(doc_id=1617167003, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1479058081, name='Растительное молоко миндальное 1,8% 1 л Zinus'),
#  Document(doc_id=1640587938, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1161839268, name='Молоко сгущенное Коровка из Кореновки с сахаром и какао, 5,0%, 270 г'),
#  Document(doc_id=794935979, name='Вафельный рожок Здоровый Рожок сливочный со сгущеным молоком 120 г, Коровка из Кореновки'),
#  Document(doc_id=1640587956, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1575355072, name='Хлопья Быстров овсяные с клубникой и молоком, не требующие варки, 240 г'),
#  Document(doc_id=239026893, name='Кокосовое молоко FOCO без добавок, жирность 10-12%, 400 мл х 2 шт'),
#  Document(doc_id=1615479506, name='Каша быстрого приготовления Ясно солнышко овсяная с клубникой и молоком, 45 г х 15 шт. Уцененный товар'),
#  Document(doc_id=284189403, name='Молоко верблюжье в капсулах 60 шт гипоаллергенное БАД для укрепления иммунитета, антиоксидант халяль'),
#  Document(doc_id=1404633830, name='Молоко Село Зеленое ультрапастеризованное 2,5%, 12 шт х 0,95 л'),
#  Document(doc_id=1417503471, name='Молоко ультрапастеризованное Славянские Кружева 3,2% 973 мл '),
#  Document(doc_id=1417503473, name='Молоко ультрапастеризованное Славянские Кружева 2,5% 973 мл '),
#  Document(doc_id=1417503475, name='Молоко ультрапастеризованное Славянские Кружева 1,5 % 973 мл '),
#  Document(doc_id=637862648, name='Молокоотсос электрический / двойной, для сцеживания молока, 9 режимов'),
#  Document(doc_id=589079289, name='Молоко 3,4%-6,0% 720 г, Кубанский Молочник'),
#  Document(doc_id=1465197308, name='ЭкоНива Молоко Стерилизованное 3.2% 1000мл. 12шт. Уцененный товар'),
#  Document(doc_id=1062699773, name='Молоко 3,2%, 1400 мл, Простоквашино, пастеризованное'),
#  Document(doc_id=145589002, name='Сливки ультрапастеризованные 33% 500 мл, Петмол,'),
#  Document(doc_id=145589003, name='Сливки ультрапастеризованные 33% 1 л, Петмол'),
#  Document(doc_id=1451295515, name='Каша быстрого приготовления Увелка овсяная Ассорти с ягодами и молоком, 6 пакетиков по 40 г, 240 г. Уцененный товар'),
#  Document(doc_id=740360989, name=' Сухое молоко 300г. 1шт.'),
#  Document(doc_id=357589791, name='Капучинатор iSottcom для молока и сливок, латте ручной электрический , подарочный набор 4 в 1: мини-миксер с подставкой, питчер, трафарет для кофе'),
#  Document(doc_id=987087662, name='Молоко цельное 3,2-4,0%, 950 мл, Калининское, пастеризованное'),
#  Document(doc_id=987087665, name='Молоко 2,5%, 950 мл, Калининское, пастеризованное'),
#  Document(doc_id=1545839409, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=987087681, name='Молоко 3,2%, 930 мл, Калининское, пастеризованное'),
#  Document(doc_id=536879962, name='Протеиновое печенье без сахара "Butter Wave" Топленое молоко (коробка из 8 упаковок по 4 штуки), 288 гр'),
#  Document(doc_id=170074971, name='Молоко цельное отборное 3,4 - 4,5%, 900 мл, Экомилк, пастеризованное'),
#  Document(doc_id=170074972, name='Молоко 3,2%, 930 мл, Экомилк, пастеризованное'),
#  Document(doc_id=684991324, name='Капучинатор мини миксер для взбивания ручной вспениватель молока сливок венчик кухонный взбиватель'),
#  Document(doc_id=1581835108, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=247317352, name='Шоколад молочный на овсяном молоке Без сахара Набор 2 шт. Без лактозы Веган продукт ручной работы / GreenMania веганский, без лактозы, постный, натуральный'),
#  Document(doc_id=285033322, name='AVON / Четырехцветные тени для век "Безупречный цвет", Мокко с молоком/Mocha Latte'),
#  Document(doc_id=1609917305, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1461502847, name='Село Зеленое Молоко Ультрапастеризованное 3.2% 950мл. 12шт. Уцененный товар'),
#  Document(doc_id=465388420, name='Сыр Качотта с пажитником из козьего молока Фермерская сыроварня Осташево, 150 г'),
#  Document(doc_id=172622743, name='Молоко Белый Город, стерилизованное, 3,2%, 1 л х 16 шт'),
#  Document(doc_id=1567269783, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=178324381, name='Молоко Parmalat UHT Comfort, безлактозное, 0,05%, 1 л х 12 шт'),
#  Document(doc_id=178324382, name='Молоко Parmalat UHT Comfort, безлактозное, 3,5%, 1 л х 12 шт'),
#  Document(doc_id=1560814503, name='Молоко Parmalat Comfort, безлактозное, 1,8%, 1 л. Уцененный товар'),
#  Document(doc_id=301007786, name='Хорошее дело Молоко Стерилизованное 2.5% 950мл. 1шт.'),
#  Document(doc_id=1560814506, name='Молоко Parmalat Comfort, безлактозное, 1,8%, 1 л. Уцененный товар'),
#  Document(doc_id=1430225836, name='Сырники с вареным сгущенным молоком Creative Kitchen,120 г'),
#  Document(doc_id=1616233399, name='Молоко Агуша обогащенное витаминами и йодом 2.5% 200мл с 8 месяцев X18. Уцененный товар'),
#  Document(doc_id=1640465341, name='Молоко Parmalat Comfort, безлактозное, 1,8%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=315270083, name='KAPOUS Studio Professional Шампунь для всех типов волос Молоко и мед 1000 мл Aromatic Symphony'),
#  Document(doc_id=231293892, name='Aroy-d Кокосовое молоко 70% жирность 17-19%, 500 мл x 2 шт'),
#  Document(doc_id=256287695, name='Десерт чиа с манго на кокосовом молоке Азбука вкуса, 180 г'),
#  Document(doc_id=301007843, name='Хорошее дело Молоко Стерилизованное 3.2% 950мл. 1шт.'),
#  Document(doc_id=141927409, name='Вспениватель молока Kitfort КТ-709, White'),
#  Document(doc_id=298386422, name='Натуральный жидкий сычужный фермент для приготовления сыра 20 мл на 100 л молока'),
#  Document(doc_id=1581556729, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=170075133, name='Молоко Экомилк, пастеризованное, 3,2%, 1,5 л'),
#  Document(doc_id=384893949, name='"Греческий йогурт" на кокосовом "молоке" Sooperfoods натуральный, 160 г'),
#  Document(doc_id=414786561, name='Конфеты шоколадные Рот Фронт Птичье молоко, сливочно-ванильные, 200 г'),
#  Document(doc_id=1329079332, name='Сгущенное молоко цельное с сахаром 8,5% 250 мл, Ozon fresh, ГОСТ'),
#  Document(doc_id=562398250, name='Растительное молоко ореховое миндальное Zinus 1л'),
#  Document(doc_id=943268942, name='Молоко сгущенное Белый Медведь цельное с сахаром  8,5% дой-пак, 270 г'),
#  Document(doc_id=1567982677, name='Молочная смесь Бибиколь Нэнни козье молоко 3, с 12 месяцев, 800 г. Уцененный товар'),
#  Document(doc_id=1406985311, name='Каша на козьем молоке детская Fleur Alpine Рисовая, с 4 месяцев, 200 г. Уцененный товар'),
#  Document(doc_id=144311416, name='Большая Кружка Молоко Ультрапастеризованное 2.5%'),
#  Document(doc_id=144311417, name='Большая Кружка Молоко Ультрапастеризованное 3.2% 980мл.'),
#  Document(doc_id=244515961, name='Кокосовое молоко AROY-D жирность 19%, 250 мл, tetra pak, 6 шт'),
#  Document(doc_id=144311421, name='Большая Кружка Молоко Ультрапастеризованное 2.5%'),
#  Document(doc_id=144311422, name='Большая Кружка Молоко Ультрапастеризованное 3.2%'),
#  Document(doc_id=1583858814, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1668793469, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=615605380, name='Батончик полезный натуральный веганский без рафинированного сахара глютена без сои без молока на кешью ореховая нуга шоколад "Карамельный" bob, 49 г'),
#  Document(doc_id=310469772, name='Десерт без сахара Сгущёнка Иван-поле, пп сгущеное молоко 200г'),
#  Document(doc_id=1661338779, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=158024880, name='Белый Город Молоко Стерилизованное 1.5% 1000мл. 1шт.'),
#  Document(doc_id=158024882, name='Сливки ультрапастеризованные 23%, 0,5 л, Parmalat'),
#  Document(doc_id=195331251, name='Торт "Птичье молоко", с халвой 600 г, Черемушки'),
#  Document(doc_id=1492976818, name='Село Зеленое Молоко Ультрапастеризованное 3.2% 950мл. 12шт. Уцененный товар'),
#  Document(doc_id=1496958130, name='ЭкоНива Молоко Стерилизованное 2.5% 1000мл. 12шт. Уцененный товар'),
#  Document(doc_id=1452975286, name='Каша быстрого приготовления Увелка овсяная Ассорти с ягодами и молоком, 6 пакетиков по 40 г, 240 г. Уцененный товар'),
#  Document(doc_id=1586382006, name='Молочная смесь Nestle NAN с рождения до 12 месяцев, на козьем молоке, 400 г. Уцененный товар'),
#  Document(doc_id=1587586228, name='Молоко ФрутоНяня ультрапастеризованное (м.д.ж. 2,5%), 0.2 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1492976826, name='Село Зеленое Молоко Ультрапастеризованное 3.2% 950мл. 12шт. Уцененный товар'),
#  Document(doc_id=863798467, name='Сыр Бюш мягкий с ананасом и миндалем 50%, 140 г, Егорлык Молоко'),
#  Document(doc_id=195331272, name='Молоко топленое 3,2%, 930 мл, Простоквашино'),
#  Document(doc_id=863798472, name='Сыр Бюш мягкий с папайя и фундуком 50%, 140 г, Егорлык Молоко'),
#  Document(doc_id=195331282, name='Сыр Ko & Co Бюш Де Шевр, мягкий, из козьего молока, с плесенью, в золе, 85 г'),
#  Document(doc_id=1575355603, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1486300379, name='ЭкоНива Молоко Стерилизованное 3.2% 1000мл. 12шт. Уцененный товар'),
#  Document(doc_id=264398053, name='Шоколад Аленка много молока, 90 г'),
#  Document(doc_id=1631438060, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=265143538, name='Сухое молоко цельное 26% жирности 1000г, 1 кг'),
#  Document(doc_id=1032594689, name='Молочная смесь Бибиколь Нэнни с пребиотиками 2, с 6 месяцев, на основе козьего молока, 800 г'),
#  Document(doc_id=1549575429, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=195331359, name='Сыр Ko & Co Бюш Де Шевр, мягкий, из козьего молока, с белой плесенью, в золе Валансе, 150 г'),
#  Document(doc_id=168666402, name='Молоко безлактозное 1,8% 1 л, Parmalat Comfort'),
#  Document(doc_id=1674863908, name='Молоко Агуша обогащенное витаминами и йодом 2.5% 200мл с 8 месяцев X18. Уцененный товар'),
#  Document(doc_id=1556792613, name='Капучинатор для молока Hyundai HMF-P300 кремовый 300мл. Уцененный товар'),
#  Document(doc_id=1632904500, name='Напиток из растительного сырья  овсяный 1 л, Здоровое меню, обогащенный Ca и витаминами, ультрапастеризованный'),
#  Document(doc_id=181167420, name='Молоко ФрутоНяня, обогащенное, 2,5%, с 8 месяцев, 12 шт по 200 мл'),
#  Document(doc_id=1485669692, name='ЭкоНива Молоко Стерилизованное 3.2% 1000мл. 12шт. Уцененный товар'),
#  Document(doc_id=618808640, name='Молоко козье Lactica цельное 2,8-4,0%, 200 мл'),
#  Document(doc_id=1618765125, name='Молоко ультрапастеризованное 1,8% Parmalat, 12 шт х 1 л. Уцененный товар'),
#  Document(doc_id=1430259029, name='Parmalat Молоко Ультрапастеризованное 1.8% 1000мл. 12шт. Уцененный товар'),
#  Document(doc_id=296396134, name='Сироп без сахара Сгущёное молоко "Ноль грамм", 330г (низкокалорийный топинг для мороженного, выпечки или коктейлей)'),
#  Document(doc_id=1639941483, name='Молоко ультрапастеризованное 1,8% Parmalat, 12 шт х 1 л. Уцененный товар'),
#  Document(doc_id=662152564, name='Набор кофе в капсулах Tassimo Кофе с молоком, 5 упаковок'),
#  Document(doc_id=1555760500, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1411761534, name='Молоко ультрапастеризованное 3,2% 1 л, Милушка'),
#  Document(doc_id=1442276737, name='Сыр сливочный со вкусом топлёного молока, 45 - 50 %, 0,9 - 1,3 кг, Ozon fresh'),
#  Document(doc_id=1408492935, name='Каша рисовая "Волконский" на кокосовом молоке с ганашем из белого шоколада и маракуйи 250 г'),
#  Document(doc_id=1442276745, name='Сыр сливочный со вкусом топлёного молока, 45 - 50 %, 0,9 - 1,05 кг, Ozon fresh'),
#  Document(doc_id=1442276752, name='Сыр сливочный со вкусом топлёного молока, 45 - 50 %, 1,05 - 1,2 кг, Ozon fresh'),
#  Document(doc_id=157943187, name='Valio Молоко Ультрапастеризованное 3.5% 1000мл. 1шт.'),
#  Document(doc_id=210158999, name='Капучинатор для молока ручной FACKELMANN Barista 20 см электрический вспениватель, мини миксер для кофе, венчик, взбиватель беспроводной для капучино, латте, матча'),
#  Document(doc_id=242681244, name='Растительное молоко 150 мл, Kati, кокосовые сливки'),
#  Document(doc_id=612689331, name='Капучинатор Kitfort КТ-786-1, лавандовый, вспениватель молока, 500 Вт, чаша 240 мл, антипригарное покрытие, 4 режима работы, 2 насадки для вспенивания и смешивания'),
#  Document(doc_id=1180771764, name='Крем-десерт с молоком сгущенным вареным 25% 40 г, сливочный Коровка из Кореновки глазированный в вафельном рожке'),
#  Document(doc_id=142624198, name='Пюре овощное Бабушкино лукошко с 6 месяцев, кабачок молоко, 100 г x 6'),
#  Document(doc_id=411796973, name='Молоко топленное 2,5%, 800 мл, МСК-Волжский'),
#  Document(doc_id=154330611, name='Сливки пастеризованные 10%, 250 г, Рузское молоко'),
#  Document(doc_id=411796980, name='Молоко 3,2%, 900 мл, МСК-Волжский, пастеризованное'),
#  Document(doc_id=154330613, name='Сметана 15% 175 г, Рузское молоко'),
#  Document(doc_id=154330614, name='Сметана 20% 175 г, Рузское молоко'),
#  Document(doc_id=154330615, name='Сметана 25%, 175 г, Рузское молоко'),
#  Document(doc_id=229729782, name='"Растительный напиток Valsoia соевый ""Бариста"" ультрапастеризованный с кальцием и витаминами, 1 л"'),
#  Document(doc_id=1411761674, name='Молоко ультрапастеризованное 2,5% 1 л, Милушка'),
#  Document(doc_id=1512179223, name='Молоко Агуша обогащенное витаминами и йодом 2.5% 200мл с 8 месяцев X18. Уцененный товар'),
#  Document(doc_id=1615341081, name='Рисовая каша на кокосовом молоке 220 г, Creative Kitchen'),
#  Document(doc_id=1659569699, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1567983142, name='Молочная смесь Бибиколь Нэнни козье молоко 3, с 12 месяцев, 800 г. Уцененный товар'),
#  Document(doc_id=171820606, name='ErickHauser, Капучинатор, вспениватель молока, мини миксер, взбиватель молока'),
#  Document(doc_id=531899966, name='Капучинатор / Вспениватель для молока /  Мини-миксер для капучино, латте / Капучинатор ручной/ Венчик для взбивания молока и сливок / Взбиватель для яиц'),
#  Document(doc_id=1624204872, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1566410321, name='Сыр Сернурский Рецепт №1 Авторский из коровьего, козьего и овечьего молока, 50%, 200 г'),
#  Document(doc_id=501007954, name='Капучинатор ; Капучинатор для приготовление напитков и молока ; Венчик ручной'),
#  Document(doc_id=1566410323, name='Сыр Сернурский Рецепт №1 Авторский с грецким орехом, из коровьего, козьего и овечьего молока 45%, 200 г'),
#  Document(doc_id=1676887645, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=173491816, name='Молоко безлактозное 1,8% 1 л х 12 шт, Parmalat Comfort'),
#  Document(doc_id=173491817, name='Молоко безлактозное 1,8% 1 л, Parmalat Comfort'),
#  Document(doc_id=958072425, name='SHOCKS! Протеиновое печенье Брауни без сахара Кофе с молоком, 9 шт'),
#  Document(doc_id=1610933888, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1676019329, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1421428353, name='Вспениватель молока Kitfort КТ-710. Уцененный товар'),
#  Document(doc_id=1566410374, name='Сыр Марсенталь Арабеск из козьего молока 50%, 150 г, Сернур'),
#  Document(doc_id=1650484886, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=178259607, name='Чай зеленый МАТЧА-ЛАТТЕ КОКОС без сахара, на сухом кокосовом молоке, 50 г. MUTE'),
#  Document(doc_id=1514735257, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=178259626, name='Чай зеленый МАТЧА-ЛАТТЕ КОКОС без сахара, на сухом кокосовом молоке, 100 г. MUTE'),
#  Document(doc_id=544147121, name='Термометр кулинарный электронный SimpleShop с выносным щупом для жидкости и еды/ Термощуп для мяса, рыбы, молока, вина, воды/ Щуп термометр из нержавеющей стали 17 см/ Таймер кухонный на батарейках'),
#  Document(doc_id=1633298097, name='Молоко Агуша 3,2% 925 мл с 3 лет X12. Уцененный товар'),
#  Document(doc_id=1633298098, name='Молоко Агуша 3,2% 925 мл с 3 лет X12. Уцененный товар'),
#  Document(doc_id=1633298101, name='Молоко Агуша 3,2% 925 мл с 3 лет X12. Уцененный товар'),
#  Document(doc_id=1421575865, name='Сосиски с молоком 350 г, Дым Дымыч'),
#  Document(doc_id=155944641, name='Молоко 973 мл, Viola UHT 3,2%'),
#  Document(doc_id=340453076, name='Молоко цельное сгущенное Коровка из Кореновки, 270 г'),
#  Document(doc_id=1180772052, name='Крем-десерт с молоком сгущенным вареным какао 25% 40 г, сливочный Коровка из Кореновки глазированный в вафельном рожке'),
#  Document(doc_id=172893911, name=' Едим с пользой Сухое молоко 400г. 1шт.'),
#  Document(doc_id=1180772055, name='Крем-десерт сливочный Коровка из Кореновки с молоком сгущенным вареным с кокосом глазированный в вафельном рожке 19%, 40 г.'),
#  Document(doc_id=1566410461, name='Сыр полутвердый с козьим молоком 50%, 150 г, Сернурский'),
#  Document(doc_id=1566410462, name='Сыр Сернурский Рецепт №1 Авторский из коровьего, козьего и овечьего молока, с трюфелем, 45%, 200 г'),
#  Document(doc_id=184264428, name='Сыр KO&CO Камамбер 150 г, мягкий, из козьего молока, с белой плесенью'),
#  Document(doc_id=184264429, name='Сыр Ko & Co Бюш Де Шевр, мягкий, из козьего молока, в прованских травах, 110 г'),
#  Document(doc_id=184264430, name='Сыр KO&CO Бюш Де Шевр 100 г, мягкий, из козьего молока, с белой плесенью'),
#  Document(doc_id=184264432, name='Сыр Ko & Co Бюш Де Шевр, мягкий, из козьего молока, свежий, 110 г'),
#  Document(doc_id=184264433, name='Сыр Ko & Co Бюш Де Шевр, мягкий, из козьего молока, с белой плесенью, в золе Валансе, 150 г'),
#  Document(doc_id=184264434, name='Сыр Ko & Co Бюш Де Шевр 100 г, Ko&Co, мягкий, из козьего молока, с плесенью, в золе Пепельный конус'),
#  Document(doc_id=184264435, name='Сыр Ko & Co Бюш Де Шевр, мягкий, из козьего молока, с плесенью, в золе, 85 г'),
#  Document(doc_id=249366273, name='Золотое молоко Куркума Латте суперфуд без кофеина,веган,100 гр.'),
#  Document(doc_id=1623287573, name='Молоко пастеризованное 2,8% - 5,6% 200 г, Козочка с Облачка'),
#  Document(doc_id=1162741528, name='Капучинатор и вспениватель молока электрический для капучино Oberhof Milchschumer IX-35 / вспениватель молочной пенки, 4 режима, объем 300 мл'),
#  Document(doc_id=1649927966, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1668056870, name='Молоко питьевое ультрапастеризованное Село Зеленое Edge, безлактозное м.д.ж. 1,8%, 0,95 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1609140015, name='Медвежонок Барни Пирожное с молоком, 150 г. Уцененный товар'),
#  Document(doc_id=1629398831, name='Молоко детское Тема 3,2%, 18 шт х 200 мл. Уцененный товар'),
#  Document(doc_id=969189169, name='Вспениватель молока Kitfort КТ-758, серый металлик, капучинатор. Уцененный товар'),
#  Document(doc_id=985335612, name='Кофе в зернах Lebo ESPRESSO MILKY Арабика 50%, робуста 50% , БЛЕНД ПОД МОЛОКО 220 г'),
#  Document(doc_id=1622837052, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1032652608, name='Каша кукурузная детская БИБИКАША с 5 месяцев, козье молоко, сухая, 200 г'),
#  Document(doc_id=226977633, name='KUNDER Подогреватель стерилизатор для бутылочек и сосок, молокоотсоса / разморозка молока, детского питания / стерилизация бутылок, посуды для новорожденных'),
#  Document(doc_id=1623287651, name='Молоко ультрапастеризованное 2,8% - 5,6% 200 г, Козочка с Облачка'),
#  Document(doc_id=1653065594, name='Молоко детское Тема 3,2%, 18 шт х 200 мл. Уцененный товар'),
#  Document(doc_id=1653065596, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1481738118, name='Каша быстрого приготовления Увелка овсяная Ассорти с ягодами и молоком, 6 пакетиков по 40 г, 240 г. Уцененный товар'),
#  Document(doc_id=1581164434, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=172173218, name='Сок с молоком Мажитэль Персик-Маракуйя 0,05%, 950 г x 12 шт'),
#  Document(doc_id=332310439, name='Сухое молоко цельное 600 гр'),
#  Document(doc_id=1526933417, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=172173227, name='Домик в Деревне Молоко Ультрапастеризованное 3.2% 950мл. 12шт.'),
#  Document(doc_id=1540130732, name='Молоко ультрапастеризованное 1,8% Parmalat, 12 шт х 1 л. Уцененный товар'),
#  Document(doc_id=172173229, name='Домик в Деревне Молоко Ультрапастеризованное 2.5% 950мл. 12шт.'),
#  Document(doc_id=1446520749, name='ЭкоНива Молоко Стерилизованное 3.2% 1000мл. 12шт. Уцененный товар'),
#  Document(doc_id=172173233, name='Сок с молоком Мажитэль Мультифрукт 0,05%, 950 г x 12 шт'),
#  Document(doc_id=172173236, name='Домик в Деревне Молоко Ультрапастеризованное 3.5% 950мл. 12шт.'),
#  Document(doc_id=142731191, name='Из Вологды Молоко Ультрапастеризованное 3.2% 1000мл. 1шт.'),
#  Document(doc_id=142731192, name='Из Вологды Молоко Ультрапастеризованное 3.2% 200мл. 1шт.'),
#  Document(doc_id=141133760, name='Шоколад Ritter Sport "Альпийское молоко" с альпийским молоком, 100 г'),
#  Document(doc_id=1674864576, name='Молоко Агуша обогащенное витаминами и йодом 2.5% 200мл с 8 месяцев X18. Уцененный товар'),
#  Document(doc_id=135456706, name='Набор контейнеров c герметичными крышками для грудного молока Philips Avent SCF618/10 180 мл, 10 шт'),
#  Document(doc_id=1551132624, name="Смесь МАМАКО 2 Premium, 800 г, с 2'-FL на козьем молоке. Уцененный товар"),
#  Document(doc_id=1551132631, name="Смесь МАМАКО 2 Premium, 800 г, с 2'-FL на козьем молоке. Уцененный товар"),
#  Document(doc_id=346769368, name='Тыквенный суп на кокосовом молоке Крафтовая кухня, 330 г'),
#  Document(doc_id=958613479, name='Сыр полутвердый BURЁNKA CLUB Марсенталь Арабеск из козьего молока, 50%, 125 г'),
#  Document(doc_id=1452713977, name='Parmalat Молоко Ультрапастеризованное 1.8% 1000мл. 12шт. Уцененный товар'),
#  Document(doc_id=186566657, name='Капучинатор ZESTEN, вспениватель молока (мини-миксер) на подставке, батарейки в комплекте'),
#  Document(doc_id=148170755, name='Млекоин Недостаток молока гранулы гомеопатические, 10 г'),
#  Document(doc_id=186566664, name='Капучинатор ZESTEN, вспениватель молока (мини-миксер) на подставке, батарейки в комплекте'),
#  Document(doc_id=196528143, name='Беспроводной капучинатор / портативный ручной вспениватель для молока Ecotone Delish с USB зарядным устройством и двумя венчиками / вспениватель молока (белый)'),
#  Document(doc_id=1089030176, name='Сыр мягкий Корова в масле 50%, 90 г, Егорлык Молоко'),
#  Document(doc_id=221505576, name='Молоко сгущенное с сахаром и какао Любинское, 380 г'),
#  Document(doc_id=1089030195, name='Сыр мягкий с пряностями и зеленью 50% , 90 г, Егорлык Молоко Корова, в масле'),
#  Document(doc_id=1652238389, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=307054653, name='Сливки Lactica, ультрапастеризованные, 10%, 500 мл'),
#  Document(doc_id=307054654, name='Сливки Lactica, ультрапастеризованные, 22%, 500 мл'),
#  Document(doc_id=1523312703, name='Молоко ультрапастеризованное 1,8% Parmalat, 12 шт х 1 л. Уцененный товар'),
#  Document(doc_id=326322260, name='Круассан со сгущенным молоком высший сорт, 75г'),
#  Document(doc_id=1565706330, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=590866536, name='Молоко 2,5%, 0,9 л, Сернур, ГОСТ, пастеризованное'),
#  Document(doc_id=590866537, name='Молоко 3,2%, 0,9 л, Сернур, ГОСТ, пастеризованное'),
#  Document(doc_id=829294701, name='Капучинатор вспениватель молока Raygood.'),
#  Document(doc_id=816965744, name='Капучинатор электрический мощный вспениватель для молока Bersecco Quattro M4'),
#  Document(doc_id=505792649, name='Питчер для молока, сливочник, молочник из пищевой нержавеющей стали - 150 мл'),
#  Document(doc_id=595822738, name='Молочная смесь Nestle NAN с рождения до 12 месяцев, на козьем молоке, 400 г'),
#  Document(doc_id=302475410, name='Крем сливочный President, для соуса, ультрапастеризованный, 23%, 200 г'),
#  Document(doc_id=1603889300, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=302475411, name='Крем сливочный President, для соуса, ультрапастеризованный, 23%, 500 г'),
#  Document(doc_id=140675230, name='Амалтея Молоко козье цельное сухое, 400 г'),
#  Document(doc_id=140675231, name='Каша гречневая детская Бибикаша с 4 месяцев, козье молоко, сухая, 200 г'),
#  Document(doc_id=140675232, name='Каша овсяная детская Бибикаша с 5 месяцев, козье молоко, сухая, 200 г'),
#  Document(doc_id=140675233, name='Каша рисовая детская Бибикаша с 4 месяцев, козье молоко, сухая, 200 г'),
#  Document(doc_id=140675234, name='Каша кукурузная детская Бибикаша с 5 месяцев, козье молоко, сухая, 200 г'),
#  Document(doc_id=1547872421, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=223692972, name='Молоко отборное 3,4%- 4,5%, 930 г, Чабан'),
#  Document(doc_id=743925955, name='Сырок творожный глазированный со сгущенным молоком 18%, 40 г, Коровка из Кореновки'),
#  Document(doc_id=265144517, name='Сухое молоко обезжиренное 1000 гр, 1 кг'),
#  Document(doc_id=245598422, name='Капучинатор для молока электрический, ручной, беспроводной / Мини миксер / Вспениватель для кофе ENERGY'),
#  Document(doc_id=743925978, name='Молоко питьевое, пастеризанное 2,7% 900 мл Коровка из КореновкиПЭТ'),
#  Document(doc_id=847169756, name='Капучинатор и вспениватель для молока электрический, ручной, беспроводной / Мини миксер / GeoLuK Milk Frother'),
#  Document(doc_id=1032644831, name='Каша гречневая детская БИБИКАША с 4 месяцев, козье молоко, сухая, 200 гр.'),
#  Document(doc_id=1639942368, name='Молоко ультрапастеризованное 1,8% Parmalat, 12 шт х 1 л. Уцененный товар'),
#  Document(doc_id=1440524529, name='Капучинатор и вспениватель молока электрический для капучино Oberhof Milchschumer IX-17 / вспениватель молочной пенки, 3 скорости, емкость батареи 1200 мАч. Уцененный товар'),
#  Document(doc_id=1569900799, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=595822850, name='Молочная смесь Nestle NAN 3 с 1 года, на основе козьего молока, 400 г'),
#  Document(doc_id=1432946965, name='ЭкоНива Молоко Стерилизованное 3.2% 1000мл. 12шт. Уцененный товар'),
#  Document(doc_id=1581058334, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1444538668, name='Parmalat Молоко Ультрапастеризованное 1.8% 1000мл. 12шт. Уцененный товар'),
#  Document(doc_id=179185965, name='Сыр творожный Козий Chevre, из козьего молока 140 г, President'),
#  Document(doc_id=798378291, name='Капучинатор / вспениватель молока для кофе / мини миксер'),
#  Document(doc_id=1655785786, name='Хлопья Быстров овсяные с малиной и молоком, не требующие варки, 240 г. Уцененный товар'),
#  Document(doc_id=384149827, name='Молоко Село Домашкино пастеризованное, 3,2%, 900 мл'),
#  Document(doc_id=1523091784, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1525713228, name='Капучинатор электрический, вспениватель молока и взбиватель яиц, ручной мощный электровенчик. Уцененный товар'),
#  Document(doc_id=1339042134, name='Вспениватель молока Kitfort КТ-758, серый металлик, капучинатор. Уцененный товар'),
#  Document(doc_id=441182554, name='Мороженое на кокосовом молоке Warm Ice "Прованские травы", 80 г'),
#  Document(doc_id=1636026718, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1511721311, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1659513184, name='Капучинатор для молока Hyundai HMF-P300 кремовый 300мл. Уцененный товар'),
#  Document(doc_id=1555237222, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=260270447, name='Aroy-d Кокосовое молоко 70% жирность 17-19%, 500 мл x 4 шт'),
#  Document(doc_id=1591167346, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1581541759, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1514908036, name='Вспениватель молока Kitfort КТ-710. Уцененный товар'),
#  Document(doc_id=1671195012, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1166723462, name='Молоко пастеризованное 3,2-4,0% 2 л ПравильноеМолоко'),
#  Document(doc_id=285378961, name='Кокосовое молоко FOCO органическое БЕЗ ДОБАВОК, жирность 10-12%, 400 мл х 4 шт'),
#  Document(doc_id=609077649, name='Средство JURA для очистки системы приготовления молока (микрогранулы) 24158'),
#  Document(doc_id=1654565283, name='Молоко Parmalat Comfort, безлактозное, 1,8%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1674865062, name='Молоко Агуша обогащенное витаминами и йодом 2.5% 200мл с 8 месяцев X18. Уцененный товар'),
#  Document(doc_id=229157298, name=' New Milky Extra Сухое молоко 1000г. 1шт.'),
#  Document(doc_id=260336065, name='Кокосовое молоко Aroy-D, 70%, жирность 17-19%, 1 л х 4 шт'),
#  Document(doc_id=365144523, name='MUKUNGHWA Мыло с молоком, 90 г'),
#  Document(doc_id=1492019667, name='ЭкоНива Молоко Стерилизованное 3.2% 1000мл. 12шт. Уцененный товар'),
#  Document(doc_id=1467976151, name='Село Зеленое Молоко Ультрапастеризованное 3.2% 950мл. 12шт. Уцененный товар'),
#  Document(doc_id=1605913048, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=562276830, name='Набор капучинатор с венчиком, белый/Вспениватель для молока и сливок/для взбивания электрический беспроводной/Мини миксер для кофе латте капучино детских смесей коктейлей чая матча/'),
#  Document(doc_id=258820582, name='Пирожное бисквитное "Ломтишка" молоко 500гр., киндер делис/Акконд/ Вкус знакомый с детства.'),
#  Document(doc_id=1432947178, name='ЭкоНива Молоко Стерилизованное 2.5% 1000мл. 12шт. Уцененный товар'),
#  Document(doc_id=721488382, name='Молочная смесь Bebelac Gold 1, на основе козьего молока, с рождения, 350 г'),
#  Document(doc_id=1612581374, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=721488389, name='Молочная смесь Bebelac Gold 2, на основе козьего молока, с 6 месяцев, 350 г'),
#  Document(doc_id=185256457, name='НАБОР 6шт по 425мл. Кокосовое молоко 17-19% (Шри-Ланка) KIMPAO'),
#  Document(doc_id=1477855782, name='Молоко Агуша обогащенное витаминами и йодом 2.5% 200мл с 8 месяцев X18. Уцененный товар'),
#  Document(doc_id=1558809126, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1612532267, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1647610417, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=641206867, name='Молоко 3,2%, 750 мл, Хутор Дороганов'),
#  Document(doc_id=864733783, name='Каша Овсянка с кокосовым молоком, манго и семенами чиа Kashers, замороженная, 220 г'),
#  Document(doc_id=1675799137, name='Молоко ФрутоНяня ультрапастеризованное (м.д.ж. 2,5%), 0.2 л х 12 шт. Уцененный товар'),
#  Document(doc_id=709372520, name='Молоко Очень важная корова ультрапастеризованное 1,5%, 1л'),
#  Document(doc_id=236505711, name='Йогурт "Греческий" из овечьего молока термостатный, 4-8%, 100 г, Сернурский СЗ массовой долей жира'),
#  Document(doc_id=334867057, name='Пакеты для грудного молока, 30 шт по 250 мл'),
#  Document(doc_id=166283896, name='Молоко сгущенное 8,5% 380 г, Рогачевъ, с сахаром'),
#  Document(doc_id=166283897, name='Молоко сгущенное Рогачевъ, с сахаром, 8,5%, 270 г'),
#  Document(doc_id=1324059259, name='Молоко Ozon fresh пастеризованное, 2,5%, 900 мл'),
#  Document(doc_id=1670883963, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1578470020, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1058171539, name='Панкейки со сгущенным молоком 150 г, Бахетле'),
#  Document(doc_id=1600391828, name='Молоко Агуша обогащенное витаминами и йодом 2.5% 200мл с 8 месяцев X18. Уцененный товар'),
#  Document(doc_id=641206933, name='Молоко 2,5%, 750 мл, Хутор Дороганов'),
#  Document(doc_id=1492617881, name='Село Зеленое Молоко Ультрапастеризованное 3.2% 950мл. 12шт. Уцененный товар'),
#  Document(doc_id=1655941785, name='Ванильные панкейки со сгущенным молоком Cook Chart, 135 г'),
#  Document(doc_id=1492617890, name='Село Зеленое Молоко Ультрапастеризованное 3.2% 950мл. 12шт. Уцененный товар'),
#  Document(doc_id=1610189477, name='Молоко ультрапастеризованное 1,8% Parmalat, 12 шт х 1 л. Уцененный товар'),
#  Document(doc_id=1610189478, name='Молоко ультрапастеризованное 1,8% Parmalat, 12 шт х 1 л. Уцененный товар'),
#  Document(doc_id=1611704998, name='Молоко ультрапастеризованное 1,8% Parmalat, 12 шт х 1 л. Уцененный товар'),
#  Document(doc_id=1492617900, name='Село Зеленое Молоко Ультрапастеризованное 3.2% 950мл. 12шт. Уцененный товар'),
#  Document(doc_id=1271696057, name='Сливочное печенье со сгущённым молоком 200 г, У Палыча'),
#  Document(doc_id=1621428928, name='Молоко ультрапастеризованное 1,8% Parmalat, 12 шт х 1 л. Уцененный товар'),
#  Document(doc_id=1557170919, name='Капучинатор для молока Hyundai HMF-P300 кремовый 300мл. Уцененный товар'),
#  Document(doc_id=1640467180, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=194587386, name='Наполнитель для кошачьего туалета Japan Premium Pet комкующийся с экстрактом бамбука и японского чая (молоко кокосовое), 6 л'),
#  Document(doc_id=430918395, name="Смесь МАМАКО 1 Premium, 800 г, с 2'-FL на козьем молоке"),
#  Document(doc_id=638192386, name='Молоко 2,5%, 930 г, Чабан'),
#  Document(doc_id=1649003270, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1324059400, name='Молоко Ozon fresh пастеризованное, 3,2%, 900 мл'),
#  Document(doc_id=430918409, name="Смесь МАМАКО 2 Premium, 800 г, с 2'-FL на козьем молоке"),
#  Document(doc_id=605055754, name='Творожный продукт из козьего молока  "Творожный крем" с ванилином, 11%-18%, LavkaLavka, 150 г'),
#  Document(doc_id=430918419, name="Смесь МАМАКО 3 Premium, 800 г, с 2'-FL на козьем молоке"),
#  Document(doc_id=1581452058, name='Молоко ультрапастеризованное Клевер, 6%, 1 л'),
#  Document(doc_id=462998304, name='Молоко цельное сгущенное с сахаром Коровка из Кореновки 8,5%, 3 упаковки по 270 гр.'),
#  Document(doc_id=1418464039, name='Капучинатор вспениватель молока венчик для взбивания электрический usb ручной'),
#  Document(doc_id=1565035334, name='Молоко Агуша обогащенное витаминами и йодом 2.5% 200мл с 8 месяцев X18. Уцененный товар'),
#  Document(doc_id=1569065798, name='Молоко ультрапастеризованное Вологжанка, 3,2 %, 1 л'),
#  Document(doc_id=1569065801, name='Молоко ультрапастеризованное Вологжанка, 2,5 %, 1 л'),
#  Document(doc_id=147180362, name='Творог из козьего молока "Козий" Ефремовское молоко 2%, 180 г'),
#  Document(doc_id=1466469205, name='Мороженое со сгущенным молоком 180 г, I Love you, с ЗМЖ'),
#  Document(doc_id=1152420699, name='Сыр Сернур Брынза из коровьего молока 40%, 250-365 г'),
# ...
#  Document(doc_id=282351251, name='Питчер для молока MyBarista 350мл'),
#  Document(doc_id=151000724, name='Молоко цельное сгущенное с сахаром Любимая Классика, 380 г'),
#  Document(doc_id=151000725, name='Молоко цельное сгущенное с сахаром Любимая Классика, 270 г'),
#  Document(doc_id=1575368343, name='Молоко питьевое ультрапастеризованное Село Зеленое Edge, безлактозное м.д.ж. 1,8%, 0,95 л х 12 шт. Уцененный товар'),
#  Document(doc_id=154359448, name='Молоко цельное, отборное, питьевое 3,4%-6,0% 900 мл, Коровка из Кореновки, пастеризованное'),
#  Document(doc_id=654014104, name='Ацидофильный напиток 2,5% 450 г, Просто Молоко'),
#  Document(doc_id=987403930, name='Печенье протеиновое Топленое молоко в карамельном шоколаде без сахара Butter Wave choco, 336г'),
#  Document(doc_id=654014109, name='Катык Просто Молоко 4%, 450 г'),
#  Document(doc_id=320362144, name='Молоко козье отборное 487 мл, Село Зеленое'),
#  Document(doc_id=654014112, name='Простокваша Мечниковская 4%, 450 г, Просто Молоко'),
#  Document(doc_id=1340741280, name='Смузи Be Up банан-апельсин-кокосовое молоко, 300 мл'),
#  Document(doc_id=320362149, name='Молоко 2,5% 950 мл, Село Зеленое, ультрапастеризованное'),
#  Document(doc_id=320362153, name='Молочная речка Молоко Ультрапастеризованное 3.2% 973мл. 1шт.'),
#  Document(doc_id=193975978, name='Молоко цельное 3,6-4,6% 1 л, Братья Чебурашкины, пастеризованное'),
#  Document(doc_id=1340741290, name='Смузи Be Up морковь-кокосовое молоко, 300 мл'),
#  Document(doc_id=1638790839, name='Молоко Parmalat Comfort, безлактозное, 1,8%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=612685512, name='Капучинатор Kitfort КТ-786-3, красный, вспениватель молока, 500 Вт, чаша 240 мл, антипригарное покрытие, 4 режима работы, 2 насадки для вспенивания и смешивания'),
#  Document(doc_id=1605277391, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=323270354, name='Молоко питьевое пастеризованное 2,5% 900 г, Агрокомплекс, пленка'),
#  Document(doc_id=323270355, name='Молоко питьевое пастеризованное 3,2% 900 г, Агрокомплекс, пленка'),
#  Document(doc_id=1553233618, name='Капучинатор для молока Hyundai HMF-P300 кремовый 300мл. Уцененный товар'),
#  Document(doc_id=287323869, name='Натуральный жидкий сычужный фермент для приготовления сыра 50 мл на 250 л молока'),
#  Document(doc_id=263943905, name='Мыло Fax Крем & Кокосовое молоко, 5х70 г, 2 упаковки'),
#  Document(doc_id=1543591670, name='Молоко ультрапастеризованное 1,8% Parmalat, 12 шт х 1 л. Уцененный товар'),
#  Document(doc_id=1543591673, name='Молоко Parmalat Comfort, безлактозное, 1,8%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1605277438, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1543591678, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=519534352, name='Кубанская Буренка Молоко Ультрапастеризованное 6.0% 950мл. 1шт.'),
#  Document(doc_id=1663006486, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=356464421, name='Молоко сгущённое варёное Свитлогорье с сахаром Лакомка, 380 г'),
#  Document(doc_id=559658791, name='Капучинатор беспроводной USB, вспениватель молока кофе сливок яиц матча латте шоколада, миксер ручной, венчик для взбивания электрический 2шт, бытовая техника для кухни, аксессуары для кухни,3 режима'),
#  Document(doc_id=1545049915, name='Молоко Parmalat UHT Comfort, безлактозное, 3,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=264394561, name='Питчер для молока и кофе, молочник 350мл серебристый с мерной шкалой'),
#  Document(doc_id=1582995272, name='Молоко ультрапастеризованное ЭкоНива, для питания детей с 3-х лет, 3,2%, 200 мл х 18 шт. Уцененный товар'),
#  Document(doc_id=1197864792, name='Молоко ФрутоНяня ультрапастеризованное (м.д.ж. 2,5%), 0.2 л'),
#  Document(doc_id=870070117, name='ЭкоНива Молоко Стерилизованное 3.5% 1шт.'),
#  Document(doc_id=741955430, name='GFGRIL высокоскоростной блендер GF-SM10 1,75 л, 30 000 об/мин, 8 стальных лезвий, стационарный блендер пароварка, нагрев до 100 градусов, суп-пюре, соевое молоко, 8 программ. Уцененный товар'),
#  Document(doc_id=354309997, name='NABI Патчи для глаз с экстрактом кокосового молока, гидрогелевые патчи для глаз от темных кругов и отеков (быстрый результат, 60 штук)'),
#  Document(doc_id=1197864822, name='Молоко ФрутоНяня ультрапастеризованное (м.д.ж. 2,5%), 0.2 л х 12 шт'),
#  Document(doc_id=1601402744, name='Капучинатор для молока Hyundai HMF-P300 кремовый 300мл. Уцененный товар'),
#  Document(doc_id=1606276985, name='Молоко ультрапастеризованное 1,8% Parmalat, 12 шт х 1 л. Уцененный товар'),
#  Document(doc_id=239662977, name='Erborian MILK&PEEL Mask, Разглаживающая маска для лица Кунжутное молоко, 60 гр'),
#  Document(doc_id=143415195, name='Pigeon Пакеты для хранения грудного молока 180 мл 25 шт'),
#  Document(doc_id=172554143, name='Молоко безлактозное, 1,5 % 970 мл, Простоквашино, ультрапастеризованное'),
#  Document(doc_id=1480005547, name='Parmalat Молоко Ультрапастеризованное 1.8% 1000мл. 12шт. Уцененный товар'),
#  Document(doc_id=1328879534, name='Молоко Халяль 2,5%, 1,4 кг, Очень важная корова, пастеризованное'),
#  Document(doc_id=499644336, name='Органическое кокосовое молоко ACP VICO Rich / 1 л / 4 шт'),
#  Document(doc_id=154277819, name='Чай в пакетиках зеленый Saito Milky Oolong, с ароматом молока, 25 шт'),
#  Document(doc_id=172799947, name='Чай Niktea Milk Oolong/ Молочный Улун, чай зеленый ароматизированный с ароматом молока в пакетиках, 25 п х 2 г'),
#  Document(doc_id=1554757580, name='Кулич пасхальный без глютена, сахара и молока'),
#  Document(doc_id=145627087, name='Вспениватель молока Kitfort КТ-710'),
#  Document(doc_id=145627088, name='Вспениватель молока Kitfort КТ-711'),
#  Document(doc_id=1632188382, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1670936544, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1586509798, name='Молоко питьевое 2,5%, 900 мл, Красное знамя, пастеризованное'),
#  Document(doc_id=1635047398, name='Каша быстрого приготовления Увелка овсяная Ассорти с ягодами и молоком, 6 пакетиков по 40 г, 240 г. Уцененный товар'),
#  Document(doc_id=545445868, name='Молоко Сгущенное Коровка из Кореновки цельное 8,5%, 880 г ПЭТ'),
#  Document(doc_id=162961389, name='Herbal Essences Кокосовое молоко, Шампунь веганский, 400 мл'),
#  Document(doc_id=1532950512, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1480620023, name='Сливки ультрапастеризованные для взбивания 33%, 250 г, Вкуснотеево'),
#  Document(doc_id=291731454, name='Мини десерт замороженный без молока "Фундучное эскимо" Lubaica, 55г / мороженое пп , без лактозы, без глютена, натуральный'),
#  Document(doc_id=364492805, name='Молоко сгущенное Коровка из Кореновки, цельное с сахаром, 8,5%, сашет, 270 г\n'),
#  Document(doc_id=1548457995, name='Сухой молочный напиток на основе козьего молока НЭННИ 4 для детей старше 1,5 лет, 800 г. Уцененный товар'),
#  Document(doc_id=1483397132, name='Село Зеленое Молоко Ультрапастеризованное 3.2% 950мл. 12шт. Уцененный товар'),
#  Document(doc_id=1638791212, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1578129464, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=793483322, name='Снежок Молоко Ультрапастеризованное 3.2% 1000мл. 1шт.'),
#  Document(doc_id=1567291468, name='Каша быстрого приготовления Увелка овсяная Ассорти с ягодами и молоком, 6 пакетиков по 40 г, 240 г. Уцененный товар'),
#  Document(doc_id=177223762, name='Органическое кокосовое молоко 1 литр CocoDaily 61%, (жирность 17-19%), 3 шт.'),
#  Document(doc_id=1636235359, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1436596325, name='Parmalat Молоко Ультрапастеризованное 1.8% 1000мл. 12шт. Уцененный товар'),
#  Document(doc_id=1409349739, name='Детское печенье на козьем молоке с яблочным соком, 2шт. по 150 г.'),
#  Document(doc_id=301021293, name='Молоко 900 г, 3,2%, Вкуснотеево, ультрапастеризованное'),
#  Document(doc_id=301021300, name='Молоко ультрапастеризованное 2,5% 900 г, Вкуснотеево'),
#  Document(doc_id=763959425, name='Молоко 2,5% 930 мл Калория Кубанское'),
#  Document(doc_id=763959430, name='Молоко Калория питьевое ультрапастеризованное  2,5%, 1л'),
#  Document(doc_id=763959435, name='Сливки Калория ультрапастеризованные 10 % , 200г'),
#  Document(doc_id=1555519629, name='Каша быстрого приготовления Увелка овсяная Ассорти с ягодами и молоком, 6 пакетиков по 40 г, 240 г. Уцененный товар'),
#  Document(doc_id=301529236, name='Shiny Kitchen, Капучинатор, вспениватель молока'),
#  Document(doc_id=340441239, name='Пельмени Сочные 700 г, с фаршем на молоке Сибирская коллекция, замороженные'),
#  Document(doc_id=144611482, name='Б.Ю.Александров Сырок с молоком сгущенным вареным в молочном шоколаде, 50 г'),
#  Document(doc_id=244676770, name='Кокосовое молоко AROY-D жирность 19%, 500 мл, tetra pak, 1 шт'),
#  Document(doc_id=1664997541, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=198678694, name='Органическое кокосовое молоко ACP VICO Rich / 330 мл / 1 шт'),
#  Document(doc_id=763959466, name='Молоко Калория СуперМилк ультрапастеризованные 3,2%, 200мл'),
#  Document(doc_id=1568946360, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=154073276, name='Ковш кухонный Fissman из нержавеющей стали, для кипячение молока - 1,5л'),
#  Document(doc_id=1477900510, name='Молоко ФрутоНяня ультрапастеризованное (м.д.ж. 2,5%), 0.2 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1465448672, name='Село Зеленое Молоко Ультрапастеризованное 3.2% 950мл. 12шт. Уцененный товар'),
#  Document(doc_id=141580513, name='Молоко ультрапастеризованное 3,5%, 1 л, Parmalat'),
#  Document(doc_id=141580514, name='Молоко ультрапастеризованное 1,8% 1 л, Parmalat'),
#  Document(doc_id=141580515, name='Parmalat Молоко Ультрапастеризованное 0.5% 1000мл. 1шт.'),
#  Document(doc_id=141580516, name='Parmalat Молоко Ультрапастеризованное 3.5% 200мл. 1шт.'),
#  Document(doc_id=141580518, name='Молоко Белый Город ультрапастеризованное 3,2%, 1 л'),
#  Document(doc_id=141580519, name='Белый Город Молоко Ультрапастеризованное 2.5% 1000мл. 1шт.'),
#  Document(doc_id=141580520, name='Белый Город Молоко Стерилизованное 1.5% 1000мл. 1шт.'),
#  Document(doc_id=654014695, name='Творог 9%, 180 г, Просто Молоко, флоу-пак'),
#  Document(doc_id=141580524, name='Parmalat Молоко Ультрапастеризованное 0.5% 1000мл. 1шт.'),
#  Document(doc_id=172292342, name='Молоко безлактозное 1,8% 1 л х 12 шт, Parmalat Comfort'),
#  Document(doc_id=813316344, name='Молоко козье цельное, пастеризованное 3,5-4,8% 310 мл G-Balance'),
#  Document(doc_id=1626511610, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=300751105, name='Шоколад «РОССИЯ» — ЩЕДРАЯ ДУША! КОФЕ С МОЛОКОМ. Молочный с добавлением кофе, 82 г'),
#  Document(doc_id=141580549, name='Сливки ультрапастеризованные 35% 0,5 л, Parmalat'),
#  Document(doc_id=141580551, name='Сливки ультрапастеризованные 23%, 0,5 л, Parmalat'),
#  Document(doc_id=183441675, name=' Healthy Lifestyle Сухое молоко 350г. 1шт.'),
#  Document(doc_id=1616566545, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1616566547, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1569208599, name='Parmalat молоко ультрапастеризованное 3,5%, 1 л. Уцененный товар'),
#  Document(doc_id=1543215390, name='Молоко Parmalat UHT Comfort, безлактозное, 0,05%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=769530152, name='Питчер для молока и кофе, молочник, посуда для сервировки 350мл Серебряный матовый'),
#  Document(doc_id=462182700, name='Молоко топленое Халяль 4%, 430 г, Очень важная корова'),
#  Document(doc_id=462182702, name='Молоко пастеризованное Халяль 1,5%, 930 г, Очень важная корова'),
#  Document(doc_id=462182704, name='Молоко Халяль 2,5%, 930 г, Очень важная корова, пастеризованное'),
#  Document(doc_id=1378285873, name='Молокоотсос Sisbro Care электрический, беспроводной, портативный / устройство с бутылочкой и соской в комплекте для кормления новорожденного и для сцеживания грудного молока'),
#  Document(doc_id=462182706, name='Молоко отборное халяль 3,4-6%, 930 г, Очень важная корова, пастеризованное'),
#  Document(doc_id=462182707, name='Молоко Халяль 3,2%, 1,4 кг, Очень важная корова, пастеризованное'),
#  Document(doc_id=462182711, name='Молоко топленое Халяль 4%, 930 г, Очень важная корова'),
#  Document(doc_id=607926587, name='Капучинатор ZESTEN, вспениватель молока (мини-миксер) на подставке, батарейки в комплекте'),
#  Document(doc_id=1550670142, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=688568644, name='Том Ям с креветками Elementaree. Набор для приготовления супа на 2-6 порций (1000 г). Содержит все необходимое - от креветок до специй и кокосового молока.'),
#  Document(doc_id=1430165833, name='Молоко Молочная Культура питьевое пастеризованное безлактозное, 3,5%-4,5%, 0,5 л'),
#  Document(doc_id=1430165834, name='Молоко Молочная Культура, 1,5%, 1,8 кг'),
#  Document(doc_id=1430165835, name='Молоко Молочная Культура ненормализованное, 3,5%-4,5%, 1,8 кг'),
#  Document(doc_id=1553209677, name='Капучинатор для молока Hyundai HMF-P300 кремовый 300мл. Уцененный товар'),
#  Document(doc_id=172955994, name='Кокосовое молоко Take a Bite, без сахара, безлактозное, 6 шт по 1 л'),
#  Document(doc_id=1586370915, name='Молочная смесь Nestle NAN с рождения до 12 месяцев, на козьем молоке, 400 г. Уцененный товар'),
#  Document(doc_id=1449539943, name='Сыр с голубой плесенью Егорлык Молоко, 50%, 100 г'),
#  Document(doc_id=193902964, name='Медофеты с курагой и черносливом Берестов А.С., 350 г суфле птичье молоко "Ассорти"'),
#  Document(doc_id=228145524, name='GFGRIL высокоскоростной блендер GF-SM10 1,75 л, 30 000 об/мин, 8 стальных лезвий, стационарный блендер пароварка, нагрев до 100 градусов, суп-пюре, соевое молоко, 8 программ'),
#  Document(doc_id=1520023933, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1562851720, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=503167370, name='Молочник из нержавеющей стали, питчер для молока, цвет медный, объем 600 мл'),
#  Document(doc_id=1520023949, name='Молоко Parmalat Comfort, безлактозное, 1,8%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1044732304, name='Сухой молочный напиток на основе козьего молока НЭННИ 4 для детей старше 1,5 лет, 800 г'),
#  Document(doc_id=1539496356, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1562851751, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1640069547, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1573804461, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=256653748, name=' EUROPEK Сухое молоко 400г. 1шт.'),
#  Document(doc_id=172374454, name='Растительное молоко Aroy-D, кокосовое, 1 л х 12 шт'),
#  Document(doc_id=258455993, name='Напиток Куркума Латте, золотое молоко, смесь специй и пряностей, 200 г'),
#  Document(doc_id=278174138, name='Сироп низкокалорийный без сахара Mr.Djemius ZERO "Сгущенное молоко" 330г/ соус, сгущенка, еда, пп'),
#  Document(doc_id=178018770, name='Сгущенное молоко вареное 8,5% 360 г, Алексеевское, с сахаром, ГОСТ, ЖБ'),
#  Document(doc_id=178018774, name='Сгущенное молоко 8,5% 270 г, Алексеевское, цельное, с сахаром, ГОСТ'),
#  ...]

# %%
search_with_or_condition(
    documents_index,
    documents_dict,
    symbols_to_replace,
    russian_stopwords,
    morph,
    "молоко ультрапастеризованное 1литр",
    10,
)
# Out:
# [Document(doc_id=1442791428, name='Parmalat Молоко Ультрапастеризованное 3.5% 1000мл. 12шт. Уцененный товар'),
#  Document(doc_id=1558601740, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=148054037, name='Zeitun Скраб для тела с маслами, питательный, сахарный "Шоколад и молоко" 250 мл'),
#  Document(doc_id=1593598002, name='Молочная смесь Nestle NAN с рождения до 12 месяцев, на козьем молоке, 400 г. Уцененный товар'),
#  Document(doc_id=175415348, name='Молоко цельное сгущенное с сахаром, Рогачевъ, ГОСТ, 8,5 %, дой-пак, 270 гр., 3 штуки'),
#  Document(doc_id=1525588024, name='Молоко Стерилизованное Село Зеленое 2,5 % 0,95 л х 12 шт. Уцененный товар'),
#  Document(doc_id=472080455, name='Сок с молоком Мажитэль Папайя-Манго-Ананас 0,05%, 950 г'),
#  Document(doc_id=231555166, name='Молочко детское Kabrita Gold 4, с 18 месяцев, на козьем молоке для комфортного пищеварения, 800 г'),
#  Document(doc_id=1439965285, name='Parmalat Молоко Ультрапастеризованное 3.5% 1000мл. 12шт. Уцененный товар'),
#  Document(doc_id=1615880294, name='Молоко ультрапастеризованное Просто Молоко, 3,2 %, 1 л'),
#  Document(doc_id=1615880309, name='Молоко ультрапастеризованное Я ем с умом, низколактозное, 1,5 %, 1 л'),
#  Document(doc_id=302121080, name='Торт "Черничное молоко" 750 г, Mirel'),
#  Document(doc_id=1514905725, name='Вспениватель молока Kitfort КТ-758, серый металлик. Уцененный товар'),
#  Document(doc_id=1419042942, name='Мороженое Птичье молоко с шоколадным топпингом 450 г, Вкусландия'),
#  Document(doc_id=321880201, name='Молоко пастеризованное Кубанская буренка 2.5% 930мл'),
#  Document(doc_id=321880202, name='Молоко пастеризованное Кубанская буренка Отборное 930мл'),
#  Document(doc_id=321880203, name='Молоко пастеризованное Кубанская буренка Отборное 1,4л'),
#  Document(doc_id=321880204, name='Молоко пастеризованное Кубанская буренка 2.5% 1,4л'),
#  Document(doc_id=156418189, name='Молоко ультрапастеризованное 3,5%, 12 шт х 1 л, Parmalat'),
#  Document(doc_id=156418190, name='Молоко ультрапастеризованное 1,8% 12 шт х 1 л, Parmalat'),
#  Document(doc_id=321880207, name='Кубанская Буренка Молоко Ультрапастеризованное 3.5% 950мл. 1шт.'),
#  Document(doc_id=156418192, name='Молоко ультрапастеризованное 3,5%, 1 л, Parmalat'),
#  Document(doc_id=156418193, name='Молоко Белый Город ультрапастеризованное 3,2%, 1 л'),
#  Document(doc_id=156418195, name='Молоко ультрапастеризованное 1,8% 1 л, Parmalat'),
#  Document(doc_id=167297178, name='Шоколад Ritter Sport "Альпийское молоко" с альпийским молоком, 100 г'),
#  Document(doc_id=173023395, name='KUNDER Бутылочка для кормления новорожденных от 3 месяцев 240мл. силиконовая антиколиковая ортодонтическая детская с соской антивакуумным клапаном для молока воды смеси, непроливайка для малышей'),
#  Document(doc_id=162259117, name='Капучинатор, вспениватель молока, электрический, MELL, цвет черный'),
#  Document(doc_id=916701361, name='Мороженое молочное с кокосовым молоком ведёрко, 272 г, Bounty'),
#  Document(doc_id=765886652, name='Молоко пастеризованное Parmalat отборное, 900 мл ПЭТ'),
#  Document(doc_id=765886655, name='Молоко пастеризованное Безлактозное 1,8% Parmalat Comfort, 900 мл ПЭТ'),
#  Document(doc_id=765886656, name='Молоко пастеризованное Безлактозное 3,5% Parmalat Comfort, 900 мл ПЭТ'),
#  Document(doc_id=1145651403, name='Капучинатор электрический SIMPLE KITCHEN, вспениватель молока, Серия - Премиум (SK_MF1)'),
#  Document(doc_id=1533657294, name='Молоко Parmalat Comfort, безлактозное, 1,8%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1566851288, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=749895900, name='Вафельная трубочка молочный крем с молоком сгущённым с сахаром, 65 г, ЗГДиОП им.В.П.Пастухова'),
#  Document(doc_id=1527234785, name='Молоко Агуша обогащенное витаминами и йодом 2.5% 200мл с 8 месяцев X18. Уцененный товар'),
#  Document(doc_id=1599848678, name='Молоко Parmalat Comfort, безлактозное, 1,8%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1626824934, name='Каша рисовая с вишней на кокосовом молоке 250 г, без сахара и глютена Азбука Вкуса'),
#  Document(doc_id=1465450737, name='Село Зеленое Молоко Ультрапастеризованное 3.2% 950мл. 12шт. Уцененный товар'),
#  Document(doc_id=577069307, name='Ряженка Домик в деревне Для тебя Топленое молоко 2.5% 270г'),
#  Document(doc_id=1504485629, name='Молоко 2,5%, 930 мл, Экомилк'),
#  Document(doc_id=1670938889, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=259531020, name='Вафли Рот Фронт Коровка топленое молоко, 300 г'),
#  Document(doc_id=160055577, name='Молочная смесь Kabrita Gold 1, с рождения, на козьем молоке для комфортного пищеварения, 400 г'),
#  Document(doc_id=160055580, name='Молочная смесь Kabrita Gold 2, с 6 месяцев, на козьем молоке для комфортного пищеварения, 400 г'),
#  Document(doc_id=160055582, name='Молочная смесь Kabrita Gold 1, с рождения, на козьем молоке для комфортного пищеварения, 800 г'),
#  Document(doc_id=160055584, name='Молочная смесь Kabrita Gold 2, с 6 месяцев, на козьем молоке для комфортного пищеварения, 800 г'),
#  Document(doc_id=160055585, name='Молочко детское Kabrita Gold 3, с 12 месяцев, на козьем молоке для комфортного пищеварения, 800 г'),
#  Document(doc_id=589947169, name='Молоко сгущенное Главпродукт ГОСТ, дой пак дозатор, 270 г'),
#  Document(doc_id=1674682660, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1543569704, name='Молоко пастеризованное 2,5% 900 г, Новая Деревня'),
#  Document(doc_id=1543569708, name='Молоко пастеризованное 3,2% 900 г, Новая Деревня'),
#  Document(doc_id=943235402, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт'),
#  Document(doc_id=172605781, name='Домик в Деревне Молоко Ультрапастеризованное 3.2% 950мл. 12шт.'),
#  Document(doc_id=630604122, name='Вспениватель молока Oursson MF3500D/IV, 3 режима работы, подогрев молока, антипригарное внутреннее покрытие'),
#  Document(doc_id=1615880546, name='Молоко ультрапастеризованное Просто Молоко, 2,5 %, 1 л'),
#  Document(doc_id=1615880547, name='Молоко ультрапастеризованное Агросила, Халяль, 3,2%, 1 л'),
#  Document(doc_id=1159577966, name='Капучинатор и вспениватель молока электрический для капучино Oberhof Milchschumer IX-17 / вспениватель молочной пенки, 3 скорости, емкость батареи 1200 мАч'),
#  Document(doc_id=564773232, name='EVELINE Крем для лица КОЗЬЕ МОЛОКО омолаживающий, дневной, 75 мл'),
#  Document(doc_id=589947269, name='Молоко сгущенное Главпродукт ГОСТ, ж.б., 380 г'),
#  Document(doc_id=173392263, name='Растительное молоко овсяное Take a Bite, без сахара, безлактозное, 6 шт по 1 л'),
#  Document(doc_id=1575354761, name='Хлопья Быстров овсяные с малиной и молоком, не требующие варки, 240 г'),
#  Document(doc_id=1627939217, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=138133907, name='Sen Soy Кокосовое молоко 5-7%, 400 мл'),
#  Document(doc_id=605053331, name='Творожный продукт из козьего молока "Творожный крем" с черникой, 11%-18%, LavkaLavka, 150 г'),
#  Document(doc_id=1574224279, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=765198754, name='Молоко ультрапастеризованное 3,2%  950 мл, Фрау Му'),
#  Document(doc_id=1576485283, name='Молоко Агрокомплекс питьевое пастеризованное, 1%, 900 мл'),
#  Document(doc_id=1597153707, name='Сливки ультрапастеризованные 10%, 125 мл, Вкуснотеево'),
#  Document(doc_id=174416300, name='Молоко Viola UHT, 3,2%, 1 л х 12 шт'),
#  Document(doc_id=1617019308, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1597153708, name='Сливки ультрапастеризованные 20%, 125 мл, Вкуснотеево'),
#  Document(doc_id=600850869, name='Сырок творожный глазированный в молочном шоколаде с молоком сгущенным вареным 26% 50 г, А.РОСТАГРОКОМПЛЕКС'),
#  Document(doc_id=1575780815, name='Молоко Parmalat Comfort, безлактозное, 1,8%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=641991132, name='Шоколад Карамельный натуральный полезный  веган веганский без сахара без глютена без сои без молока 50 гр'),
#  Document(doc_id=1576288733, name='Молоко Стерилизованное Село Зеленое 2,5 % 0,95 л х 12 шт. Уцененный товар'),
#  Document(doc_id=141165025, name='Молоко ультрапастеризованное Простоквашино, 3,2%, 950 мл'),
#  Document(doc_id=180437474, name='Молоко Parmalat Comfort 1,8%, безлактозное, 200 мл х 24 шт'),
#  Document(doc_id=141165031, name='Молоко детское Тема 3,2%, 200 мл'),
#  Document(doc_id=141165033, name='Молоко Тема детское 3,2% с 3 лет, 500мл'),
#  Document(doc_id=1145651693, name='Капучинатор с подставкой SIMPLE KITCHEN, электрический вспениватель молока и взбиватель яиц, ручной мощный электровенчик (SK_MF1)'),
#  Document(doc_id=384532974, name='"Питьевой йогурт" на кокосовом "молоке" Sooperfoods, клубника-банан, 300 мл'),
#  Document(doc_id=1511956975, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=141165038, name='Сливки Петмол, ультрапастеризованные, 11%, 500 мл'),
#  Document(doc_id=170222065, name='Торт Птичье молоко Советская классика 600 г, Черемушки'),
#  Document(doc_id=170222066, name='Торт "Птичье молоко", с халвой 600 г, Черемушки'),
#  Document(doc_id=1440080370, name='Сыр твердый по-итальянски Гаудита Ешь Деревенское, 45%, из коровьего молока, 210 г'),
#  Document(doc_id=1440080372, name='Сыр полутвердый Хавартио по-итальянски Ешь Деревенское, 55%, из коровьего молока, 210 г'),
#  Document(doc_id=141165041, name='Сливки Петмол, ультрапастеризованные, 22%, 1 л'),
#  Document(doc_id=355402233, name='Село Зеленое Молоко Ультрапастеризованное 0.032% 950мл.'),
#  Document(doc_id=1551041038, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1480606225, name='Parmalat Молоко Ультрапастеризованное 1.8% 1000мл. 12шт. Уцененный товар'),
#  Document(doc_id=357245459, name='Капучинатор и вспениватель для молока и кофе ( электрический, ручной, беспроводной мини миксер )'),
#  Document(doc_id=1511957022, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1613578786, name='Молочная смесь Nestle NAN 3 с 1 года, на основе козьего молока, 400 г. Уцененный товар'),
#  Document(doc_id=1612554787, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1612554788, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1612554790, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1575117352, name='Каша быстрого приготовления Увелка овсяная Ассорти с ягодами и молоком, 6 пакетиков по 40 г, 240 г. Уцененный товар'),
#  Document(doc_id=1145651761, name='Капучинатор с подставкой SIMPLE KITCHEN, электрический вспениватель молока и взбиватель яиц, ручной мощный электровенчик (SK_MF1)'),
#  Document(doc_id=1529160264, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=724894287, name='Кокосовая сгущенка без сахара с лавандой ORGANIC LAB пп сладости, сгущенное молоко из кокосового урбеча, 220 гр.'),
#  Document(doc_id=1479058023, name='Растительное молоко кокосовое, 2,0% 1 л, Zinus Barista'),
#  Document(doc_id=1641808489, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1479058028, name='Растительное молоко миндальное 2,0% 1 л Zinus Barista'),
#  Document(doc_id=1479058030, name='Растительное молоко банановое 2,0%, 1 л, Zinus Barista, на кокосовом молоке'),
#  Document(doc_id=1479058032, name='Растительное молоко кокосовое 1,8% 1 л Zinus'),
#  Document(doc_id=1655014006, name='Каша быстрого приготовления Ясно солнышко овсяная с клубникой и молоком, 45 г х 15 шт. Уцененный товар'),
#  Document(doc_id=1465451154, name='Село Зеленое Молоко Ультрапастеризованное 3.2% 950мл. 12шт. Уцененный товар'),
#  Document(doc_id=1617167003, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1479058081, name='Растительное молоко миндальное 1,8% 1 л Zinus'),
#  Document(doc_id=1640587938, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1161839268, name='Молоко сгущенное Коровка из Кореновки с сахаром и какао, 5,0%, 270 г'),
#  Document(doc_id=794935979, name='Вафельный рожок Здоровый Рожок сливочный со сгущеным молоком 120 г, Коровка из Кореновки'),
#  Document(doc_id=1640587956, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1575355072, name='Хлопья Быстров овсяные с клубникой и молоком, не требующие варки, 240 г'),
#  Document(doc_id=239026893, name='Кокосовое молоко FOCO без добавок, жирность 10-12%, 400 мл х 2 шт'),
#  Document(doc_id=1615479506, name='Каша быстрого приготовления Ясно солнышко овсяная с клубникой и молоком, 45 г х 15 шт. Уцененный товар'),
#  Document(doc_id=284189403, name='Молоко верблюжье в капсулах 60 шт гипоаллергенное БАД для укрепления иммунитета, антиоксидант халяль'),
#  Document(doc_id=1404633830, name='Молоко Село Зеленое ультрапастеризованное 2,5%, 12 шт х 0,95 л'),
#  Document(doc_id=1417503471, name='Молоко ультрапастеризованное Славянские Кружева 3,2% 973 мл '),
#  Document(doc_id=1417503473, name='Молоко ультрапастеризованное Славянские Кружева 2,5% 973 мл '),
#  Document(doc_id=1417503475, name='Молоко ультрапастеризованное Славянские Кружева 1,5 % 973 мл '),
#  Document(doc_id=637862648, name='Молокоотсос электрический / двойной, для сцеживания молока, 9 режимов'),
#  Document(doc_id=589079289, name='Молоко 3,4%-6,0% 720 г, Кубанский Молочник'),
#  Document(doc_id=1465197308, name='ЭкоНива Молоко Стерилизованное 3.2% 1000мл. 12шт. Уцененный товар'),
#  Document(doc_id=1062699773, name='Молоко 3,2%, 1400 мл, Простоквашино, пастеризованное'),
#  Document(doc_id=145589002, name='Сливки ультрапастеризованные 33% 500 мл, Петмол,'),
#  Document(doc_id=145589003, name='Сливки ультрапастеризованные 33% 1 л, Петмол'),
#  Document(doc_id=1451295515, name='Каша быстрого приготовления Увелка овсяная Ассорти с ягодами и молоком, 6 пакетиков по 40 г, 240 г. Уцененный товар'),
#  Document(doc_id=740360989, name=' Сухое молоко 300г. 1шт.'),
#  Document(doc_id=357589791, name='Капучинатор iSottcom для молока и сливок, латте ручной электрический , подарочный набор 4 в 1: мини-миксер с подставкой, питчер, трафарет для кофе'),
#  Document(doc_id=987087662, name='Молоко цельное 3,2-4,0%, 950 мл, Калининское, пастеризованное'),
#  Document(doc_id=987087665, name='Молоко 2,5%, 950 мл, Калининское, пастеризованное'),
#  Document(doc_id=1545839409, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=987087681, name='Молоко 3,2%, 930 мл, Калининское, пастеризованное'),
#  Document(doc_id=536879962, name='Протеиновое печенье без сахара "Butter Wave" Топленое молоко (коробка из 8 упаковок по 4 штуки), 288 гр'),
#  Document(doc_id=170074971, name='Молоко цельное отборное 3,4 - 4,5%, 900 мл, Экомилк, пастеризованное'),
#  Document(doc_id=170074972, name='Молоко 3,2%, 930 мл, Экомилк, пастеризованное'),
#  Document(doc_id=684991324, name='Капучинатор мини миксер для взбивания ручной вспениватель молока сливок венчик кухонный взбиватель'),
#  Document(doc_id=1581835108, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=247317352, name='Шоколад молочный на овсяном молоке Без сахара Набор 2 шт. Без лактозы Веган продукт ручной работы / GreenMania веганский, без лактозы, постный, натуральный'),
#  Document(doc_id=285033322, name='AVON / Четырехцветные тени для век "Безупречный цвет", Мокко с молоком/Mocha Latte'),
#  Document(doc_id=1609917305, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1461502847, name='Село Зеленое Молоко Ультрапастеризованное 3.2% 950мл. 12шт. Уцененный товар'),
#  Document(doc_id=465388420, name='Сыр Качотта с пажитником из козьего молока Фермерская сыроварня Осташево, 150 г'),
#  Document(doc_id=172622743, name='Молоко Белый Город, стерилизованное, 3,2%, 1 л х 16 шт'),
#  Document(doc_id=1567269783, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=178324381, name='Молоко Parmalat UHT Comfort, безлактозное, 0,05%, 1 л х 12 шт'),
#  Document(doc_id=178324382, name='Молоко Parmalat UHT Comfort, безлактозное, 3,5%, 1 л х 12 шт'),
#  Document(doc_id=1560814503, name='Молоко Parmalat Comfort, безлактозное, 1,8%, 1 л. Уцененный товар'),
#  Document(doc_id=301007786, name='Хорошее дело Молоко Стерилизованное 2.5% 950мл. 1шт.'),
#  Document(doc_id=1560814506, name='Молоко Parmalat Comfort, безлактозное, 1,8%, 1 л. Уцененный товар'),
#  Document(doc_id=1430225836, name='Сырники с вареным сгущенным молоком Creative Kitchen,120 г'),
#  Document(doc_id=1616233399, name='Молоко Агуша обогащенное витаминами и йодом 2.5% 200мл с 8 месяцев X18. Уцененный товар'),
#  Document(doc_id=1640465341, name='Молоко Parmalat Comfort, безлактозное, 1,8%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=315270083, name='KAPOUS Studio Professional Шампунь для всех типов волос Молоко и мед 1000 мл Aromatic Symphony'),
#  Document(doc_id=231293892, name='Aroy-d Кокосовое молоко 70% жирность 17-19%, 500 мл x 2 шт'),
#  Document(doc_id=256287695, name='Десерт чиа с манго на кокосовом молоке Азбука вкуса, 180 г'),
#  Document(doc_id=301007843, name='Хорошее дело Молоко Стерилизованное 3.2% 950мл. 1шт.'),
#  Document(doc_id=141927409, name='Вспениватель молока Kitfort КТ-709, White'),
#  Document(doc_id=298386422, name='Натуральный жидкий сычужный фермент для приготовления сыра 20 мл на 100 л молока'),
#  Document(doc_id=1581556729, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=170075133, name='Молоко Экомилк, пастеризованное, 3,2%, 1,5 л'),
#  Document(doc_id=384893949, name='"Греческий йогурт" на кокосовом "молоке" Sooperfoods натуральный, 160 г'),
#  Document(doc_id=414786561, name='Конфеты шоколадные Рот Фронт Птичье молоко, сливочно-ванильные, 200 г'),
#  Document(doc_id=1329079332, name='Сгущенное молоко цельное с сахаром 8,5% 250 мл, Ozon fresh, ГОСТ'),
#  Document(doc_id=562398250, name='Растительное молоко ореховое миндальное Zinus 1л'),
#  Document(doc_id=943268942, name='Молоко сгущенное Белый Медведь цельное с сахаром  8,5% дой-пак, 270 г'),
#  Document(doc_id=1567982677, name='Молочная смесь Бибиколь Нэнни козье молоко 3, с 12 месяцев, 800 г. Уцененный товар'),
#  Document(doc_id=1406985311, name='Каша на козьем молоке детская Fleur Alpine Рисовая, с 4 месяцев, 200 г. Уцененный товар'),
#  Document(doc_id=144311416, name='Большая Кружка Молоко Ультрапастеризованное 2.5%'),
#  Document(doc_id=144311417, name='Большая Кружка Молоко Ультрапастеризованное 3.2% 980мл.'),
#  Document(doc_id=244515961, name='Кокосовое молоко AROY-D жирность 19%, 250 мл, tetra pak, 6 шт'),
#  Document(doc_id=144311421, name='Большая Кружка Молоко Ультрапастеризованное 2.5%'),
#  Document(doc_id=144311422, name='Большая Кружка Молоко Ультрапастеризованное 3.2%'),
#  Document(doc_id=1583858814, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1668793469, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=615605380, name='Батончик полезный натуральный веганский без рафинированного сахара глютена без сои без молока на кешью ореховая нуга шоколад "Карамельный" bob, 49 г'),
#  Document(doc_id=310469772, name='Десерт без сахара Сгущёнка Иван-поле, пп сгущеное молоко 200г'),
#  Document(doc_id=1661338779, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=158024880, name='Белый Город Молоко Стерилизованное 1.5% 1000мл. 1шт.'),
#  Document(doc_id=158024882, name='Сливки ультрапастеризованные 23%, 0,5 л, Parmalat'),
#  Document(doc_id=195331251, name='Торт "Птичье молоко", с халвой 600 г, Черемушки'),
#  Document(doc_id=1492976818, name='Село Зеленое Молоко Ультрапастеризованное 3.2% 950мл. 12шт. Уцененный товар'),
#  Document(doc_id=1496958130, name='ЭкоНива Молоко Стерилизованное 2.5% 1000мл. 12шт. Уцененный товар'),
#  Document(doc_id=1452975286, name='Каша быстрого приготовления Увелка овсяная Ассорти с ягодами и молоком, 6 пакетиков по 40 г, 240 г. Уцененный товар'),
#  Document(doc_id=1586382006, name='Молочная смесь Nestle NAN с рождения до 12 месяцев, на козьем молоке, 400 г. Уцененный товар'),
#  Document(doc_id=1587586228, name='Молоко ФрутоНяня ультрапастеризованное (м.д.ж. 2,5%), 0.2 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1492976826, name='Село Зеленое Молоко Ультрапастеризованное 3.2% 950мл. 12шт. Уцененный товар'),
#  Document(doc_id=863798467, name='Сыр Бюш мягкий с ананасом и миндалем 50%, 140 г, Егорлык Молоко'),
#  Document(doc_id=195331272, name='Молоко топленое 3,2%, 930 мл, Простоквашино'),
#  Document(doc_id=863798472, name='Сыр Бюш мягкий с папайя и фундуком 50%, 140 г, Егорлык Молоко'),
#  Document(doc_id=195331282, name='Сыр Ko & Co Бюш Де Шевр, мягкий, из козьего молока, с плесенью, в золе, 85 г'),
#  Document(doc_id=1575355603, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1486300379, name='ЭкоНива Молоко Стерилизованное 3.2% 1000мл. 12шт. Уцененный товар'),
#  Document(doc_id=264398053, name='Шоколад Аленка много молока, 90 г'),
#  Document(doc_id=1631438060, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=265143538, name='Сухое молоко цельное 26% жирности 1000г, 1 кг'),
#  Document(doc_id=1032594689, name='Молочная смесь Бибиколь Нэнни с пребиотиками 2, с 6 месяцев, на основе козьего молока, 800 г'),
#  Document(doc_id=1549575429, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=195331359, name='Сыр Ko & Co Бюш Де Шевр, мягкий, из козьего молока, с белой плесенью, в золе Валансе, 150 г'),
#  Document(doc_id=168666402, name='Молоко безлактозное 1,8% 1 л, Parmalat Comfort'),
#  Document(doc_id=1674863908, name='Молоко Агуша обогащенное витаминами и йодом 2.5% 200мл с 8 месяцев X18. Уцененный товар'),
#  Document(doc_id=1556792613, name='Капучинатор для молока Hyundai HMF-P300 кремовый 300мл. Уцененный товар'),
#  Document(doc_id=1632904500, name='Напиток из растительного сырья  овсяный 1 л, Здоровое меню, обогащенный Ca и витаминами, ультрапастеризованный'),
#  Document(doc_id=181167420, name='Молоко ФрутоНяня, обогащенное, 2,5%, с 8 месяцев, 12 шт по 200 мл'),
#  Document(doc_id=1485669692, name='ЭкоНива Молоко Стерилизованное 3.2% 1000мл. 12шт. Уцененный товар'),
#  Document(doc_id=618808640, name='Молоко козье Lactica цельное 2,8-4,0%, 200 мл'),
#  Document(doc_id=1618765125, name='Молоко ультрапастеризованное 1,8% Parmalat, 12 шт х 1 л. Уцененный товар'),
#  Document(doc_id=1430259029, name='Parmalat Молоко Ультрапастеризованное 1.8% 1000мл. 12шт. Уцененный товар'),
#  Document(doc_id=296396134, name='Сироп без сахара Сгущёное молоко "Ноль грамм", 330г (низкокалорийный топинг для мороженного, выпечки или коктейлей)'),
#  Document(doc_id=1639941483, name='Молоко ультрапастеризованное 1,8% Parmalat, 12 шт х 1 л. Уцененный товар'),
#  Document(doc_id=662152564, name='Набор кофе в капсулах Tassimo Кофе с молоком, 5 упаковок'),
#  Document(doc_id=1555760500, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1411761534, name='Молоко ультрапастеризованное 3,2% 1 л, Милушка'),
#  Document(doc_id=1442276737, name='Сыр сливочный со вкусом топлёного молока, 45 - 50 %, 0,9 - 1,3 кг, Ozon fresh'),
#  Document(doc_id=1408492935, name='Каша рисовая "Волконский" на кокосовом молоке с ганашем из белого шоколада и маракуйи 250 г'),
#  Document(doc_id=1442276745, name='Сыр сливочный со вкусом топлёного молока, 45 - 50 %, 0,9 - 1,05 кг, Ozon fresh'),
#  Document(doc_id=1442276752, name='Сыр сливочный со вкусом топлёного молока, 45 - 50 %, 1,05 - 1,2 кг, Ozon fresh'),
#  Document(doc_id=157943187, name='Valio Молоко Ультрапастеризованное 3.5% 1000мл. 1шт.'),
#  Document(doc_id=210158999, name='Капучинатор для молока ручной FACKELMANN Barista 20 см электрический вспениватель, мини миксер для кофе, венчик, взбиватель беспроводной для капучино, латте, матча'),
#  Document(doc_id=242681244, name='Растительное молоко 150 мл, Kati, кокосовые сливки'),
#  Document(doc_id=612689331, name='Капучинатор Kitfort КТ-786-1, лавандовый, вспениватель молока, 500 Вт, чаша 240 мл, антипригарное покрытие, 4 режима работы, 2 насадки для вспенивания и смешивания'),
#  Document(doc_id=1180771764, name='Крем-десерт с молоком сгущенным вареным 25% 40 г, сливочный Коровка из Кореновки глазированный в вафельном рожке'),
#  Document(doc_id=142624198, name='Пюре овощное Бабушкино лукошко с 6 месяцев, кабачок молоко, 100 г x 6'),
#  Document(doc_id=411796973, name='Молоко топленное 2,5%, 800 мл, МСК-Волжский'),
#  Document(doc_id=154330611, name='Сливки пастеризованные 10%, 250 г, Рузское молоко'),
#  Document(doc_id=411796980, name='Молоко 3,2%, 900 мл, МСК-Волжский, пастеризованное'),
#  Document(doc_id=154330613, name='Сметана 15% 175 г, Рузское молоко'),
#  Document(doc_id=154330614, name='Сметана 20% 175 г, Рузское молоко'),
#  Document(doc_id=154330615, name='Сметана 25%, 175 г, Рузское молоко'),
#  Document(doc_id=229729782, name='"Растительный напиток Valsoia соевый ""Бариста"" ультрапастеризованный с кальцием и витаминами, 1 л"'),
#  Document(doc_id=1411761674, name='Молоко ультрапастеризованное 2,5% 1 л, Милушка'),
#  Document(doc_id=1512179223, name='Молоко Агуша обогащенное витаминами и йодом 2.5% 200мл с 8 месяцев X18. Уцененный товар'),
#  Document(doc_id=1615341081, name='Рисовая каша на кокосовом молоке 220 г, Creative Kitchen'),
#  Document(doc_id=1659569699, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1567983142, name='Молочная смесь Бибиколь Нэнни козье молоко 3, с 12 месяцев, 800 г. Уцененный товар'),
#  Document(doc_id=171820606, name='ErickHauser, Капучинатор, вспениватель молока, мини миксер, взбиватель молока'),
#  Document(doc_id=531899966, name='Капучинатор / Вспениватель для молока /  Мини-миксер для капучино, латте / Капучинатор ручной/ Венчик для взбивания молока и сливок / Взбиватель для яиц'),
#  Document(doc_id=1624204872, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1566410321, name='Сыр Сернурский Рецепт №1 Авторский из коровьего, козьего и овечьего молока, 50%, 200 г'),
#  Document(doc_id=501007954, name='Капучинатор ; Капучинатор для приготовление напитков и молока ; Венчик ручной'),
#  Document(doc_id=1566410323, name='Сыр Сернурский Рецепт №1 Авторский с грецким орехом, из коровьего, козьего и овечьего молока 45%, 200 г'),
#  Document(doc_id=1676887645, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=173491816, name='Молоко безлактозное 1,8% 1 л х 12 шт, Parmalat Comfort'),
#  Document(doc_id=173491817, name='Молоко безлактозное 1,8% 1 л, Parmalat Comfort'),
#  Document(doc_id=958072425, name='SHOCKS! Протеиновое печенье Брауни без сахара Кофе с молоком, 9 шт'),
#  Document(doc_id=1610933888, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1676019329, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1421428353, name='Вспениватель молока Kitfort КТ-710. Уцененный товар'),
#  Document(doc_id=1566410374, name='Сыр Марсенталь Арабеск из козьего молока 50%, 150 г, Сернур'),
#  Document(doc_id=1650484886, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=178259607, name='Чай зеленый МАТЧА-ЛАТТЕ КОКОС без сахара, на сухом кокосовом молоке, 50 г. MUTE'),
#  Document(doc_id=1514735257, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=178259626, name='Чай зеленый МАТЧА-ЛАТТЕ КОКОС без сахара, на сухом кокосовом молоке, 100 г. MUTE'),
#  Document(doc_id=544147121, name='Термометр кулинарный электронный SimpleShop с выносным щупом для жидкости и еды/ Термощуп для мяса, рыбы, молока, вина, воды/ Щуп термометр из нержавеющей стали 17 см/ Таймер кухонный на батарейках'),
#  Document(doc_id=1633298097, name='Молоко Агуша 3,2% 925 мл с 3 лет X12. Уцененный товар'),
#  Document(doc_id=1633298098, name='Молоко Агуша 3,2% 925 мл с 3 лет X12. Уцененный товар'),
#  Document(doc_id=1633298101, name='Молоко Агуша 3,2% 925 мл с 3 лет X12. Уцененный товар'),
#  Document(doc_id=1421575865, name='Сосиски с молоком 350 г, Дым Дымыч'),
#  Document(doc_id=155944641, name='Молоко 973 мл, Viola UHT 3,2%'),
#  Document(doc_id=340453076, name='Молоко цельное сгущенное Коровка из Кореновки, 270 г'),
#  Document(doc_id=1180772052, name='Крем-десерт с молоком сгущенным вареным какао 25% 40 г, сливочный Коровка из Кореновки глазированный в вафельном рожке'),
#  Document(doc_id=172893911, name=' Едим с пользой Сухое молоко 400г. 1шт.'),
#  Document(doc_id=1180772055, name='Крем-десерт сливочный Коровка из Кореновки с молоком сгущенным вареным с кокосом глазированный в вафельном рожке 19%, 40 г.'),
#  Document(doc_id=1566410461, name='Сыр полутвердый с козьим молоком 50%, 150 г, Сернурский'),
#  Document(doc_id=1566410462, name='Сыр Сернурский Рецепт №1 Авторский из коровьего, козьего и овечьего молока, с трюфелем, 45%, 200 г'),
#  Document(doc_id=184264428, name='Сыр KO&CO Камамбер 150 г, мягкий, из козьего молока, с белой плесенью'),
#  Document(doc_id=184264429, name='Сыр Ko & Co Бюш Де Шевр, мягкий, из козьего молока, в прованских травах, 110 г'),
#  Document(doc_id=184264430, name='Сыр KO&CO Бюш Де Шевр 100 г, мягкий, из козьего молока, с белой плесенью'),
#  Document(doc_id=184264432, name='Сыр Ko & Co Бюш Де Шевр, мягкий, из козьего молока, свежий, 110 г'),
#  Document(doc_id=184264433, name='Сыр Ko & Co Бюш Де Шевр, мягкий, из козьего молока, с белой плесенью, в золе Валансе, 150 г'),
#  Document(doc_id=184264434, name='Сыр Ko & Co Бюш Де Шевр 100 г, Ko&Co, мягкий, из козьего молока, с плесенью, в золе Пепельный конус'),
#  Document(doc_id=184264435, name='Сыр Ko & Co Бюш Де Шевр, мягкий, из козьего молока, с плесенью, в золе, 85 г'),
#  Document(doc_id=249366273, name='Золотое молоко Куркума Латте суперфуд без кофеина,веган,100 гр.'),
#  Document(doc_id=1623287573, name='Молоко пастеризованное 2,8% - 5,6% 200 г, Козочка с Облачка'),
#  Document(doc_id=1162741528, name='Капучинатор и вспениватель молока электрический для капучино Oberhof Milchschumer IX-35 / вспениватель молочной пенки, 4 режима, объем 300 мл'),
#  Document(doc_id=1649927966, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1668056870, name='Молоко питьевое ультрапастеризованное Село Зеленое Edge, безлактозное м.д.ж. 1,8%, 0,95 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1609140015, name='Медвежонок Барни Пирожное с молоком, 150 г. Уцененный товар'),
#  Document(doc_id=1629398831, name='Молоко детское Тема 3,2%, 18 шт х 200 мл. Уцененный товар'),
#  Document(doc_id=969189169, name='Вспениватель молока Kitfort КТ-758, серый металлик, капучинатор. Уцененный товар'),
#  Document(doc_id=985335612, name='Кофе в зернах Lebo ESPRESSO MILKY Арабика 50%, робуста 50% , БЛЕНД ПОД МОЛОКО 220 г'),
#  Document(doc_id=1622837052, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1032652608, name='Каша кукурузная детская БИБИКАША с 5 месяцев, козье молоко, сухая, 200 г'),
#  Document(doc_id=226977633, name='KUNDER Подогреватель стерилизатор для бутылочек и сосок, молокоотсоса / разморозка молока, детского питания / стерилизация бутылок, посуды для новорожденных'),
#  Document(doc_id=1623287651, name='Молоко ультрапастеризованное 2,8% - 5,6% 200 г, Козочка с Облачка'),
#  Document(doc_id=1653065594, name='Молоко детское Тема 3,2%, 18 шт х 200 мл. Уцененный товар'),
#  Document(doc_id=1653065596, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1481738118, name='Каша быстрого приготовления Увелка овсяная Ассорти с ягодами и молоком, 6 пакетиков по 40 г, 240 г. Уцененный товар'),
#  Document(doc_id=1581164434, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=172173218, name='Сок с молоком Мажитэль Персик-Маракуйя 0,05%, 950 г x 12 шт'),
#  Document(doc_id=332310439, name='Сухое молоко цельное 600 гр'),
#  Document(doc_id=1526933417, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=172173227, name='Домик в Деревне Молоко Ультрапастеризованное 3.2% 950мл. 12шт.'),
#  Document(doc_id=1540130732, name='Молоко ультрапастеризованное 1,8% Parmalat, 12 шт х 1 л. Уцененный товар'),
#  Document(doc_id=172173229, name='Домик в Деревне Молоко Ультрапастеризованное 2.5% 950мл. 12шт.'),
#  Document(doc_id=1446520749, name='ЭкоНива Молоко Стерилизованное 3.2% 1000мл. 12шт. Уцененный товар'),
#  Document(doc_id=172173233, name='Сок с молоком Мажитэль Мультифрукт 0,05%, 950 г x 12 шт'),
#  Document(doc_id=172173236, name='Домик в Деревне Молоко Ультрапастеризованное 3.5% 950мл. 12шт.'),
#  Document(doc_id=142731191, name='Из Вологды Молоко Ультрапастеризованное 3.2% 1000мл. 1шт.'),
#  Document(doc_id=142731192, name='Из Вологды Молоко Ультрапастеризованное 3.2% 200мл. 1шт.'),
#  Document(doc_id=141133760, name='Шоколад Ritter Sport "Альпийское молоко" с альпийским молоком, 100 г'),
#  Document(doc_id=1674864576, name='Молоко Агуша обогащенное витаминами и йодом 2.5% 200мл с 8 месяцев X18. Уцененный товар'),
#  Document(doc_id=135456706, name='Набор контейнеров c герметичными крышками для грудного молока Philips Avent SCF618/10 180 мл, 10 шт'),
#  Document(doc_id=1551132624, name="Смесь МАМАКО 2 Premium, 800 г, с 2'-FL на козьем молоке. Уцененный товар"),
#  Document(doc_id=1551132631, name="Смесь МАМАКО 2 Premium, 800 г, с 2'-FL на козьем молоке. Уцененный товар"),
#  Document(doc_id=346769368, name='Тыквенный суп на кокосовом молоке Крафтовая кухня, 330 г'),
#  Document(doc_id=958613479, name='Сыр полутвердый BURЁNKA CLUB Марсенталь Арабеск из козьего молока, 50%, 125 г'),
#  Document(doc_id=1452713977, name='Parmalat Молоко Ультрапастеризованное 1.8% 1000мл. 12шт. Уцененный товар'),
#  Document(doc_id=186566657, name='Капучинатор ZESTEN, вспениватель молока (мини-миксер) на подставке, батарейки в комплекте'),
#  Document(doc_id=148170755, name='Млекоин Недостаток молока гранулы гомеопатические, 10 г'),
#  Document(doc_id=186566664, name='Капучинатор ZESTEN, вспениватель молока (мини-миксер) на подставке, батарейки в комплекте'),
#  Document(doc_id=196528143, name='Беспроводной капучинатор / портативный ручной вспениватель для молока Ecotone Delish с USB зарядным устройством и двумя венчиками / вспениватель молока (белый)'),
#  Document(doc_id=1089030176, name='Сыр мягкий Корова в масле 50%, 90 г, Егорлык Молоко'),
#  Document(doc_id=221505576, name='Молоко сгущенное с сахаром и какао Любинское, 380 г'),
#  Document(doc_id=1089030195, name='Сыр мягкий с пряностями и зеленью 50% , 90 г, Егорлык Молоко Корова, в масле'),
#  Document(doc_id=1652238389, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=307054653, name='Сливки Lactica, ультрапастеризованные, 10%, 500 мл'),
#  Document(doc_id=307054654, name='Сливки Lactica, ультрапастеризованные, 22%, 500 мл'),
#  Document(doc_id=1523312703, name='Молоко ультрапастеризованное 1,8% Parmalat, 12 шт х 1 л. Уцененный товар'),
#  Document(doc_id=326322260, name='Круассан со сгущенным молоком высший сорт, 75г'),
#  Document(doc_id=1565706330, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=590866536, name='Молоко 2,5%, 0,9 л, Сернур, ГОСТ, пастеризованное'),
#  Document(doc_id=590866537, name='Молоко 3,2%, 0,9 л, Сернур, ГОСТ, пастеризованное'),
#  Document(doc_id=829294701, name='Капучинатор вспениватель молока Raygood.'),
#  Document(doc_id=816965744, name='Капучинатор электрический мощный вспениватель для молока Bersecco Quattro M4'),
#  Document(doc_id=505792649, name='Питчер для молока, сливочник, молочник из пищевой нержавеющей стали - 150 мл'),
#  Document(doc_id=595822738, name='Молочная смесь Nestle NAN с рождения до 12 месяцев, на козьем молоке, 400 г'),
#  Document(doc_id=302475410, name='Крем сливочный President, для соуса, ультрапастеризованный, 23%, 200 г'),
#  Document(doc_id=1603889300, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=302475411, name='Крем сливочный President, для соуса, ультрапастеризованный, 23%, 500 г'),
#  Document(doc_id=140675230, name='Амалтея Молоко козье цельное сухое, 400 г'),
#  Document(doc_id=140675231, name='Каша гречневая детская Бибикаша с 4 месяцев, козье молоко, сухая, 200 г'),
#  Document(doc_id=140675232, name='Каша овсяная детская Бибикаша с 5 месяцев, козье молоко, сухая, 200 г'),
#  Document(doc_id=140675233, name='Каша рисовая детская Бибикаша с 4 месяцев, козье молоко, сухая, 200 г'),
#  Document(doc_id=140675234, name='Каша кукурузная детская Бибикаша с 5 месяцев, козье молоко, сухая, 200 г'),
#  Document(doc_id=1547872421, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=223692972, name='Молоко отборное 3,4%- 4,5%, 930 г, Чабан'),
#  Document(doc_id=743925955, name='Сырок творожный глазированный со сгущенным молоком 18%, 40 г, Коровка из Кореновки'),
#  Document(doc_id=265144517, name='Сухое молоко обезжиренное 1000 гр, 1 кг'),
#  Document(doc_id=245598422, name='Капучинатор для молока электрический, ручной, беспроводной / Мини миксер / Вспениватель для кофе ENERGY'),
#  Document(doc_id=743925978, name='Молоко питьевое, пастеризанное 2,7% 900 мл Коровка из КореновкиПЭТ'),
#  Document(doc_id=847169756, name='Капучинатор и вспениватель для молока электрический, ручной, беспроводной / Мини миксер / GeoLuK Milk Frother'),
#  Document(doc_id=1032644831, name='Каша гречневая детская БИБИКАША с 4 месяцев, козье молоко, сухая, 200 гр.'),
#  Document(doc_id=1639942368, name='Молоко ультрапастеризованное 1,8% Parmalat, 12 шт х 1 л. Уцененный товар'),
#  Document(doc_id=1440524529, name='Капучинатор и вспениватель молока электрический для капучино Oberhof Milchschumer IX-17 / вспениватель молочной пенки, 3 скорости, емкость батареи 1200 мАч. Уцененный товар'),
#  Document(doc_id=1569900799, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=595822850, name='Молочная смесь Nestle NAN 3 с 1 года, на основе козьего молока, 400 г'),
#  Document(doc_id=1432946965, name='ЭкоНива Молоко Стерилизованное 3.2% 1000мл. 12шт. Уцененный товар'),
#  Document(doc_id=1581058334, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1444538668, name='Parmalat Молоко Ультрапастеризованное 1.8% 1000мл. 12шт. Уцененный товар'),
#  Document(doc_id=179185965, name='Сыр творожный Козий Chevre, из козьего молока 140 г, President'),
#  Document(doc_id=798378291, name='Капучинатор / вспениватель молока для кофе / мини миксер'),
#  Document(doc_id=1655785786, name='Хлопья Быстров овсяные с малиной и молоком, не требующие варки, 240 г. Уцененный товар'),
#  Document(doc_id=384149827, name='Молоко Село Домашкино пастеризованное, 3,2%, 900 мл'),
#  Document(doc_id=1523091784, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1525713228, name='Капучинатор электрический, вспениватель молока и взбиватель яиц, ручной мощный электровенчик. Уцененный товар'),
#  Document(doc_id=1339042134, name='Вспениватель молока Kitfort КТ-758, серый металлик, капучинатор. Уцененный товар'),
#  Document(doc_id=441182554, name='Мороженое на кокосовом молоке Warm Ice "Прованские травы", 80 г'),
#  Document(doc_id=1636026718, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1511721311, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1659513184, name='Капучинатор для молока Hyundai HMF-P300 кремовый 300мл. Уцененный товар'),
#  Document(doc_id=1555237222, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=260270447, name='Aroy-d Кокосовое молоко 70% жирность 17-19%, 500 мл x 4 шт'),
#  Document(doc_id=1591167346, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1581541759, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1514908036, name='Вспениватель молока Kitfort КТ-710. Уцененный товар'),
#  Document(doc_id=1671195012, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1166723462, name='Молоко пастеризованное 3,2-4,0% 2 л ПравильноеМолоко'),
#  Document(doc_id=285378961, name='Кокосовое молоко FOCO органическое БЕЗ ДОБАВОК, жирность 10-12%, 400 мл х 4 шт'),
#  Document(doc_id=609077649, name='Средство JURA для очистки системы приготовления молока (микрогранулы) 24158'),
#  Document(doc_id=1654565283, name='Молоко Parmalat Comfort, безлактозное, 1,8%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1674865062, name='Молоко Агуша обогащенное витаминами и йодом 2.5% 200мл с 8 месяцев X18. Уцененный товар'),
#  Document(doc_id=229157298, name=' New Milky Extra Сухое молоко 1000г. 1шт.'),
#  Document(doc_id=260336065, name='Кокосовое молоко Aroy-D, 70%, жирность 17-19%, 1 л х 4 шт'),
#  Document(doc_id=365144523, name='MUKUNGHWA Мыло с молоком, 90 г'),
#  Document(doc_id=1492019667, name='ЭкоНива Молоко Стерилизованное 3.2% 1000мл. 12шт. Уцененный товар'),
#  Document(doc_id=1467976151, name='Село Зеленое Молоко Ультрапастеризованное 3.2% 950мл. 12шт. Уцененный товар'),
#  Document(doc_id=1605913048, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=562276830, name='Набор капучинатор с венчиком, белый/Вспениватель для молока и сливок/для взбивания электрический беспроводной/Мини миксер для кофе латте капучино детских смесей коктейлей чая матча/'),
#  Document(doc_id=258820582, name='Пирожное бисквитное "Ломтишка" молоко 500гр., киндер делис/Акконд/ Вкус знакомый с детства.'),
#  Document(doc_id=1432947178, name='ЭкоНива Молоко Стерилизованное 2.5% 1000мл. 12шт. Уцененный товар'),
#  Document(doc_id=721488382, name='Молочная смесь Bebelac Gold 1, на основе козьего молока, с рождения, 350 г'),
#  Document(doc_id=1612581374, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=721488389, name='Молочная смесь Bebelac Gold 2, на основе козьего молока, с 6 месяцев, 350 г'),
#  Document(doc_id=185256457, name='НАБОР 6шт по 425мл. Кокосовое молоко 17-19% (Шри-Ланка) KIMPAO'),
#  Document(doc_id=1477855782, name='Молоко Агуша обогащенное витаминами и йодом 2.5% 200мл с 8 месяцев X18. Уцененный товар'),
#  Document(doc_id=1558809126, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1612532267, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1647610417, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=641206867, name='Молоко 3,2%, 750 мл, Хутор Дороганов'),
#  Document(doc_id=864733783, name='Каша Овсянка с кокосовым молоком, манго и семенами чиа Kashers, замороженная, 220 г'),
#  Document(doc_id=1675799137, name='Молоко ФрутоНяня ультрапастеризованное (м.д.ж. 2,5%), 0.2 л х 12 шт. Уцененный товар'),
#  Document(doc_id=709372520, name='Молоко Очень важная корова ультрапастеризованное 1,5%, 1л'),
#  Document(doc_id=236505711, name='Йогурт "Греческий" из овечьего молока термостатный, 4-8%, 100 г, Сернурский СЗ массовой долей жира'),
#  Document(doc_id=334867057, name='Пакеты для грудного молока, 30 шт по 250 мл'),
#  Document(doc_id=166283896, name='Молоко сгущенное 8,5% 380 г, Рогачевъ, с сахаром'),
#  Document(doc_id=166283897, name='Молоко сгущенное Рогачевъ, с сахаром, 8,5%, 270 г'),
#  Document(doc_id=1324059259, name='Молоко Ozon fresh пастеризованное, 2,5%, 900 мл'),
#  Document(doc_id=1670883963, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1578470020, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1058171539, name='Панкейки со сгущенным молоком 150 г, Бахетле'),
#  Document(doc_id=1600391828, name='Молоко Агуша обогащенное витаминами и йодом 2.5% 200мл с 8 месяцев X18. Уцененный товар'),
#  Document(doc_id=641206933, name='Молоко 2,5%, 750 мл, Хутор Дороганов'),
#  Document(doc_id=1492617881, name='Село Зеленое Молоко Ультрапастеризованное 3.2% 950мл. 12шт. Уцененный товар'),
#  Document(doc_id=1655941785, name='Ванильные панкейки со сгущенным молоком Cook Chart, 135 г'),
#  Document(doc_id=1492617890, name='Село Зеленое Молоко Ультрапастеризованное 3.2% 950мл. 12шт. Уцененный товар'),
#  Document(doc_id=1610189477, name='Молоко ультрапастеризованное 1,8% Parmalat, 12 шт х 1 л. Уцененный товар'),
#  Document(doc_id=1610189478, name='Молоко ультрапастеризованное 1,8% Parmalat, 12 шт х 1 л. Уцененный товар'),
#  Document(doc_id=1611704998, name='Молоко ультрапастеризованное 1,8% Parmalat, 12 шт х 1 л. Уцененный товар'),
#  Document(doc_id=1492617900, name='Село Зеленое Молоко Ультрапастеризованное 3.2% 950мл. 12шт. Уцененный товар'),
#  Document(doc_id=1271696057, name='Сливочное печенье со сгущённым молоком 200 г, У Палыча'),
#  Document(doc_id=1621428928, name='Молоко ультрапастеризованное 1,8% Parmalat, 12 шт х 1 л. Уцененный товар'),
#  Document(doc_id=1557170919, name='Капучинатор для молока Hyundai HMF-P300 кремовый 300мл. Уцененный товар'),
#  Document(doc_id=1640467180, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=194587386, name='Наполнитель для кошачьего туалета Japan Premium Pet комкующийся с экстрактом бамбука и японского чая (молоко кокосовое), 6 л'),
#  Document(doc_id=430918395, name="Смесь МАМАКО 1 Premium, 800 г, с 2'-FL на козьем молоке"),
#  Document(doc_id=638192386, name='Молоко 2,5%, 930 г, Чабан'),
#  Document(doc_id=1649003270, name='Молоко ультрапастеризованное ЭкоНива, 2,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1324059400, name='Молоко Ozon fresh пастеризованное, 3,2%, 900 мл'),
#  Document(doc_id=430918409, name="Смесь МАМАКО 2 Premium, 800 г, с 2'-FL на козьем молоке"),
#  Document(doc_id=605055754, name='Творожный продукт из козьего молока  "Творожный крем" с ванилином, 11%-18%, LavkaLavka, 150 г'),
#  Document(doc_id=430918419, name="Смесь МАМАКО 3 Premium, 800 г, с 2'-FL на козьем молоке"),
#  Document(doc_id=1581452058, name='Молоко ультрапастеризованное Клевер, 6%, 1 л'),
#  Document(doc_id=462998304, name='Молоко цельное сгущенное с сахаром Коровка из Кореновки 8,5%, 3 упаковки по 270 гр.'),
#  Document(doc_id=1418464039, name='Капучинатор вспениватель молока венчик для взбивания электрический usb ручной'),
#  Document(doc_id=1565035334, name='Молоко Агуша обогащенное витаминами и йодом 2.5% 200мл с 8 месяцев X18. Уцененный товар'),
#  Document(doc_id=1569065798, name='Молоко ультрапастеризованное Вологжанка, 3,2 %, 1 л'),
#  Document(doc_id=1569065801, name='Молоко ультрапастеризованное Вологжанка, 2,5 %, 1 л'),
#  Document(doc_id=147180362, name='Творог из козьего молока "Козий" Ефремовское молоко 2%, 180 г'),
#  Document(doc_id=1466469205, name='Мороженое со сгущенным молоком 180 г, I Love you, с ЗМЖ'),
#  Document(doc_id=1152420699, name='Сыр Сернур Брынза из коровьего молока 40%, 250-365 г'),
# ...
#  Document(doc_id=288888459, name=' Концепт Вкуса Сухое молоко 600г. 1шт.'),
#  Document(doc_id=282351251, name='Питчер для молока MyBarista 350мл'),
#  Document(doc_id=151000724, name='Молоко цельное сгущенное с сахаром Любимая Классика, 380 г'),
#  Document(doc_id=151000725, name='Молоко цельное сгущенное с сахаром Любимая Классика, 270 г'),
#  Document(doc_id=1575368343, name='Молоко питьевое ультрапастеризованное Село Зеленое Edge, безлактозное м.д.ж. 1,8%, 0,95 л х 12 шт. Уцененный товар'),
#  Document(doc_id=154359448, name='Молоко цельное, отборное, питьевое 3,4%-6,0% 900 мл, Коровка из Кореновки, пастеризованное'),
#  Document(doc_id=654014104, name='Ацидофильный напиток 2,5% 450 г, Просто Молоко'),
#  Document(doc_id=987403930, name='Печенье протеиновое Топленое молоко в карамельном шоколаде без сахара Butter Wave choco, 336г'),
#  Document(doc_id=654014109, name='Катык Просто Молоко 4%, 450 г'),
#  Document(doc_id=320362144, name='Молоко козье отборное 487 мл, Село Зеленое'),
#  Document(doc_id=654014112, name='Простокваша Мечниковская 4%, 450 г, Просто Молоко'),
#  Document(doc_id=1340741280, name='Смузи Be Up банан-апельсин-кокосовое молоко, 300 мл'),
#  Document(doc_id=320362149, name='Молоко 2,5% 950 мл, Село Зеленое, ультрапастеризованное'),
#  Document(doc_id=320362153, name='Молочная речка Молоко Ультрапастеризованное 3.2% 973мл. 1шт.'),
#  Document(doc_id=193975978, name='Молоко цельное 3,6-4,6% 1 л, Братья Чебурашкины, пастеризованное'),
#  Document(doc_id=1340741290, name='Смузи Be Up морковь-кокосовое молоко, 300 мл'),
#  Document(doc_id=1638790839, name='Молоко Parmalat Comfort, безлактозное, 1,8%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=612685512, name='Капучинатор Kitfort КТ-786-3, красный, вспениватель молока, 500 Вт, чаша 240 мл, антипригарное покрытие, 4 режима работы, 2 насадки для вспенивания и смешивания'),
#  Document(doc_id=1605277391, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=323270354, name='Молоко питьевое пастеризованное 2,5% 900 г, Агрокомплекс, пленка'),
#  Document(doc_id=323270355, name='Молоко питьевое пастеризованное 3,2% 900 г, Агрокомплекс, пленка'),
#  Document(doc_id=1553233618, name='Капучинатор для молока Hyundai HMF-P300 кремовый 300мл. Уцененный товар'),
#  Document(doc_id=287323869, name='Натуральный жидкий сычужный фермент для приготовления сыра 50 мл на 250 л молока'),
#  Document(doc_id=263943905, name='Мыло Fax Крем & Кокосовое молоко, 5х70 г, 2 упаковки'),
#  Document(doc_id=1543591670, name='Молоко ультрапастеризованное 1,8% Parmalat, 12 шт х 1 л. Уцененный товар'),
#  Document(doc_id=1543591673, name='Молоко Parmalat Comfort, безлактозное, 1,8%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1605277438, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1543591678, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=519534352, name='Кубанская Буренка Молоко Ультрапастеризованное 6.0% 950мл. 1шт.'),
#  Document(doc_id=1663006486, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=356464421, name='Молоко сгущённое варёное Свитлогорье с сахаром Лакомка, 380 г'),
#  Document(doc_id=559658791, name='Капучинатор беспроводной USB, вспениватель молока кофе сливок яиц матча латте шоколада, миксер ручной, венчик для взбивания электрический 2шт, бытовая техника для кухни, аксессуары для кухни,3 режима'),
#  Document(doc_id=1545049915, name='Молоко Parmalat UHT Comfort, безлактозное, 3,5%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=264394561, name='Питчер для молока и кофе, молочник 350мл серебристый с мерной шкалой'),
#  Document(doc_id=1582995272, name='Молоко ультрапастеризованное ЭкоНива, для питания детей с 3-х лет, 3,2%, 200 мл х 18 шт. Уцененный товар'),
#  Document(doc_id=1197864792, name='Молоко ФрутоНяня ультрапастеризованное (м.д.ж. 2,5%), 0.2 л'),
#  Document(doc_id=870070117, name='ЭкоНива Молоко Стерилизованное 3.5% 1шт.'),
#  Document(doc_id=741955430, name='GFGRIL высокоскоростной блендер GF-SM10 1,75 л, 30 000 об/мин, 8 стальных лезвий, стационарный блендер пароварка, нагрев до 100 градусов, суп-пюре, соевое молоко, 8 программ. Уцененный товар'),
#  Document(doc_id=354309997, name='NABI Патчи для глаз с экстрактом кокосового молока, гидрогелевые патчи для глаз от темных кругов и отеков (быстрый результат, 60 штук)'),
#  Document(doc_id=1197864822, name='Молоко ФрутоНяня ультрапастеризованное (м.д.ж. 2,5%), 0.2 л х 12 шт'),
#  Document(doc_id=1601402744, name='Капучинатор для молока Hyundai HMF-P300 кремовый 300мл. Уцененный товар'),
#  Document(doc_id=1606276985, name='Молоко ультрапастеризованное 1,8% Parmalat, 12 шт х 1 л. Уцененный товар'),
#  Document(doc_id=239662977, name='Erborian MILK&PEEL Mask, Разглаживающая маска для лица Кунжутное молоко, 60 гр'),
#  Document(doc_id=143415195, name='Pigeon Пакеты для хранения грудного молока 180 мл 25 шт'),
#  Document(doc_id=172554143, name='Молоко безлактозное, 1,5 % 970 мл, Простоквашино, ультрапастеризованное'),
#  Document(doc_id=1480005547, name='Parmalat Молоко Ультрапастеризованное 1.8% 1000мл. 12шт. Уцененный товар'),
#  Document(doc_id=1328879534, name='Молоко Халяль 2,5%, 1,4 кг, Очень важная корова, пастеризованное'),
#  Document(doc_id=499644336, name='Органическое кокосовое молоко ACP VICO Rich / 1 л / 4 шт'),
#  Document(doc_id=154277819, name='Чай в пакетиках зеленый Saito Milky Oolong, с ароматом молока, 25 шт'),
#  Document(doc_id=172799947, name='Чай Niktea Milk Oolong/ Молочный Улун, чай зеленый ароматизированный с ароматом молока в пакетиках, 25 п х 2 г'),
#  Document(doc_id=1554757580, name='Кулич пасхальный без глютена, сахара и молока'),
#  Document(doc_id=145627087, name='Вспениватель молока Kitfort КТ-710'),
#  Document(doc_id=145627088, name='Вспениватель молока Kitfort КТ-711'),
#  Document(doc_id=1632188382, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1670936544, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1586509798, name='Молоко питьевое 2,5%, 900 мл, Красное знамя, пастеризованное'),
#  Document(doc_id=1635047398, name='Каша быстрого приготовления Увелка овсяная Ассорти с ягодами и молоком, 6 пакетиков по 40 г, 240 г. Уцененный товар'),
#  Document(doc_id=545445868, name='Молоко Сгущенное Коровка из Кореновки цельное 8,5%, 880 г ПЭТ'),
#  Document(doc_id=162961389, name='Herbal Essences Кокосовое молоко, Шампунь веганский, 400 мл'),
#  Document(doc_id=1532950512, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1480620023, name='Сливки ультрапастеризованные для взбивания 33%, 250 г, Вкуснотеево'),
#  Document(doc_id=291731454, name='Мини десерт замороженный без молока "Фундучное эскимо" Lubaica, 55г / мороженое пп , без лактозы, без глютена, натуральный'),
#  Document(doc_id=364492805, name='Молоко сгущенное Коровка из Кореновки, цельное с сахаром, 8,5%, сашет, 270 г\n'),
#  Document(doc_id=1548457995, name='Сухой молочный напиток на основе козьего молока НЭННИ 4 для детей старше 1,5 лет, 800 г. Уцененный товар'),
#  Document(doc_id=1483397132, name='Село Зеленое Молоко Ультрапастеризованное 3.2% 950мл. 12шт. Уцененный товар'),
#  Document(doc_id=1638791212, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1578129464, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=793483322, name='Снежок Молоко Ультрапастеризованное 3.2% 1000мл. 1шт.'),
#  Document(doc_id=1567291468, name='Каша быстрого приготовления Увелка овсяная Ассорти с ягодами и молоком, 6 пакетиков по 40 г, 240 г. Уцененный товар'),
#  Document(doc_id=177223762, name='Органическое кокосовое молоко 1 литр CocoDaily 61%, (жирность 17-19%), 3 шт.'),
#  Document(doc_id=1636235359, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1436596325, name='Parmalat Молоко Ультрапастеризованное 1.8% 1000мл. 12шт. Уцененный товар'),
#  Document(doc_id=1409349739, name='Детское печенье на козьем молоке с яблочным соком, 2шт. по 150 г.'),
#  Document(doc_id=301021293, name='Молоко 900 г, 3,2%, Вкуснотеево, ультрапастеризованное'),
#  Document(doc_id=301021300, name='Молоко ультрапастеризованное 2,5% 900 г, Вкуснотеево'),
#  Document(doc_id=763959425, name='Молоко 2,5% 930 мл Калория Кубанское'),
#  Document(doc_id=763959430, name='Молоко Калория питьевое ультрапастеризованное  2,5%, 1л'),
#  Document(doc_id=763959435, name='Сливки Калория ультрапастеризованные 10 % , 200г'),
#  Document(doc_id=1555519629, name='Каша быстрого приготовления Увелка овсяная Ассорти с ягодами и молоком, 6 пакетиков по 40 г, 240 г. Уцененный товар'),
#  Document(doc_id=301529236, name='Shiny Kitchen, Капучинатор, вспениватель молока'),
#  Document(doc_id=340441239, name='Пельмени Сочные 700 г, с фаршем на молоке Сибирская коллекция, замороженные'),
#  Document(doc_id=144611482, name='Б.Ю.Александров Сырок с молоком сгущенным вареным в молочном шоколаде, 50 г'),
#  Document(doc_id=244676770, name='Кокосовое молоко AROY-D жирность 19%, 500 мл, tetra pak, 1 шт'),
#  Document(doc_id=1664997541, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=198678694, name='Органическое кокосовое молоко ACP VICO Rich / 330 мл / 1 шт'),
#  Document(doc_id=763959466, name='Молоко Калория СуперМилк ультрапастеризованные 3,2%, 200мл'),
#  Document(doc_id=1568946360, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=154073276, name='Ковш кухонный Fissman из нержавеющей стали, для кипячение молока - 1,5л'),
#  Document(doc_id=1477900510, name='Молоко ФрутоНяня ультрапастеризованное (м.д.ж. 2,5%), 0.2 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1465448672, name='Село Зеленое Молоко Ультрапастеризованное 3.2% 950мл. 12шт. Уцененный товар'),
#  Document(doc_id=141580513, name='Молоко ультрапастеризованное 3,5%, 1 л, Parmalat'),
#  Document(doc_id=141580514, name='Молоко ультрапастеризованное 1,8% 1 л, Parmalat'),
#  Document(doc_id=141580515, name='Parmalat Молоко Ультрапастеризованное 0.5% 1000мл. 1шт.'),
#  Document(doc_id=141580516, name='Parmalat Молоко Ультрапастеризованное 3.5% 200мл. 1шт.'),
#  Document(doc_id=141580518, name='Молоко Белый Город ультрапастеризованное 3,2%, 1 л'),
#  Document(doc_id=141580519, name='Белый Город Молоко Ультрапастеризованное 2.5% 1000мл. 1шт.'),
#  Document(doc_id=141580520, name='Белый Город Молоко Стерилизованное 1.5% 1000мл. 1шт.'),
#  Document(doc_id=654014695, name='Творог 9%, 180 г, Просто Молоко, флоу-пак'),
#  Document(doc_id=141580524, name='Parmalat Молоко Ультрапастеризованное 0.5% 1000мл. 1шт.'),
#  Document(doc_id=172292342, name='Молоко безлактозное 1,8% 1 л х 12 шт, Parmalat Comfort'),
#  Document(doc_id=813316344, name='Молоко козье цельное, пастеризованное 3,5-4,8% 310 мл G-Balance'),
#  Document(doc_id=1626511610, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=300751105, name='Шоколад «РОССИЯ» — ЩЕДРАЯ ДУША! КОФЕ С МОЛОКОМ. Молочный с добавлением кофе, 82 г'),
#  Document(doc_id=141580549, name='Сливки ультрапастеризованные 35% 0,5 л, Parmalat'),
#  Document(doc_id=141580551, name='Сливки ультрапастеризованные 23%, 0,5 л, Parmalat'),
#  Document(doc_id=183441675, name=' Healthy Lifestyle Сухое молоко 350г. 1шт.'),
#  Document(doc_id=1616566545, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1616566547, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1569208599, name='Parmalat молоко ультрапастеризованное 3,5%, 1 л. Уцененный товар'),
#  Document(doc_id=1543215390, name='Молоко Parmalat UHT Comfort, безлактозное, 0,05%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=769530152, name='Питчер для молока и кофе, молочник, посуда для сервировки 350мл Серебряный матовый'),
#  Document(doc_id=462182700, name='Молоко топленое Халяль 4%, 430 г, Очень важная корова'),
#  Document(doc_id=462182702, name='Молоко пастеризованное Халяль 1,5%, 930 г, Очень важная корова'),
#  Document(doc_id=462182704, name='Молоко Халяль 2,5%, 930 г, Очень важная корова, пастеризованное'),
#  Document(doc_id=1378285873, name='Молокоотсос Sisbro Care электрический, беспроводной, портативный / устройство с бутылочкой и соской в комплекте для кормления новорожденного и для сцеживания грудного молока'),
#  Document(doc_id=462182706, name='Молоко отборное халяль 3,4-6%, 930 г, Очень важная корова, пастеризованное'),
#  Document(doc_id=462182707, name='Молоко Халяль 3,2%, 1,4 кг, Очень важная корова, пастеризованное'),
#  Document(doc_id=462182711, name='Молоко топленое Халяль 4%, 930 г, Очень важная корова'),
#  Document(doc_id=607926587, name='Капучинатор ZESTEN, вспениватель молока (мини-миксер) на подставке, батарейки в комплекте'),
#  Document(doc_id=1550670142, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=688568644, name='Том Ям с креветками Elementaree. Набор для приготовления супа на 2-6 порций (1000 г). Содержит все необходимое - от креветок до специй и кокосового молока.'),
#  Document(doc_id=1430165833, name='Молоко Молочная Культура питьевое пастеризованное безлактозное, 3,5%-4,5%, 0,5 л'),
#  Document(doc_id=1430165834, name='Молоко Молочная Культура, 1,5%, 1,8 кг'),
#  Document(doc_id=1430165835, name='Молоко Молочная Культура ненормализованное, 3,5%-4,5%, 1,8 кг'),
#  Document(doc_id=1553209677, name='Капучинатор для молока Hyundai HMF-P300 кремовый 300мл. Уцененный товар'),
#  Document(doc_id=172955994, name='Кокосовое молоко Take a Bite, без сахара, безлактозное, 6 шт по 1 л'),
#  Document(doc_id=1586370915, name='Молочная смесь Nestle NAN с рождения до 12 месяцев, на козьем молоке, 400 г. Уцененный товар'),
#  Document(doc_id=1449539943, name='Сыр с голубой плесенью Егорлык Молоко, 50%, 100 г'),
#  Document(doc_id=193902964, name='Медофеты с курагой и черносливом Берестов А.С., 350 г суфле птичье молоко "Ассорти"'),
#  Document(doc_id=228145524, name='GFGRIL высокоскоростной блендер GF-SM10 1,75 л, 30 000 об/мин, 8 стальных лезвий, стационарный блендер пароварка, нагрев до 100 градусов, суп-пюре, соевое молоко, 8 программ'),
#  Document(doc_id=1520023933, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=1562851720, name='Молоко Parmalat ультрапастеризованное 3,5%, 12 шт х 1 л\n. Уцененный товар'),
#  Document(doc_id=503167370, name='Молочник из нержавеющей стали, питчер для молока, цвет медный, объем 600 мл'),
#  Document(doc_id=1520023949, name='Молоко Parmalat Comfort, безлактозное, 1,8%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1044732304, name='Сухой молочный напиток на основе козьего молока НЭННИ 4 для детей старше 1,5 лет, 800 г'),
#  Document(doc_id=1539496356, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1562851751, name='Молоко ультрапастеризованное ЭкоНива, 3,2%, 1 л х 12 шт. Уцененный товар'),
#  Document(doc_id=1640069547, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=1573804461, name='Село Зеленое Молоко питьевое ультрапастеризованное 3,2%, 950 мл х 12 шт. Уцененный товар'),
#  Document(doc_id=256653748, name=' EUROPEK Сухое молоко 400г. 1шт.'),
#  Document(doc_id=172374454, name='Растительное молоко Aroy-D, кокосовое, 1 л х 12 шт'),
#  Document(doc_id=258455993, name='Напиток Куркума Латте, золотое молоко, смесь специй и пряностей, 200 г'),
#  Document(doc_id=278174138, name='Сироп низкокалорийный без сахара Mr.Djemius ZERO "Сгущенное молоко" 330г/ соус, сгущенка, еда, пп'),
#  Document(doc_id=178018770, name='Сгущенное молоко вареное 8,5% 360 г, Алексеевское, с сахаром, ГОСТ, ЖБ'),
#  ...]

# %%
search_with_or_condition(
    documents_index,
    documents_dict,
    symbols_to_replace,
    russian_stopwords,
    morph,
    "диван кровать",
    10,
)
# Out:
# [Document(doc_id=1489766400, name='Средство пятновыводитель для чистки ковров, дивана,салона и удаления пятен на мягкой мебели WONDER LAB, без запаха, 550 мл. Уцененный товар'),
#  Document(doc_id=282235399, name='Накладка на подлокотник дивана DECOREZ / Подставка деревянная 46*29 см'),
#  Document(doc_id=258876942, name='Накладка на подлокотник дивана DECOREZ / Подставка деревянная 46*29 см'),
#  Document(doc_id=270393871, name='Защитные накладка на стул, 22мм. 24 штуки. Наклейка войлочная на ножку мебели, подпятник на диван, насадки мебельные'),
#  Document(doc_id=302585365, name='Наматрасник 160х200 непромокаемый c бортами на резинке, чехол на матрас или диван аквастоп, простынь непромокаемая водонепроницаемая на резинке, топпер, наматрацник'),
#  Document(doc_id=462384665, name='CINLANKIDS Защитный бортик для детской кровати 180*98 см от падения, серый (высота регулируется), 1 шт.'),
#  Document(doc_id=262376994, name='Наматрасник стеганый 160 200 водонепроницаемый непромокаемый Мягкость&Комфорт, наматрасник стеганный мягкий 160х200 с резинкой по углам на кровать 160, на диван, хлопок'),
#  Document(doc_id=655012387, name='Плед для дивана BARIEL, покрывало на кровать, 150x200 см, двухсторонний плед 1,5 спальный, 60% хлопок, синий с бежевым'),
#  Document(doc_id=229424677, name='Пылесос для дома Jimmy WB55, ручной, для мебели и для удаления пылевых клещей, от шерсти животных, с контейнером, для диванов и кроватей, ультрафиолетовая и ультразвуковая чистка, мощный 600Вт'),
#  Document(doc_id=219546664, name='БДСМ набор на кровать Джага Джага, №11,'),
#  Document(doc_id=408169513, name='БДСМ набор для кровати, фиксаторы для рук и ног, манжеты для ног, наручники, оковы, бандаж БДСМ для связывания ног и рук, комплект для ролевых игр'),
#  Document(doc_id=219546666, name='БДСМ набор для кровати, Комплект для ролевых игр, Бондаж на кровать'),
#  Document(doc_id=1164402222, name='Плед 200х220 на кровать BELEZZA, для дивана, двухсторонний, 60% хлопок'),
#  Document(doc_id=710514228, name='Самоклеящаяся защитная плёнка для мебели и стен от царапин и когтей кошек когтеточка на диван'),
#  Document(doc_id=229425205, name='Пылесос для дома Jimmy JV35, ручной, для мебели, для удаления пылевых клещей, от шерсти животных, с контейнером, для диванов и кроватей, ультрафиолетовая чистка и обработка горячим воздухом'),
#  Document(doc_id=344386617, name='Подставка на подлокотник дивана ALPY,40 х 28 см. Гибкий столик на диван'),
#  Document(doc_id=627844666, name='Покрывало плед шерстяной 200х220 см PLEDICO "Скандинавский стиль" на кровать диван евро, серый белый, накидка на диван шерсть, подарочная упаковка, производство Россия'),
#  Document(doc_id=646411836, name='Средство пятновыводитель для чистки ковров, дивана,салона и удаления пятен на мягкой мебели WONDER LAB, без запаха, 550 мл'),
#  Document(doc_id=487247937, name='Mia Cara Покрывало на кровать 210х240, хлопок Таинственный сад, Secret garden'),
#  Document(doc_id=509211202, name='Щетка скребок для удаления шерсти животных, катышков, ковров и диванов от животных кошек и собак'),
#  Document(doc_id=361843781, name='Щетка скребок для уборки шерсти животных с ковра дивана одежды ворса очистки / Скребок от катышек катушек / Щетка для удаления шерсти животных / Щетка для одежды от шерсти чистки ковров /Машинка для удаления катышек /Машинка для удаления катышков с одежды'),
#  Document(doc_id=1456538182, name='Наматрасник 160 200 водонепроницаемый непромокаемый SWEET DREAMS, наматрасник 160х200 на резинке по периметру на кровать 160, хлопок, непромокаемая простынь на резинке с бортом. Уцененный товар'),
#  Document(doc_id=1569817675, name='Средство пятновыводитель для чистки ковров, дивана,салона и удаления пятен на мягкой мебели WONDER LAB, без запаха, 550 мл. Уцененный товар'),
#  Document(doc_id=175280205, name='Белая натяжная простыня Ambesonne на резинке на двуспальную кровать 180х200 см, на матрас высотой до 30 см.'),
#  Document(doc_id=655019087, name='Плед Новогодний FROLANCE для дивана, покрывало на кровать, 150x200 см, двухсторонний плед 1,5 спальный, 60% хлопок, серый с красным'),
#  Document(doc_id=282446931, name='БДСМ набор для кровати, LOVEPEAK, для ролевых игр секс оковы фиксатор рук и ног бандаж'),
#  Document(doc_id=1055941717, name='Покрывало на кровать Nikma, Плед на диван 150х210 с наволочками 50x70 Стеганая накидка 1,5 спальная'),
#  Document(doc_id=282764375, name='Подставка - накладка деревянная на подлокотник дивана. Гибкий столик - поднос сервировочный под горячее, напитки, фрукты и закуски, для кухни и комнаты.'),
#  Document(doc_id=546303575, name='Самоклеящаяся защитная плёнка для мебели и стен от царапин и когтей кошек настенная когтеточка на диван'),
#  Document(doc_id=1456538199, name='Наматрасник 160 200 водонепроницаемый непромокаемый SWEET DREAMS, наматрасник 160х200 на резинке по периметру на кровать 160, хлопок, непромокаемая простынь на резинке с бортом. Уцененный товар'),
#  Document(doc_id=866927709, name='Пылесос для дома Jimmy WB55, ручной, для мебели и для удаления пылевых клещей, от шерсти животных, с контейнером, для диванов и кроватей, ультрафиолетовая и ультразвуковая чистка, мощный 600Вт'),
#  Document(doc_id=496408166, name='Покрывало на кровать и диван 117х200 см стеганое, плед для дивана детской и спальни в подарок, бархат, серое АМИ МЕБЕЛЬ Беларусь'),
#  Document(doc_id=1580201066, name='Средство пятновыводитель для чистки ковров, дивана,салона и удаления пятен на мягкой мебели WONDER LAB, без запаха, 550 мл. Уцененный товар'),
#  Document(doc_id=643881579, name='Покрывало на кровать Nikma, Плед на диван 210x240'),
#  Document(doc_id=1594669163, name='Средство пятновыводитель для чистки ковров, дивана,салона и удаления пятен на мягкой мебели WONDER LAB, без запаха, 550 мл. Уцененный товар'),
#  Document(doc_id=625985642, name='Держатель для простыни резинка фиксатор с зажимом Подтяжки крепление прищепки 12 шт для кровати Черные'),
#  Document(doc_id=1531483250, name='Средство пятновыводитель для чистки ковров, дивана,салона и удаления пятен на мягкой мебели WONDER LAB, без запаха, 550 мл. Уцененный товар'),
#  Document(doc_id=149462131, name='Intex Кровать надувная 250х300 см'),
#  Document(doc_id=311565940, name='OL-Tex Наматрасник 160х200 на резинке стеганый с бортом ( чехол на матрас, топпер на диван)'),
#  Document(doc_id=355105396, name='Двухъярусная кровать для кукол 46 см Our genration'),
#  Document(doc_id=705161847, name='Подставка для ноутбука Оксфорд , столик для ноутбука, на кровать , бежевый , Ами Мебель'),
#  Document(doc_id=296224385, name='Плед 180х200 велсофт / покрывало велсофт / покрывало 2 спальное / покрывало на кровать / покрывало / покрывало на кровать 180х200 / гипоаллергенное Mia Cara 180х200 "Амулето" бургунди 191972'),
#  Document(doc_id=791002248, name='Лесенка для кровати для лежачих больных, с петлями, 200 см'),
#  Document(doc_id=582489740, name='Скребок от катышек катушек / Щетка скребок для уборки шерсти животных с ковра дивана одежды ворса очистки / Щетка для удаления шерсти животных / Щетка для одежды от шерсти чистки ковров /Машинка для удаления катышек /Машинка для удаления катышков с одежды'),
#  Document(doc_id=1456538253, name='Наматрасник 160 200 водонепроницаемый непромокаемый SWEET DREAMS, наматрасник 160х200 на резинке по периметру на кровать 160, хлопок, непромокаемая простынь на резинке с бортом. Уцененный товар'),
#  Document(doc_id=974487185, name='Плед 200х220 для дивана MORENA, покрывало на кровать, двухсторонний, 60% хлопок'),
#  Document(doc_id=974490770, name='Плед для дивана WILMA, покрывало на кровать, 150x200 см, двухсторонний плед 1,5 спальный, 60% хлопок'),
#  Document(doc_id=1456538265, name='Наматрасник 160 200 водонепроницаемый непромокаемый SWEET DREAMS, наматрасник 160х200 на резинке по периметру на кровать 160, хлопок, непромокаемая простынь на резинке с бортом. Уцененный товар'),
#  Document(doc_id=355099804, name='Набор игровой Lori Двуярусная кровать с аксессуарами'),
#  Document(doc_id=500234910, name='Кровать надувная INTEX 183х203х25 см / Матрас надувной FIBER-TECH "CLASSIC DOWNY КИНГ", 64755'),
#  Document(doc_id=1439936160, name='От саванны до дивана: Эволюционная история кошек Лосос Джонатан Б. | Лосос Джонатан Б.'),
#  Document(doc_id=700850336, name='Покрывало на кровать / 210х240 / покрывало стеганое / лавандовый'),
#  Document(doc_id=1531294376, name='Средство пятновыводитель для чистки ковров, дивана,салона и удаления пятен на мягкой мебели WONDER LAB, без запаха, 550 мл. Уцененный товар'),
#  Document(doc_id=1164247722, name='Плед 200х220 на кровать GRAYSEN, для дивана, двухсторонний, 60% хлопок'),
#  Document(doc_id=1455641258, name='Подставка для ноутбука охлаждающая. Столик для ноутбука в кровать. Уцененный товар'),
#  Document(doc_id=203627692, name='Покрывало на кровать 145х200 детское Непоседа, Гарри Поттер / Хогвартс'),
#  Document(doc_id=700740270, name='Наматрасник 180x200 непромокаемый на резинке Nikma с бортом 25 (защитный чехол на матрас или диван)'),
#  Document(doc_id=514356916, name='Плед флисовый 1,5 спальный на кровать и диван плюшевый Экономь и Я Желтый 150*200см, плотность 160 г/м2, 100% полиэстер'),
#  Document(doc_id=1531294390, name='Средство пятновыводитель для чистки ковров, дивана,салона и удаления пятен на мягкой мебели WONDER LAB, без запаха, 550 мл. Уцененный товар'),
#  Document(doc_id=258908855, name='Накладка на подлокотник дивана DECOREZ / Подставка деревянная 46*29 см'),
#  Document(doc_id=446898873, name='CINLANKIDS Защитный бортик для детской кровати 200*98 см от падения, серый (высота регулируется), 1 шт.'),
#  Document(doc_id=1660875962, name='Средство пятновыводитель для чистки ковров, дивана,салона и удаления пятен на мягкой мебели WONDER LAB, без запаха, 550 мл. Уцененный товар'),
#  Document(doc_id=409995963, name='Столик-поднос на кровать, подставка Walmer Safari 35x25 см, цвет темное дерево'),
#  Document(doc_id=1577994943, name='Плед 200х220 на кровать LUZIA, покрывало на кровать, для дивана, двухсторонний, 60% хлопок, бежевый. Уцененный товар'),
#  Document(doc_id=1531315906, name='Средство пятновыводитель для чистки ковров, дивана,салона и удаления пятен на мягкой мебели WONDER LAB, без запаха, 550 мл. Уцененный товар'),
#  Document(doc_id=1489768645, name='Средство пятновыводитель для чистки ковров, дивана,салона и удаления пятен на мягкой мебели WONDER LAB, без запаха, 550 мл. Уцененный товар'),
#  Document(doc_id=421452489, name='DECOREZ Накладка на подлокотник дивана / Подставка деревянная 46*29 см'),
#  Document(doc_id=1531294411, name='Средство пятновыводитель для чистки ковров, дивана,салона и удаления пятен на мягкой мебели WONDER LAB, без запаха, 550 мл. Уцененный товар'),
#  Document(doc_id=1584561356, name='Средство пятновыводитель для чистки ковров, дивана,салона и удаления пятен на мягкой мебели WONDER LAB, без запаха, 550 мл. Уцененный товар'),
#  Document(doc_id=579348175, name='Покрывало, плед на кровать, на диван 210х240, хлопок 100%'),
#  Document(doc_id=1571419344, name='Средство пятновыводитель для чистки ковров, дивана,салона и удаления пятен на мягкой мебели WONDER LAB, без запаха, 550 мл. Уцененный товар'),
#  Document(doc_id=1571419347, name='Средство пятновыводитель для чистки ковров, дивана,салона и удаления пятен на мягкой мебели WONDER LAB, без запаха, 550 мл. Уцененный товар'),
#  Document(doc_id=655015636, name='Плед новогодний 200х220 на кровать Karna FROLANCE, для дивана, двухсторонний, 60% хлопок, серый с красным, подарок на Новый год'),
#  Document(doc_id=1142218964, name='Наматрасник 160x200 непромокаемый на резинке Nikma с бортом 25 ( защитный чехол на матрас 160х200, водонепроницаемый чехол на матрас или диван)'),
#  Document(doc_id=1571419349, name='Средство пятновыводитель для чистки ковров, дивана,салона и удаления пятен на мягкой мебели WONDER LAB, без запаха, 550 мл. Уцененный товар'),
#  Document(doc_id=497234134, name='Покрывало на кровать 220х240 велсофт ВИТЭЛИЯ серый'),
#  Document(doc_id=659988182, name='БДСМ набор Rabby: ремни на кровать для связывания с фиксаторами для запястий и лодыжек, товары для взрослых, игрушки для секса, бондаж и фетиш, эротические и интимные товары'),
#  Document(doc_id=1571419354, name='Средство пятновыводитель для чистки ковров, дивана,салона и удаления пятен на мягкой мебели WONDER LAB, без запаха, 550 мл. Уцененный товар'),
#  Document(doc_id=1531294427, name='Средство пятновыводитель для чистки ковров, дивана,салона и удаления пятен на мягкой мебели WONDER LAB, без запаха, 550 мл. Уцененный товар'),
#  Document(doc_id=644291804, name='Наматрасник 160x200 непромокаемый на резинке Nikma с бортом 25 ( защитный чехол на матрас 160х200, водонепроницаемый чехол на матрас или диван)'),
#  Document(doc_id=1194312925, name='Моющий пылесос Deerma BY200 с функцией чистки мебели и влажной уборки,12000 Pa/Пылесос для химчистки ковров/Химчистка дивана моющим (пылесосом). Уцененный товар'),
#  Document(doc_id=700739295, name='Наматрасник 140x200 непромокаемый на резинке Nikma с бортом 25 (защитный чехол на матрас или диван)'),
#  Document(doc_id=1055891680, name='Покрывало на кровать Nikma, Плед на диван 210x240'),
#  Document(doc_id=1531294433, name='Средство пятновыводитель для чистки ковров, дивана,салона и удаления пятен на мягкой мебели WONDER LAB, без запаха, 550 мл. Уцененный товар'),
#  Document(doc_id=1571419359, name='Средство пятновыводитель для чистки ковров, дивана,салона и удаления пятен на мягкой мебели WONDER LAB, без запаха, 550 мл. Уцененный товар'),
#  Document(doc_id=413892834, name='Кровать надувная двуспальная Intex Comfort-Plush + встр. насос 220В 152х203х56см'),
#  Document(doc_id=1571419364, name='Средство пятновыводитель для чистки ковров, дивана,салона и удаления пятен на мягкой мебели WONDER LAB, без запаха, 550 мл. Уцененный товар'),
#  Document(doc_id=1434557663, name='Охлаждающая подставка для ноутбука с 4 вентиляторами и красной подсветкой - мощная система охлаждения USB под большой игровой ноутбук 15" 15,6" 16" 17" на кровать и стол. Уцененный товар'),
#  Document(doc_id=282182889, name='Накладка на подлокотник дивана DECOREZ / Подставка деревянная 46*29 см'),
#  Document(doc_id=565236463, name='Хлопковый плед покрывало на кровать и диван, пр-во Турция, цвет бежевый, р-р 200*220.'),
#  Document(doc_id=541335282, name='Чистящее средство для уборки дома,пола SYNERGETIC универсальное,для чистки диванов ковров для мытья пола, поверхностей , 0,5л спрей, универсальное средство для уборки дома'),
#  Document(doc_id=245377779, name='Покрывало на диван/кровать MIX 140х210 см'),
#  Document(doc_id=495117560, name='Подставка на подлокотник дивана ALPY, 40 х 28 см. Гибкий столик на диван'),
#  Document(doc_id=1651544312, name='От саванны до дивана: Эволюционная история кошек Лосос Джонатан Б. | Лосос Джонатан Б.. Уцененный товар | Лосос Джонатан Б.'),
#  Document(doc_id=630278394, name='Подставка на подлокотник дивана ALPY, 40 х 28 см. Гибкий столик на диван'),
#  Document(doc_id=1669159673, name='Средство пятновыводитель для чистки ковров, дивана,салона и удаления пятен на мягкой мебели WONDER LAB, без запаха, 550 мл. Уцененный товар'),
#  Document(doc_id=653519612, name='Средство для чистки ковров Londix, мягкой мебели, дивана, обивки салона автомобиля, 500 мл'),
#  Document(doc_id=1531315965, name='Средство пятновыводитель для чистки ковров, дивана,салона и удаления пятен на мягкой мебели WONDER LAB, без запаха, 550 мл. Уцененный товар'),
#  Document(doc_id=446899965, name='CINLANKIDS Защитный бортик для детской кровати 200*98 см от падения, серый (высота регулируется), 1 шт.'),
#  Document(doc_id=1499783932, name='Наматрасник 160 200 водонепроницаемый непромокаемый SWEET DREAMS, наматрасник 160х200 на резинке по периметру на кровать 160, хлопок, непромокаемая простынь на резинке с бортом. Уцененный товар'),
#  Document(doc_id=203595521, name='Чехол на диван без подлокотников универсальный на резинке клик кляк'),
#  Document(doc_id=592546561, name='Плед 200х220 см, покрывало на кровать велсофт ВИТЭЛИЯ диз Пиноли серый'),
#  Document(doc_id=470222595, name='Одеяло Эвкалипт Евро, Ломбардия Премиум, 220х200 см, PRIAVERAFRESCA всесезонное зимнее стеганое, домашний текстиль на кровать в спальню'),
#  Document(doc_id=865993989, name='Наматрасник 160x200 непромокаемый на резинке Nikma с бортом 20 (защитный чехол на матрас или диван)'),
#  Document(doc_id=383425290, name='Подушка на стул для сидения "Пуф", на пол, диван, подоконник и балкон, для улицы, для медитации, подушка бустер на стул в детскую'),
#  Document(doc_id=174443280, name='Наматрасник 160х200 непромокаемый с бортом 30см на резинке, простынь непромокаемая водонепроницаемая на резинке, чехол на матрас или диван аквастоп, наматрасник топпер'),
#  Document(doc_id=174443281, name='Наматрасник 180х200 непромокаемый с бортом 30см на резинке, чехол на матрас или диван аквастоп, простынь непромокаемая водонепроницаемая на резинке, наматрасник топпер'),
#  Document(doc_id=174443283, name='Наматрасник 100х200 непромокаемый с бортом 30см на резинке, чехол на матрас или диван аквастоп, простынь непромокаемая водонепроницаемая на резинке, наматрасник топпер'),
#  Document(doc_id=1531315989, name='Средство пятновыводитель для чистки ковров, дивана,салона и удаления пятен на мягкой мебели WONDER LAB, без запаха, 550 мл. Уцененный товар'),
#  Document(doc_id=1575859478, name='Средство пятновыводитель для чистки ковров, дивана,салона и удаления пятен на мягкой мебели WONDER LAB, без запаха, 550 мл. Уцененный товар'),
#  Document(doc_id=666212120, name='Ol-Tex Подушка декоративная 40х40 4 шт внутренняя без наволочки, белая / комплект подушек на диван'),
#  Document(doc_id=1605304090, name='Средство пятновыводитель для чистки ковров, дивана,салона и удаления пятен на мягкой мебели WONDER LAB, без запаха, 550 мл. Уцененный товар'),
#  Document(doc_id=655012125, name='Плед 200х220 на кровать BARIEL, для дивана, двухсторонний, 60% хлопок, синий с бежевым'),
#  Document(doc_id=700839716, name='Покрывало на кровать / 210х240 / покрывало стеганое / голубой'),
#  Document(doc_id=1605516582, name='Средство пятновыводитель для чистки ковров, дивана,салона и удаления пятен на мягкой мебели WONDER LAB, без запаха, 550 мл. Уцененный товар'),
#  Document(doc_id=255046447, name='БДСМ фиксация к кровати "Сюрприз" SexyFire из натуральной кожи (цвет бордо)'),
#  Document(doc_id=414307639, name='Накладка на подлокотник дивана DECOREZ / Подставка деревянная 46*29 см'),
#  Document(doc_id=418312504, name='Моющий вертикальный пылесос с аккумулятором Teqqo Aquastick 3 в 1, для дома, для ковров, для дивана, для ламината'),
#  Document(doc_id=974488377, name='Плед для дивана MORENA, покрывало на кровать, 150x200 см, двухсторонний плед 1,5 спальный, 60% хлопок'),
#  Document(doc_id=1531316025, name='Средство пятновыводитель для чистки ковров, дивана,салона и удаления пятен на мягкой мебели WONDER LAB, без запаха, 550 мл. Уцененный товар'),
#  Document(doc_id=336274231, name='Кровать детская Rant Indy маятник продольного качания в комплекте Cloud White (арт.766)'),
#  Document(doc_id=355115836, name="Набор мебели игровой Li'l Woodzeez Детская и двухъярусная кровать"),
#  Document(doc_id=1508476217, name='Бортики в кроватку для новорожденных Rudiks / бортики на кровать защитные'),
#  Document(doc_id=279745854, name='Подвесной карман-органайзер для кровати с карманами, на диван, кресло, для пульта, журналов, телефона, хранения книг и очков'),
#  Document(doc_id=325179712, name='Средство для моющего пылесоса, для дома, для мытья полов, средство для чистки дивана, для ковров, пятновыводитель для мебели, бытовая химия, концентрат 1 литр ACTIVAI'),
#  Document(doc_id=758012740, name='Скребок для удаления шерсти животных, катышков, волос, с ковра, одежды прибор для снятия ворса, очистки дивана, одежды, волос уборка одежды, шерсти, ковра/Щетка для удаления шерсти животных, катышков, волос, ворса, чистки ковров / Щетка для одежды'),
#  Document(doc_id=1434028877, name='Средство пятновыводитель для чистки ковров, дивана,салона и удаления пятен на мягкой мебели WONDER LAB, без запаха, 550 мл. Уцененный товар'),
#  Document(doc_id=1164401998, name='Плед для дивана BELEZZA, покрывало на кровать, 150x200 см, двухсторонний плед 1,5 спальный, 60% хлопок'),
#  Document(doc_id=170627411, name='Наматрасник 180х200 непромокаемый с резинками по углам, простыня водонепроницаемая непромокаемая, наматрацник водонепроницаемый, чехол на матрас или диван, наматрасник защитный махровый, топпер.'),
#  Document(doc_id=1164394329, name='Плед для дивана VIOLE, покрывало на кровать, 150x200 см, двухсторонний плед 1,5 спальный, 60% хлопок'),
#  Document(doc_id=345469785, name='Подставка для ноутбука 13, 15.6 дюймов, стойка алюминиевая под планшета настольная, смартфона и книги, складная, на кровать, портативная, подарок'),
#  Document(doc_id=174148448, name='Наматрасник 90х190 непромокаемый с бортом на резинке, чехол на матрас или диван аквастоп, простынь непромокаемая водонепроницаемая на резинке, наматрасник топпер, наматрацник'),
#  Document(doc_id=600652129, name='Средство для моющего пылесоса, для мытья полов, средство для чистки дивана, для ковров, пятновыводитель для мебели, бытовая химия для дома, концентрат 1 литр ACTIVAI'),
#  Document(doc_id=203598178, name='Чехол на диван без подлокотников универсальный на резинке клик кляк'),
#  Document(doc_id=655020385, name='Плед 200х220 на кровать LUZIA, покрывало на кровать, для дивана, двухсторонний, 60% хлопок, бежевый'),
#  Document(doc_id=367354212, name='Плед из хлопка с кисточками односпальный для дивана и на кровать бежевый и коричневый 125х152см, Desert'),
#  Document(doc_id=1590244709, name='Средство пятновыводитель для чистки ковров, дивана,салона и удаления пятен на мягкой мебели WONDER LAB, без запаха, 550 мл. Уцененный товар'),
#  Document(doc_id=760196459, name='Плед для дивана LAVAL, покрывало на кровать, 150x200 см, двухсторонний плед 1,5 спальный, 60% хлопок, серо-бежевый'),
#  Document(doc_id=760196461, name='Плед 200х220 для дивана LAVAL, покрывало на кровать, для дивана, двухсторонний, 60% хлопок, бежевый'),
#  Document(doc_id=672998766, name='CINLANKIDS Защитный барьер для кровати, бортик для кровати от падения 200 см, серый, олень, 1 шт.'),
#  Document(doc_id=339324277, name='Наклейка на ножку стула,войлочные накладки на мебель, подпятник на диван, защитные протекторы на стул, 20 х 20 мм.,32 штуки'),
#  Document(doc_id=169810294, name='Наматрасник 160х200 непромокаемый с резинками по углам, простыня водонепроницаемая непромокаемая, наматрацник водонепроницаемый, чехол на матрас или диван, наматрасник защитный махровый, топпер.'),
#  Document(doc_id=177310072, name='Плед Павлайн Ирен какао 150х200 , плед на кровать; плед на диван; покрывало на кровать; покрывало на диван; плед 150 на 200; плед 200 на 220; 150*200; плед 200х220; плед 150х200; полуторка'),
#  Document(doc_id=692433784, name='Бандаж БДСМ для крепления к кровати, набор для фиксации рук и ног, ролевые игры'),
#  Document(doc_id=799296380, name='Покрывало на кровать Nikma, Плед на диван 150х210 с наволочками 50x70 Стеганая накидка 1,5 спальная'),
#  Document(doc_id=170627453, name='Наматрасник 140х200 непромокаемый с резинками по углам, простыня водонепроницаемая непромокаемая, наматрацник водонепроницаемый, чехол на матрас или диван, наматрасник защитный махровый, топпер.'),
#  Document(doc_id=170627456, name='Наматрасник 100х200 непромокаемый с резинками по углам, простыня водонепроницаемая непромокаемая, наматрацник водонепроницаемый, чехол на матрас или диван, наматрасник защитный махровый, топпер.'),
#  Document(doc_id=169810305, name='Наматрасник 80х200 непромокаемый с резинками по углам, простыня водонепроницаемая непромокаемая, наматрацник водонепроницаемый, чехол на матрас или диван, наматрасник защитный махровый, топпер.'),
#  Document(doc_id=367575426, name='Носки с войлоком защитные накладки чехлы на ножки стола, стула, комода, дивана, для мебели черный 16 шт.'),
#  Document(doc_id=1476462976, name='Наматрасник 160 200 водонепроницаемый непромокаемый SWEET DREAMS, наматрасник 160х200 на резинке по периметру на кровать 160, хлопок, непромокаемая простынь на резинке с бортом. Уцененный товар'),
#  Document(doc_id=630586760, name='Подставка на подлокотник дивана из бамбука ALPY, 40 х 28 см. Журнальный столик накладка для дивана'),
#  Document(doc_id=169810314, name='Наматрасник 90х200 непромокаемый с резинками по углам, простыня водонепроницаемая непромокаемая, наматрацник водонепроницаемый, чехол на матрас или диван, наматрасник защитный махровый, топпер.'),
#  Document(doc_id=265583506, name='Накладки защитные для дома, протекторы на углы мебели кровати стульев стола, 4см, 4шт, мягкие прозрачные в форме треугольника, полукруг'),
#  Document(doc_id=262054295, name='Подставка для ноутбука охлаждающая. Столик для ноутбука в кровать'),
#  Document(doc_id=258901916, name='Накладка на подлокотник дивана DECOREZ / Подставка деревянная 46*29 см'),
#  Document(doc_id=530198429, name='Подставка для ноутбука BOOZO Desk ultra 2, столик для ноутбука в кровать'),
#  Document(doc_id=204416930, name='Носки с войлоком защитные накладки чехлы на ножки стола, стула, комода, дивана, для мебели серый 4 шт.'),
#  Document(doc_id=523819944, name='VarFabric Наматрасник-чехол для дивана 200х200, наматрацник 200x200 белый'),
#  Document(doc_id=658078122, name='Накладка на подлокотник дивана DECOREZ / Подставка деревянная 46*34 см'),
#  Document(doc_id=1566161325, name='Наматрасник 160 200 водонепроницаемый непромокаемый SWEET DREAMS, наматрасник 160х200 на резинке по периметру на кровать 160, хлопок, непромокаемая простынь на резинке с бортом. Уцененный товар'),
#  Document(doc_id=1657036208, name='От саванны до дивана: Эволюционная история кошек Лосос Джонатан Б. | Лосос Джонатан Б.. Уцененный товар | Лосос Джонатан Б.'),
#  Document(doc_id=241146291, name='Наматрасник 180х200 водонепроницаемый непромокаемый SWEET DREAMS, наматрасник 180 200 на резинке по периметру на кровать 180, хлопок, непромокаемая простынь на резинке с бортом'),
#  Document(doc_id=1578142644, name='Средство пятновыводитель для чистки ковров, дивана,салона и удаления пятен на мягкой мебели WONDER LAB, без запаха, 550 мл. Уцененный товар'),
#  Document(doc_id=172686265, name='Наматрасник 90х200 непромокаемый с бортом на резинке, чехол на матрас или диван аквастоп, простынь непромокаемая водонепроницаемая на резинке, наматрасник топпер'),
#  Document(doc_id=373139897, name='Покрывало детское 145х200 см / покрывало на кровать 1,5 спальное Непоседа, Brawl stars, Путь к славе 16486-1'),
#  Document(doc_id=172686268, name='Наматрасник 140х200 непромокаемый с бортом на резинке, чехол на матрас или диван аквастоп, простынь непромокаемая водонепроницаемая на резинке, наматрасник топпер, наматрацник'),
#  Document(doc_id=172686269, name='Наматрасник 120х200 непромокаемый с бортом на резинке, чехол на матрас или диван аквастоп, простынь непромокаемая водонепроницаемая на резинке, наматрасник топпер, наматрацник'),
#  Document(doc_id=172686270, name='Наматрасник 180х200 непромокаемый с бортом на резинке, чехол на матрас или диван аквастоп, простынь непромокаемая водонепроницаемая на резинке, наматрасник топпер'),
#  Document(doc_id=525483453, name='Ol-Tex Подушка декоративная 40х40 2 шт внутренняя без наволочки, белая / комплект подушек на диван'),
#  Document(doc_id=814884284, name='БДСМ набор для кровати, Комплект для ролевых игр, Товары 18+, Бондаж на кровать'),
#  Document(doc_id=299894209, name='Бондаж БДСМ для крепления к кровати, оковы'),
#  Document(doc_id=367579588, name='Носки с войлоком защитные накладки чехлы на ножки стола, стула, комода, дивана, для мебели бежевый 16 шт.'),
#  Document(doc_id=441160644, name='Плед на кровать Casa Conforte Фантазия, 180х200 см, белый с принтом кошки'),
#  Document(doc_id=1443914190, name='Средство пятновыводитель для чистки ковров, дивана,салона и удаления пятен на мягкой мебели WONDER LAB, без запаха, 550 мл. Уцененный товар'),
#  Document(doc_id=367555536, name='Носки с войлоком защитные накладки чехлы на ножки стола, стула, комода, дивана, для мебели серый 16 шт.'),
#  Document(doc_id=610523088, name='Охлаждающая подставка для ноутбука с 4 вентиляторами и красной подсветкой - мощная система охлаждения USB под большой игровой ноутбук 15" 15,6" 16" 17" на кровать и стол'),
#  Document(doc_id=522969042, name='Накладка на подлокотник дивана DECOREZ / Подставка деревянная 46*34 см'),
#  Document(doc_id=1462934996, name='Средство пятновыводитель для чистки ковров, дивана,салона и удаления пятен на мягкой мебели WONDER LAB, без запаха, 550 мл. Уцененный товар'),
#  Document(doc_id=630268373, name='Подставка на подлокотник дивана ALPY , 40 х 28 см. Гибкий столик лофт на диван'),
#  Document(doc_id=28876761, name='Держатель пялец для вышивания на диване, кресле или за столом, Hobby Nurge'),
#  Document(doc_id=255343578, name='Покрывало "Сладкий Сон" 220х240 см, двустороннее, однотонное, стеганое Ультрастеп. На кровать, на диван.'),
#  Document(doc_id=563247577, name='Средство пятновыводитель для чистки ковров, дивана,салона и удаления пятен на мягкой мебели WONDER LAB, без запаха, 550 мл'),
#  Document(doc_id=424884701, name='Щетка для удаления шерсти животных, щетка для чистки ковров, скребок для удаления катышков, машинка против катышек, щетка для одежды, прибор для снятия ворса, очистки дивана, мебели, пальто, сбора волос. Ролик, валик, миниклинер для уборки ковра'),
#  Document(doc_id=1527138788, name='Средство пятновыводитель для чистки ковров, дивана,салона и удаления пятен на мягкой мебели WONDER LAB, без запаха, 550 мл. Уцененный товар'),
#  Document(doc_id=7014376, name='Sylvanian Families Игровой набор Трехъярусная кровать'),
#  Document(doc_id=567905258, name='Покрывало на кровать и диван 140х220 см стеганое 1,5 спальное, плед для дивана детской и спальни в подарок, бархат, АМИ МЕБЕЛЬ Беларусь'),
#  Document(doc_id=259150828, name='Накладка на подлокотник дивана DECOREZ / Подставка деревянная 46*29 см'),
#  Document(doc_id=600965613, name='Ol-Tex Подушка декоративная 40х40 4 шт однотонные без наволочки, / комплект подушек на диван Карлесграс'),
#  Document(doc_id=1576490482, name='Средство пятновыводитель для чистки ковров, дивана,салона и удаления пятен на мягкой мебели WONDER LAB, без запаха, 550 мл. Уцененный товар'),
#  Document(doc_id=344196083, name='Покрывало на кровать "Стеганое" 180Х200 см PROVANCE , Микрофибра'),
#  Document(doc_id=705164787, name='Подставка для ноутбука Оксфорд , столик для ноутбука, на кровать , коричневый , Ами Мебель'),
#  Document(doc_id=1344919027, name='Подставка для ноутбука Оксфорд , столик для ноутбука, на кровать , коричневый , Ами Мебель. Уцененный товар'),
#  Document(doc_id=225723386, name='Покрывало на кровать 220х240 велсофт ВИТЭЛИЯ диз Полоса серый'),
#  Document(doc_id=478237691, name='Наматрасник 140х200 непромокаемый с бортом на резинке, простынь непромокаемая водонепроницаемая на резинке, чехол на матрас или диван аквастоп, наматрасник топпер'),
#  Document(doc_id=655020030, name='Плед для дивана LUZIA, покрывало на кровать, двухсторонний плед 150x200 см, 1,5 спальный, 60% хлопок, бежевый')]

# %%
calculate_validation_metrics(
    partial(
        search_with_or_condition,
        documents_index,
        documents_dict,
        symbols_to_replace,
        russian_stopwords,
        morph,
    ),
    limit=20,
)
# Out:
# precision = 0.038091081542604974
# recall = 0.6583476100097401
# f1_score = 0.05104573014970413

# %% [markdown]
# ## 3.1 Введение в ранжирование

# %% [markdown]
# #### В обратный индекс можно добавить term frequency

# %%
def create_index_with_tf(documents_processed: list[list[str]], limit: Optional[int] = None):
    sample_documents_processed = documents_processed[:limit]
    corpus_tokens = [
        (token, doc_id) for doc_id, doc_tokens in sample_documents_processed for token in doc_tokens
    ]
    corpus_tokens.sort()

    index = {}

    for token, doc_id in corpus_tokens:
        if token in index:
            if doc_id == index[token][-1][0]:
                index[token][-1][1] += 1
                continue
            index[token].append([doc_id, 1])
        else:
            index[token] = [[doc_id, 1]]

    return index

# %%
index_with_tf = create_index_with_tf(documents_processed)

# %%
index_with_tf["диван"]
# Out:
# [[28876761, 1],
#  [169810294, 1],
#  [169810305, 1],
#  [169810314, 1],
#  [170627411, 1],
#  [170627453, 1],
#  [170627456, 1],
#  [172686265, 1],
#  [172686268, 1],
#  [172686269, 1],
#  [172686270, 1],
#  [174148448, 1],
#  [174443280, 1],
#  [174443281, 1],
#  [174443283, 1],
#  [177310072, 2],
#  [203595521, 1],
#  [203598178, 1],
#  [204416930, 1],
#  [229424677, 1],
#  [229425205, 1],
#  [245377779, 1],
#  [255343578, 1],
#  [258876942, 1],
#  [258901916, 1],
#  [258908855, 1],
#  [259150828, 1],
#  [262376994, 1],
#  [270393871, 1],
#  [279745854, 1],
#  [282182889, 1],
#  [282235399, 1],
#  [282764375, 1],
#  [302585365, 1],
#  [311565940, 1],
#  [325179712, 1],
#  [339324277, 1],
#  [344386617, 2],
#  [361843781, 1],
#  [367354212, 1],
#  [367555536, 1],
#  [367575426, 1],
#  [367579588, 1],
#  [383425290, 1],
#  [414307639, 1],
#  [418312504, 1],
#  [421452489, 1],
#  [424884701, 1],
#  [478237691, 1],
#  [495117560, 2],
#  [496408166, 2],
#  [509211202, 1],
#  [514356916, 1],
#  [522969042, 1],
#  [523819944, 1],
#  [525483453, 1],
#  [541335282, 1],
#  [546303575, 1],
#  [563247577, 1],
#  [565236463, 1],
#  [567905258, 2],
#  [579348175, 1],
#  [582489740, 1],
#  [600652129, 1],
#  [600965613, 1],
#  [627844666, 2],
#  [630268373, 2],
#  [630278394, 2],
#  [630586760, 2],
#  [643881579, 1],
#  [644291804, 1],
#  [646411836, 1],
#  [653519612, 1],
#  [655012125, 1],
#  [655012387, 1],
#  [655015636, 1],
#  [655019087, 1],
#  [655020030, 1],
#  [655020385, 1],
#  [658078122, 1],
#  [666212120, 1],
#  [700739295, 1],
#  [700740270, 1],
#  [710514228, 1],
#  [758012740, 1],
#  [760196459, 1],
#  [760196461, 2],
#  [799296380, 1],
#  [865993989, 1],
#  [866927709, 1],
#  [974487185, 1],
#  [974488377, 1],
#  [974490770, 1],
#  [1055891680, 1],
#  [1055941717, 1],
#  [1142218964, 1],
#  [1164247722, 1],
#  [1164394329, 1],
#  [1164401998, 1],
#  [1164402222, 1],
#  [1194312925, 1],
#  [1434028877, 1],
#  [1439936160, 1],
#  [1443914190, 1],
#  [1462934996, 1],
#  [1489766400, 1],
#  [1489768645, 1],
#  [1527138788, 1],
#  [1531294376, 1],
#  [1531294390, 1],
#  [1531294411, 1],
#  [1531294427, 1],
#  [1531294433, 1],
#  [1531315906, 1],
#  [1531315965, 1],
#  [1531315989, 1],
#  [1531316025, 1],
#  [1531483250, 1],
#  [1569817675, 1],
#  [1571419344, 1],
#  [1571419347, 1],
#  [1571419349, 1],
#  [1571419354, 1],
#  [1571419359, 1],
#  [1571419364, 1],
#  [1575859478, 1],
#  [1576490482, 1],
#  [1577994943, 1],
#  [1578142644, 1],
#  [1580201066, 1],
#  [1584561356, 1],
#  [1590244709, 1],
#  [1594669163, 1],
#  [1605304090, 1],
#  [1605516582, 1],
#  [1651544312, 1],
#  [1657036208, 1],
#  [1660875962, 1],
#  [1669159673, 1]]

# %%
index_with_tf["молоко"]
# Out:
# [[31413018, 1],
#  [33705241, 1],
#  [135456706, 1],
#  [135789425, 1],
#  [135789426, 1],
#  [136780595, 1],
#  [136780600, 1],
#  [137673490, 1],
#  [137673491, 1],
#  [137673492, 1],
#  [138133907, 1],
#  [140463353, 1],
#  [140475265, 1],
#  [140475273, 1],
#  [140675230, 1],
#  [140675231, 1],
#  [140675232, 1],
#  [140675233, 1],
#  [140675234, 1],
#  [140676398, 1],
#  [140676409, 1],
#  [140676410, 1],
#  [140676411, 1],
#  [140676412, 1],
#  [140987734, 1],
#  [140987736, 1],
#  [140987737, 1],
#  [140987738, 1],
#  [140987742, 1],
#  [140987743, 1],
#  [141133760, 2],
#  [141165025, 1],
#  [141165031, 1],
#  [141165033, 1],
#  [141270536, 1],
#  [141270537, 1],
#  [141544350, 1],
#  [141580513, 1],
#  [141580514, 1],
#  [141580515, 1],
#  [141580516, 1],
#  [141580518, 1],
#  [141580519, 1],
#  [141580520, 1],
#  [141580524, 1],
#  [141876199, 1],
#  [141876200, 1],
#  [141876201, 1],
#  [141927409, 1],
#  [142120587, 1],
#  [142120588, 1],
#  [142120589, 1],
#  [142120590, 1],
#  [142479173, 1],
#  [142624198, 1],
#  [142731191, 1],
#  [142731192, 1],
#  [143321964, 1],
#  [143321967, 1],
#  [143321969, 1],
#  [143321972, 1],
#  [143412236, 1],
#  [143415195, 1],
#  [144311416, 1],
#  [144311417, 1],
#  [144311421, 1],
#  [144311422, 1],
#  [144430492, 1],
#  [144560396, 1],
#  [144611482, 1],
#  [145627087, 1],
#  [145627088, 1],
#  [146215033, 1],
#  [146215034, 1],
#  [146215037, 1],
#  [146215038, 1],
#  [146215073, 1],
#  [146215079, 1],
#  [146215080, 1],
#  [146742998, 1],
#  [146742999, 1],
#  [146743000, 1],
#  [146763500, 1],
#  [146763517, 1],
#  [146763537, 1],
#  [146764195, 1],
#  [146764197, 1],
#  [146885506, 1],
#  [146885507, 1],
#  [146885508, 1],
#  [146885509, 1],
#  [146885510, 1],
#  [146885515, 1],
#  [146885516, 1],
#  [146885521, 1],
#  [146885570, 1],
#  [146885579, 1],
#  [146885636, 1],
#  [147135785, 1],
#  [147180362, 2],
#  [147494149, 1],
#  [148054037, 1],
#  [148170755, 1],
#  [149040984, 1],
#  [151000724, 1],
#  [151000725, 1],
#  [151002033, 1],
#  [152669658, 1],
#  [154073276, 1],
#  [154205167, 1],
#  [154205168, 1],
#  [154205170, 1],
#  [154277819, 1],
#  [154330611, 1],
#  [154330613, 1],
#  [154330614, 1],
#  [154330615, 1],
#  [154359448, 1],
#  [155032385, 1],
#  [155032386, 1],
#  [155942494, 1],
#  [155944641, 1],
#  [155947866, 1],
#  [156095237, 1],
#  [156095238, 1],
#  [156418189, 1],
#  [156418190, 1],
#  [156418192, 1],
#  [156418193, 1],
#  [156418195, 1],
#  [157302600, 1],
#  [157806650, 1],
#  [157943187, 1],
#  [158022995, 1],
#  [158022999, 1],
#  [158024880, 1],
#  [160055577, 1],
#  [160055580, 1],
#  [160055582, 1],
#  [160055584, 1],
#  [160055585, 1],
#  [160807696, 1],
#  [161623844, 1],
#  [161623845, 1],
#  [161791004, 1],
#  [162259117, 1],
#  [162961389, 1],
#  [164862552, 1],
#  [164862553, 1],
#  [164862554, 1],
#  [166283896, 1],
#  [166283897, 1],
#  [167297178, 2],
#  [167653047, 1],
#  [167653054, 1],
#  [168666402, 1],
#  [168998188, 1],
#  [169111013, 1],
#  [169111014, 1],
#  [169271009, 1],
#  [170074971, 1],
#  [170074972, 1],
#  [170075133, 1],
#  [170222065, 1],
#  [170222066, 1],
#  [170380618, 1],
#  [171820606, 2],
#  [172173218, 1],
#  [172173227, 1],
#  [172173229, 1],
#  [172173233, 1],
#  [172173236, 1],
#  [172292342, 1],
#  [172374454, 1],
#  [172554143, 1],
#  [172572542, 1],
#  [172605781, 1],
#  [172622743, 1],
#  [172799947, 1],
#  [172891367, 1],
#  [172893911, 1],
#  [172955994, 1],
#  [173023395, 1],
#  [173306598, 1],
#  [173392263, 1],
#  [173491816, 1],
#  [173491817, 1],
#  [173521638, 1],
#  [173625674, 1],
#  [174416300, 1],
#  [175181733, 1],
#  [175415348, 1],
#  [175640183, 1],
#  [176164087, 1],
#  [176405569, 1],
#  [176417860, 1],
#  [177205272, 1],
#  [177205275, 1],
#  [177205278, 1],
#  [177205279, 1],
#  [177205282, 2],
#  [177205283, 2],
#  [177205285, 2],
#  [177205286, 1],
#  [177205289, 1],
#  [177205290, 1],
#  [177223762, 1],
#  [177614297, 1],
#  [178018770, 1],
#  [178018774, 1],
#  [178018775, 1],
#  [178018777, 1],
#  [178259607, 1],
#  [178259626, 1],
#  [178324381, 1],
#  [178324382, 1],
#  [179185965, 1],
#  [180437474, 1],
#  [181167420, 1],
#  [181579167, 1],
#  [182776073, 1],
#  [183121252, 1],
#  [183441675, 1],
#  [184264428, 1],
#  [184264429, 1],
#  [184264430, 1],
#  [184264432, 1],
#  [184264433, 1],
#  [184264434, 1],
#  [184264435, 1],
#  [184275898, 1],
#  [185256457, 1],
#  [186566657, 1],
#  [186566664, 1],
#  [193902964, 1],
#  [193975978, 1],
#  [194587386, 1],
#  [195331251, 1],
#  [195331272, 1],
#  [195331282, 1],
#  [195331359, 1],
#  [196528143, 2],
#  [198678694, 1],
#  [199587301, 1],
#  [200559494, 1],
#  [202914782, 1],
#  [202914789, 1],
#  [202914790, 1],
#  [204177003, 1],
#  [208092633, 1],
#  [208092637, 1],
#  [210158999, 1],
#  [217452033, 1],
#  [217987857, 1],
#  [221505576, 1],
#  [223692972, 1],
#  [226161477, 1],
#  [226161510, 1],
#  [226194350, 1],
#  [226292200, 1],
#  [226977633, 1],
#  [228145524, 1],
#  [229157298, 1],
#  [229211643, 1],
#  [229340419, 1],
#  [231193649, 1],
#  [231293892, 1],
#  [231555166, 1],
#  [235088899, 1],
#  [236505711, 1],
#  [239026893, 1],
#  [239662977, 1],
#  [242209232, 1],
#  [242681244, 1],
#  [244515961, 1],
#  [244676770, 1],
#  [244824761, 1],
#  [245206607, 1],
#  [245598422, 1],
#  [247317352, 1],
#  [249290161, 1],
#  [249366273, 1],
#  [256287695, 1],
#  [256653748, 1],
#  [257235961, 1],
#  [258455993, 1],
#  [258820582, 1],
#  [258849378, 1],
#  [259531020, 1],
#  [260270447, 1],
#  [260336065, 1],
#  [260348592, 1],
#  [260799895, 1],
#  [261926499, 1],
#  [263943905, 1],
#  [264270885, 1],
#  [264394561, 1],
#  [264398053, 1],
#  [264404121, 1],
#  [265143538, 1],
#  [265144517, 1],
#  [266063233, 1],
#  [266965216, 1],
#  [268440601, 1],
#  [268906403, 1],
#  [271473147, 1],
#  [278174138, 1],
#  [278240528, 1],
#  [278649907, 1],
#  [282351251, 1],
#  [284189403, 1],
#  [285033322, 1],
#  [285378961, 1],
#  [285478912, 1],
#  [285520909, 1],
#  [287323869, 1],
#  [288740204, 1],
#  [288740652, 1],
#  [288887032, 1],
#  [288888459, 1],
#  [288984542, 1],
#  [289313231, 1],
#  [291634716, 1],
#  [291634717, 1],
#  [291634724, 1],
#  [291634735, 1],
#  [291634737, 1],
#  [291634765, 1],
#  [291731454, 1],
#  [292060365, 1],
#  [296396134, 1],
#  [298386422, 1],
#  [299113469, 1],
#  [300727742, 1],
#  [300751105, 1],
#  [301007786, 1],
#  [301007843, 1],
#  [301021293, 1],
#  [301021300, 1],
#  [301529236, 1],
#  [302121080, 1],
#  [303734339, 1],
#  [303734349, 1],
#  [303734515, 1],
#  [303734524, 1],
#  [303734526, 1],
#  [303734531, 1],
#  [303734538, 1],
#  [303734539, 1],
#  [303734541, 1],
#  [305484179, 1],
#  [305484275, 1],
#  [305484390, 1],
#  [309145812, 1],
#  [310469772, 1],
#  [310473718, 1],
#  [312000285, 1],
#  [313539476, 1],
#  [314021506, 1],
#  [314021507, 1],
#  [314021510, 1],
#  [315270083, 1],
#  [318775286, 1],
#  [318804655, 1],
#  [318804656, 1],
#  [318894446, 1],
#  [318894458, 1],
#  [320042243, 2],
#  [320117242, 1],
#  [320131582, 1],
#  [320131583, 1],
#  [320362144, 1],
#  [320362149, 1],
#  [320362153, 1],
#  [320860118, 1],
#  [320860119, 1],
#  [320860120, 1],
#  [321876197, 1],
#  [321876199, 1],
#  [321880201, 1],
#  [321880202, 1],
#  [321880203, 1],
#  [321880204, 1],
#  [321880207, 1],
#  [322022679, 1],
#  [322702994, 1],
#  [323270354, 1],
#  [323270355, 1],
#  [324632139, 1],
#  [324632157, 1],
#  [325397718, 1],
#  [325397719, 1],
#  [326087406, 1],
#  [326322260, 1],
#  [332310439, 1],
#  [334867057, 1],
#  [338186381, 1],
#  [339651717, 1],
#  [340441239, 1],
#  [340446790, 1],
#  [340446791, 1],
#  [340446792, 1],
#  [340446793, 1],
#  [340446851, 1],
#  [340446914, 1],
#  [340446973, 1],
#  [340447007, 1],
#  [340453076, 1],
#  [341974114, 1],
#  [346769368, 1],
#  [354309997, 1],
#  [355402233, 1],
#  [356464421, 1],
#  [356521098, 1],
#  [356521138, 1],
#  [357245459, 1],
#  [357589791, 1],
#  [357823601, 1],
#  [364492805, 1],
#  [364778302, 1],
#  [365144523, 1],
#  [384149827, 1],
#  [384532974, 1],
#  [384893949, 1],
#  [390556665, 1],
#  [390556756, 1],
#  [405918926, 1],
#  [409509397, 1],
#  [411796973, 1],
#  [411796980, 1],
#  [412980379, 1],
#  [414786561, 1],
#  [416619278, 1],
#  [421518026, 1],
#  [421518036, 1],
#  [421518047, 1],
#  [425498244, 1],
#  [430918395, 1],
#  [430918409, 1],
#  [430918419, 1],
#  [431422043, 1],
#  [431422050, 1],
#  [438244835, 1],
#  [441182554, 1],
#  [444923834, 1],
#  [448485977, 1],
#  [454556690, 1],
#  [455561922, 1],
#  [462182700, 1],
#  [462182702, 1],
#  [462182704, 1],
#  [462182706, 1],
#  [462182707, 1],
#  [462182711, 1],
#  [462182883, 1],
#  [462663324, 1],
#  [462978177, 1],
#  [462998304, 1],
#  [463007993, 1],
#  [465388420, 1],
#  [471497219, 1],
#  [471497224, 1],
#  [472080455, 1],
#  [474954581, 1],
#  [476491844, 1],
#  [487182273, 1],
#  [487182288, 1],
#  [487182301, 1],
#  [487182318, 1],
#  [488314168, 1],
#  [499644336, 1],
#  [501007954, 1],
#  [503167370, 1],
#  [505792649, 1],
#  [506277252, 1],
#  [511253096, 2],
#  [519534352, 1],
#  [519820403, 1],
#  [519820443, 1],
#  [519820475, 1],
#  [520860914, 1],
#  [531354311, 1],
#  [531899966, 2],
#  [533853502, 1],
#  [535113181, 1],
#  [536879962, 1],
#  [538791647, 2],
#  [544147121, 1],
#  [545445868, 1],
#  [546525900, 1],
#  [546560547, 1],
#  [559658791, 1],
#  [562238227, 1],
#  [562276830, 1],
#  [562398250, 1],
#  [562401707, 1],
#  [564773232, 1],
#  [571985016, 1],
#  [571995783, 1],
#  [572003129, 1],
#  [573345532, 1],
#  [577008886, 1],
#  [577069307, 1],
#  [578793695, 1],
#  [589079289, 1],
#  [589947169, 1],
#  [589947269, 1],
#  [590866536, 1],
#  [590866537, 1],
#  [593277105, 1],
#  [595822738, 1],
#  [595822850, 1],
#  [598086937, 1],
#  [600850869, 1],
#  [601053873, 2],
#  [605053331, 1],
#  [605055754, 1],
#  [605368380, 1],
#  [605368391, 1],
#  [605368708, 1],
#  [607926587, 1],
#  [609077649, 1],
#  [609230204, 1],
#  [612677181, 1],
#  [612678669, 1],
#  [612685512, 1],
#  [612689331, 1],
#  [615605380, 1],
#  [616102573, 1],
#  [618255650, 1],
#  [618666830, 1],
#  [618808640, 1],
#  [618929846, 1],
#  [622804571, 1],
#  [623807749, 1],
#  [624364678, 1],
#  [626462644, 1],
#  [630604122, 2],
#  [636252447, 1],
#  [637047474, 1],
#  [637862648, 1],
#  [638192386, 1],
#  [641206867, 1],
#  [641206933, 1],
#  [641970527, 1],
#  [641991132, 1],
#  [642608994, 1],
#  [648658221, 1],
#  [650177621, 1],
#  [652515829, 1],
#  [654013075, 1],
#  [654013203, 1],
#  [654013385, 1],
#  [654013448, 1],
#  [654013558, 1],
#  [654013717, 1],
#  [654014104, 1],
#  [654014109, 1],
#  [654014112, 1],
#  [654014695, 1],
#  [659373191, 1],
#  [659459569, 2],
#  [661216265, 1],
#  [661216778, 1],
#  [662066688, 1],
#  [662152564, 1],
#  [671665913, 1],
#  [672037427, 1],
#  [676896595, 1],
#  [683401134, 1],
#  [684991324, 1],
#  [688568644, 1],
#  [692591763, 1],
#  [694514761, 1],
#  [697209691, 1],
#  [700841498, 1],
#  [700841977, 1],
#  [701156312, 1],
#  [703746383, 1],
#  [709372520, 1],
#  [709373794, 1],
#  [709373807, 1],
#  [711783443, 2],
#  [715603595, 1],
#  [715603596, 1],
#  [715603597, 1],
#  [715603629, 1],
#  [719318410, 1],
#  [721039161, 1],
#  [721488382, 1],
#  [721488389, 1],
#  [724894287, 1],
#  [727768838, 1],
#  [729714012, 1],
#  [729715307, 1],
#  [729715575, 1],
#  [730788765, 1],
#  [740360989, 1],
#  [741955430, 1],
#  [743398996, 1],
#  [743399335, 1],
#  [743925955, 1],
#  [743925978, 1],
#  [745044678, 1],
#  [749895900, 1],
#  [750443109, 1],
#  [753398418, 1],
#  [756423174, 1],
#  [759435922, 1],
#  [762654068, 1],
#  [763821343, 1],
#  [763959425, 1],
#  [763959430, 1],
#  [763959466, 1],
#  [765198754, 1],
#  [765886652, 1],
#  [765886655, 1],
#  [765886656, 1],
#  [769530152, 1],
#  [789573365, 1],
#  [791482919, 1],
#  [791482920, 1],
#  [791483024, 1],
#  [793483322, 1],
#  [794935979, 1],
#  [796153084, 1],
#  [798378291, 1],
#  [799207326, 1],
#  [800272732, 1],
#  [802116362, 1],
#  [813316344, 1],
#  [816965744, 1],
#  [822006157, 1],
#  [823996062, 1],
#  [829294701, 1],
#  [832953030, 1],
#  [833703864, 1],
#  [837921792, 1],
#  [847169756, 1],
#  [853046462, 2],
#  [860273599, 1],
#  [863798467, 1],
#  [863798472, 1],
#  [864733783, 1],
#  [870069469, 1],
#  [870070117, 1],
#  [890385153, 1],
#  [890385158, 2],
#  [890385164, 2],
#  [905843592, 1],
#  [916701361, 1],
#  [943235402, 1],
#  [943268942, 1],
#  [954635582, 1],
#  [958072425, 1],
#  [958613479, 1],
#  [966438673, 1],
#  [966438684, 1],
#  [969189169, 1],
#  [984125162, 1],
#  [984125224, 1],
#  [985335612, 1],
#  [987087662, 1],
#  [987087665, 1],
#  [987087681, 1],
#  [987403930, 1],
#  [1032421228, 1],
#  [1032594689, 1],
#  [1032644831, 1],
#  [1032652608, 1],
#  [1032657595, 1],
#  [1032818971, 1],
#  [1033877988, 1],
#  [1034884698, 1],
#  [1044732304, 1],
#  [1058171539, 1],
#  [1058172395, 1],
#  [1062697951, 1],
#  [1062699773, 1],
#  [1074158529, 1],
#  [1087295940, 1],
#  [1089030176, 1],
#  [1089030195, 1],
#  [1119531406, 1],
#  [1144807309, 1],
#  [1145651403, 1],
#  [1145651693, 1],
#  [1145651761, 1],
#  [1152420699, 1],
#  [1152421097, 1],
#  [1567291468, 1],
#  [1567854144, 1],
#  [1567970665, 1],
#  [1567972657, 1],
#  [1567978775, 1],
#  [1567980032, 1],
#  [1567982677, 1],
#  [1567983142, 1],
#  [1568946360, 1],
#  [1569065798, 1],
#  [1569065801, 1],
#  [1569208599, 1],
#  [1569871000, 1],
#  [1569900799, 1],
#  [1570460820, 1],
#  [1572319266, 1],
#  [1573313916, 1],
#  [1573804461, 1],
#  [1574223080, 1],
#  [1574223795, 1],
#  [1574224279, 1],
#  [1574785779, 1],
#  [1575117352, 1],
#  [1575354761, 1],
#  [1575355072, 1],
#  [1575355603, 1],
#  [1575368031, 1],
#  [1575368343, 1],
#  [1575780815, 1],
#  [1575793516, 1],
#  [1575795512, 1],
#  [1576285336, 1],
#  [1576287013, 1],
#  [1576288733, 1],
#  [1576291275, 1],
#  [1576465405, 1],
#  [1576485283, 1],
#  [1577541194, 1],
#  [1578097446, 1],
#  [1578097450, 1],
#  [1578129464, 1],
#  [1578196630, 1],
#  [1578470020, 1],
#  [1578560412, 1],
#  [1578579473, 1],
#  [1578653235, 1],
#  [1580011922, 1],
#  [1580628880, 1],
#  [1581058334, 1],
#  [1581101929, 1],
#  [1581164434, 1],
#  [1581452058, 1],
#  [1581541759, 1],
#  ...]

# %%
with open("documents_index_with_tf.json", "w") as f:
    json.dump(index_with_tf, f)

# %%
with open("documents_index_with_tf.json", "r") as f:
    documents_index_with_tf = json.load(f)

# %% [markdown]
# ### Взвешенный поиск по индексу

# %%
def search_with_tf_with_or_condition(
    index: dict[str, list[int]], 
    documents_dict: dict[int, str],
    symbols_to_replace: dict[str, str],
    russian_stopwords: set[str],
    lemmatizer: MorphAnalyzer, 
    query: str, 
    limit: Optional[int] = None,
) -> list[str]:
    query_processed = process_document(query, symbols_to_replace, russian_stopwords, lemmatizer)

    result = dict()
    for token in query_processed:
        token_results = index.get(token, [])
        for token_result in token_results:
            doc_id, tf = token_result[0], token_result[1]
            if doc_id in result:
                result[doc_id] += tf
            else:
                result[doc_id] = tf

    return sorted(
        [Document(doc_id=result_doc_id, name=[documents_dict[result_doc_id], score]) for result_doc_id, score in result.items()],
        key=lambda x: -x.name[1]
    )[:limit]

# %%
search_with_tf_with_or_condition(
    documents_index_with_tf,
    documents_dict,
    symbols_to_replace,
    russian_stopwords,
    morph,
    "диван кровать",
    10,
)
# Out:
# [Document(doc_id=177310072, name=['Плед Павлайн Ирен какао 150х200 , плед на кровать; плед на диван; покрывало на кровать; покрывало на диван; плед 150 на 200; плед 200 на 220; 150*200; плед 200х220; плед 150х200; полуторка', 4]),
#  Document(doc_id=496408166, name=['Покрывало на кровать и диван 117х200 см стеганое, плед для дивана детской и спальни в подарок, бархат, серое АМИ МЕБЕЛЬ Беларусь', 3]),
#  Document(doc_id=567905258, name=['Покрывало на кровать и диван 140х220 см стеганое 1,5 спальное, плед для дивана детской и спальни в подарок, бархат, АМИ МЕБЕЛЬ Беларусь', 3]),
#  Document(doc_id=627844666, name=['Покрывало плед шерстяной 200х220 см PLEDICO "Скандинавский стиль" на кровать диван евро, серый белый, накидка на диван шерсть, подарочная упаковка, производство Россия', 3]),
#  Document(doc_id=655020385, name=['Плед 200х220 на кровать LUZIA, покрывало на кровать, для дивана, двухсторонний, 60% хлопок, бежевый', 3]),
#  Document(doc_id=760196461, name=['Плед 200х220 для дивана LAVAL, покрывало на кровать, для дивана, двухсторонний, 60% хлопок, бежевый', 3]),
#  Document(doc_id=1577994943, name=['Плед 200х220 на кровать LUZIA, покрывало на кровать, для дивана, двухсторонний, 60% хлопок, бежевый. Уцененный товар', 3]),
#  Document(doc_id=229424677, name=['Пылесос для дома Jimmy WB55, ручной, для мебели и для удаления пылевых клещей, от шерсти животных, с контейнером, для диванов и кроватей, ультрафиолетовая и ультразвуковая чистка, мощный 600Вт', 2]),
#  Document(doc_id=229425205, name=['Пылесос для дома Jimmy JV35, ручной, для мебели, для удаления пылевых клещей, от шерсти животных, с контейнером, для диванов и кроватей, ультрафиолетовая чистка и обработка горячим воздухом', 2]),
#  Document(doc_id=245377779, name=['Покрывало на диван/кровать MIX 140х210 см', 2])]

# %%
search_with_tf_with_or_condition(
    documents_index_with_tf,
    documents_dict,
    symbols_to_replace,
    russian_stopwords,
    morph,
    "молоко ультрапастеризованное 1литр",
    10,
)
# Out:
# [Document(doc_id=1615880294, name=['Молоко ультрапастеризованное Просто Молоко, 3,2 %, 1 л', 3]),
#  Document(doc_id=1615880546, name=['Молоко ультрапастеризованное Просто Молоко, 2,5 %, 1 л', 3]),
#  Document(doc_id=140987734, name=['Valio Молоко Ультрапастеризованное 1.5% 250мл. 1шт.', 2]),
#  Document(doc_id=140987737, name=['Valio Молоко Ультрапастеризованное 2.5% 1000мл. 1шт.', 2]),
#  Document(doc_id=140987742, name=['Valio Молоко Ультрапастеризованное 3.5% 1000мл. 1шт.', 2]),
#  Document(doc_id=141133760, name=['Шоколад Ritter Sport "Альпийское молоко" с альпийским молоком, 100 г', 2]),
#  Document(doc_id=141165025, name=['Молоко ультрапастеризованное Простоквашино, 3,2%, 950 мл', 2]),
#  Document(doc_id=141270536, name=['Молоко Вкуснотеево ультрапастеризованное, 2,5%, 950 мл', 2]),
#  Document(doc_id=141270537, name=['Молоко ультрапастеризованное, 3,2%, 950 мл, Вкуснотеево', 2]),
#  Document(doc_id=141580513, name=['Молоко ультрапастеризованное 3,5%, 1 л, Parmalat', 2])]

# %%
calculate_validation_metrics(
    partial(
        search_with_tf_with_or_condition,
        documents_index_with_tf,
        documents_dict,
        symbols_to_replace,
        russian_stopwords,
        morph,
    ),
    limit=20,
)
# Out:
# precision = 0.11266666666666668
# recall = 0.11471620251678676
# f1_score = 0.10590267610832985

# %% [markdown]
# ### Альтернативное хранение словаря - префиксное дерево поиска aka trie

# %%
class TrieNode:
    def __init__(self):
        self.children: dict[str, "TrieNode"] = {}
        self.is_end_of_word: bool = False
        self.document_ids: list[int] = set()

class TrieInvertedIndex:
    def __init__(self):
        self.root = TrieNode()

    def _insert_document(self, token: str, doc_id: int) -> None:
        node = self.root

        for char in token:
            if char not in node.children:
                node.children[char] = TrieNode()
            node = node.children[char]

        node.is_end_of_word = True
        node.document_ids.add(doc_id)
    
    def insert_document(self, doc_id: int, tokens: list[str]) -> None:
        for token in tokens:
            self._insert_document(token, doc_id)

    def _search_node(self, token: str) -> TrieNode:
        node = self.root
        
        for char in token:
            if char not in node.children:
                return None
            node = node.children[char]

        return node
    
    def search(self, token: str) -> list[int]:
        node = self._search_node(token)

        if node and node.is_end_of_word:
            return sorted(node.document_ids)
        return []

# %%
def create_trie_index(documents_processed: list[tuple[int, list[str]]], limit: Optional[int] = None) -> TrieInvertedIndex:
    sample_documents_processed = documents_processed[:limit] if limit else documents_processed
    index = TrieInvertedIndex()
    
    for doc_id, tokens in sample_documents_processed:
        index.insert_document(doc_id, tokens)
    
    return index

# %%
trie_index = create_trie_index(documents_processed)

# %%
def search_with_and_condition(
    index: TrieInvertedIndex, 
    documents_dict: dict[int, str],
    symbols_to_replace: dict[str, str],
    russian_stopwords: set[str],
    lemmatizer: MorphAnalyzer,
    query: str, 
    limit: Optional[int] = None,
) -> list[str]:
    query_processed = process_document(query, symbols_to_replace, russian_stopwords, lemmatizer)
    if not query_processed:
        return []
    merged_posting_lists = merge_and(
        [index.search(token) for token in query_processed]
    )
    
    return [
        Document(doc_id=result_doc_id, name=documents_dict[result_doc_id]) for result_doc_id in merged_posting_lists
    ][:limit]

# %%
search_with_and_condition(
    trie_index,
    documents_dict,
    symbols_to_replace,
    russian_stopwords,
    morph,
    "двухъярусная кровать",
    10,
)
# Out:
# [Document(doc_id=355105396, name='Двухъярусная кровать для кукол 46 см Our genration'),
#  Document(doc_id=355115836, name="Набор мебели игровой Li'l Woodzeez Детская и двухъярусная кровать")]

# %%
search_with_and_condition(
    trie_index,
    documents_dict,
    symbols_to_replace,
    russian_stopwords,
    morph,
    "молоко ультрапастеризованное",
    10,
)
# Out:
# [Document(doc_id=140987734, name='Valio Молоко Ультрапастеризованное 1.5% 250мл. 1шт.'),
#  Document(doc_id=140987737, name='Valio Молоко Ультрапастеризованное 2.5% 1000мл. 1шт.'),
#  Document(doc_id=140987742, name='Valio Молоко Ультрапастеризованное 3.5% 1000мл. 1шт.'),
#  Document(doc_id=141165025, name='Молоко ультрапастеризованное Простоквашино, 3,2%, 950 мл'),
#  Document(doc_id=141270536, name='Молоко Вкуснотеево ультрапастеризованное, 2,5%, 950 мл'),
#  Document(doc_id=141270537, name='Молоко ультрапастеризованное, 3,2%, 950 мл, Вкуснотеево'),
#  Document(doc_id=141580513, name='Молоко ультрапастеризованное 3,5%, 1 л, Parmalat'),
#  Document(doc_id=141580514, name='Молоко ультрапастеризованное 1,8% 1 л, Parmalat'),
#  Document(doc_id=141580515, name='Parmalat Молоко Ультрапастеризованное 0.5% 1000мл. 1шт.'),
#  Document(doc_id=141580516, name='Parmalat Молоко Ультрапастеризованное 3.5% 200мл. 1шт.')]

# %% [markdown]
# #### Что получили:
#
# 1. Экономия памяти для схожих токенов
#
# 2. Эффективный поиск по префиксу - можно находить все токены, начинающиеся с определенной последовательности символов
